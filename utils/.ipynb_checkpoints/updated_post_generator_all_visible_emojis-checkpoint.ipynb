# %% [markdown]
# ##  Creation of Facebook post  (no overlapping emojis)
# Includes:
# - replacement of dislike by comment button
# - likes and reactions (overlapping)
# - nr shares and comments

# %%
import os
BASE_DIR = "/home/scc/miranda.barros-everett/conformity-llms-facebook-posts"

# %% [markdown]
# ## Correct statement

# %% [markdown]
# ### Remy Ashford

# %%
from post_generator_all_visible_emojis import generate_facebook_post, display_facebook_post

PROFILE_NAME = "Remy Ashford" 
POST_TEXT = "The Spotify 2026 music genres distribution has just been released. Looks like Pop was more popular than Latin this year!"
POST_TIME = "Today at 2:43 PM"
VERIFIED = False  # Set to True to show verified badge

PROFILE_IMAGE_PATH =  None

# missing endearing emoji!
REACTION_DEFS = {
    "like":  ("👍", "#1877f2"),
    "love":  ("❤️", "#f33e58"),
    "haha":  ("😆", "#f7b928"),
    "wow":   ("😮", "#f7b928"),
    "sad":   ("😢", "#f7b928"),
    "angry": ("😡", "#e9710f"),
}

REACTIONS = {
    "like":  0,
    "love":  0,
    "haha":  0,
    "wow":   0,
    "sad":   0,
    "angry": 0,
}
COMMENT_COUNT = 0
SHARE_COUNT   = 0

for i in range(1, 101):
    POST_IMAGE_PATH = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_visualizations/pop_23_5_latin_11/spotify_genre_pie_chart_{i:03d}.png")
    output_file = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_plot_posts/baselines/correct/html/{i:03d}_remy_ashford_c.html")
    
    html_content = generate_facebook_post(
        profile_name=PROFILE_NAME,
        post_text=POST_TEXT,
        post_time=POST_TIME,
        reactions=REACTIONS,
        comment_count=COMMENT_COUNT,
        share_count=SHARE_COUNT,
        post_image_path=POST_IMAGE_PATH,
        output_file=output_file,
        verified=VERIFIED,
        profile_image_path=PROFILE_IMAGE_PATH,
    )
    display_facebook_post(html_content)

# %%
"""
# To delete all files in a folder with a specific name
import os
import glob

folder = "/home/scc/miranda.barros-everett/conformity-llms-facebook-posts/spotify_pie_plot/pie_plot_posts/baselines/incorrect/html/"

files = glob.glob(os.path.join(folder, "*.html"))
for f in files:
    os.remove(f)
    print(f"Deleted: {f}")

print("Done!")
"""

# %% [markdown]
# ### Morgan Fenwick

# %%
from post_generator_all_visible_emojis import generate_facebook_post, display_facebook_post

PROFILE_NAME = "Morgan Fenwick" 
POST_TEXT = "The Spotify 2026 music genres distribution has just been released. Looks like Pop was more popular than Latin this year!"
POST_TIME = "Today at 2:43 PM"
VERIFIED = False  # Set to True to show verified badge

PROFILE_IMAGE_PATH =  None

# missing endearing emoji!
REACTION_DEFS = {
    "like":  ("👍", "#1877f2"),
    "love":  ("❤️", "#f33e58"),
    "haha":  ("😆", "#f7b928"),
    "wow":   ("😮", "#f7b928"),
    "sad":   ("😢", "#f7b928"),
    "angry": ("😡", "#e9710f"),
}

REACTIONS = {
    "like":  0,
    "love":  0,
    "haha":  0,
    "wow":   0,
    "sad":   0,
    "angry": 0,
}
COMMENT_COUNT = 0
SHARE_COUNT   = 0

# 

for i in range(1, 101):
    POST_IMAGE_PATH = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_visualizations/pop_23_5_latin_11/spotify_genre_pie_chart_{i:03d}.png")
    output_file = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_plot_posts/baselines/correct/html/{i:03d}_morgan_fenwick_c.html")
    
    html_content = generate_facebook_post(
        profile_name=PROFILE_NAME,
        post_text=POST_TEXT,
        post_time=POST_TIME,
        reactions=REACTIONS,
        comment_count=COMMENT_COUNT,
        share_count=SHARE_COUNT,
        post_image_path=POST_IMAGE_PATH,
        output_file=output_file,
        verified=VERIFIED,
        profile_image_path=PROFILE_IMAGE_PATH,
    )
    display_facebook_post(html_content)

# %% [markdown]
# ### Casey Brierly

# %%
from post_generator_all_visible_emojis import generate_facebook_post, display_facebook_post

PROFILE_NAME = "Casey Brierly" 
POST_TEXT = "The Spotify 2026 music genres distribution has just been released. Looks like Pop was more popular than Latin this year!"
POST_TIME = "Today at 2:43 PM"
VERIFIED = False  # Set to True to show verified badge

PROFILE_IMAGE_PATH =  None

# missing endearing emoji!
REACTION_DEFS = {
    "like":  ("👍", "#1877f2"),
    "love":  ("❤️", "#f33e58"),
    "haha":  ("😆", "#f7b928"),
    "wow":   ("😮", "#f7b928"),
    "sad":   ("😢", "#f7b928"),
    "angry": ("😡", "#e9710f"),
}

REACTIONS = {
    "like":  0,
    "love":  0,
    "haha":  0,
    "wow":   0,
    "sad":   0,
    "angry": 0,
}
COMMENT_COUNT = 0
SHARE_COUNT   = 0

for i in range(1, 101):
    POST_IMAGE_PATH = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_visualizations/pop_23_5_latin_11/spotify_genre_pie_chart_{i:03d}.png")
    output_file = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_plot_posts/baselines/correct/html/{i:03d}_casey_brierly_c.html")
    
    html_content = generate_facebook_post(
        profile_name=PROFILE_NAME,
        post_text=POST_TEXT,
        post_time=POST_TIME,
        reactions=REACTIONS,
        comment_count=COMMENT_COUNT,
        share_count=SHARE_COUNT,
        post_image_path=POST_IMAGE_PATH,
        output_file=output_file,
        verified=VERIFIED,
        profile_image_path=PROFILE_IMAGE_PATH,
    )
    display_facebook_post(html_content)

# %% [markdown]
# # Incorrect statement

# %% [markdown]
# ### Remy Ashford

# %%
from post_generator_all_visible_emojis import generate_facebook_post, display_facebook_post

PROFILE_NAME = "Remy Ashford" 
POST_TEXT = "The Spotify 2026 music genres distribution has just been released. Looks like Latin was more popular than Pop this year!"
POST_TIME = "Today at 2:43 PM"
VERIFIED = False  # Set to True to show verified badge

PROFILE_IMAGE_PATH =  None

# missing endearing emoji!
REACTION_DEFS = {
    "like":  ("👍", "#1877f2"),
    "love":  ("❤️", "#f33e58"),
    "haha":  ("😆", "#f7b928"),
    "wow":   ("😮", "#f7b928"),
    "sad":   ("😢", "#f7b928"),
    "angry": ("😡", "#e9710f"),
}

REACTIONS = {
    "like":  0,
    "love":  0,
    "haha":  0,
    "wow":   0,
    "sad":   0,
    "angry": 0,
}
COMMENT_COUNT = 0
SHARE_COUNT   = 0

for i in range(1, 101):
    POST_IMAGE_PATH = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_visualizations/pop_23_5_latin_11/spotify_genre_pie_chart_{i:03d}.png")
    output_file = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_plot_posts/baselines/incorrect/html/{i:03d}_remy_ashford_i.html")
    
    html_content = generate_facebook_post(
        profile_name=PROFILE_NAME,
        post_text=POST_TEXT,
        post_time=POST_TIME,
        reactions=REACTIONS,
        comment_count=COMMENT_COUNT,
        share_count=SHARE_COUNT,
        post_image_path=POST_IMAGE_PATH,
        output_file=output_file,
        verified=VERIFIED,
        profile_image_path=PROFILE_IMAGE_PATH,
    )
    display_facebook_post(html_content)

# %% [markdown]
# ### Morgan Fenwick

# %%
from post_generator_all_visible_emojis import generate_facebook_post, display_facebook_post

PROFILE_NAME = "Morgan Fenwick" 
POST_TEXT = "The Spotify 2026 music genres distribution has just been released. Looks like Latin was more popular than Pop this year!"
POST_TIME = "Today at 2:43 PM"
VERIFIED = False  # Set to True to show verified badge

PROFILE_IMAGE_PATH =  None

# missing endearing emoji!
REACTION_DEFS = {
    "like":  ("👍", "#1877f2"),
    "love":  ("❤️", "#f33e58"),
    "haha":  ("😆", "#f7b928"),
    "wow":   ("😮", "#f7b928"),
    "sad":   ("😢", "#f7b928"),
    "angry": ("😡", "#e9710f"),
}

REACTIONS = {
    "like":  0,
    "love":  0,
    "haha":  0,
    "wow":   0,
    "sad":   0,
    "angry": 0,
}
COMMENT_COUNT = 0
SHARE_COUNT   = 0

# 

for i in range(1, 101):
    POST_IMAGE_PATH = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_visualizations/pop_23_5_latin_11/spotify_genre_pie_chart_{i:03d}.png")
    output_file = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_plot_posts/baselines/incorrect/html/{i:03d}_morgan_fenwick_i.html")
    
    html_content = generate_facebook_post(
        profile_name=PROFILE_NAME,
        post_text=POST_TEXT,
        post_time=POST_TIME,
        reactions=REACTIONS,
        comment_count=COMMENT_COUNT,
        share_count=SHARE_COUNT,
        post_image_path=POST_IMAGE_PATH,
        output_file=output_file,
        verified=VERIFIED,
        profile_image_path=PROFILE_IMAGE_PATH,
    )
    display_facebook_post(html_content)

# %% [markdown]
# ### Casey Brierly

# %%
from post_generator_all_visible_emojis import generate_facebook_post, display_facebook_post

PROFILE_NAME = "Casey Brierly" 
POST_TEXT = "The Spotify 2026 music genres distribution has just been released. Looks like Latin was more popular than Pop this year!"
POST_TIME = "Today at 2:43 PM"
VERIFIED = False  # Set to True to show verified badge

PROFILE_IMAGE_PATH =  None

# missing endearing emoji!
REACTION_DEFS = {
    "like":  ("👍", "#1877f2"),
    "love":  ("❤️", "#f33e58"),
    "haha":  ("😆", "#f7b928"),
    "wow":   ("😮", "#f7b928"),
    "sad":   ("😢", "#f7b928"),
    "angry": ("😡", "#e9710f"),
}

REACTIONS = {
    "like":  0,
    "love":  0,
    "haha":  0,
    "wow":   0,
    "sad":   0,
    "angry": 0,
}
COMMENT_COUNT = 0
SHARE_COUNT   = 0

# 

for i in range(1, 101):
    POST_IMAGE_PATH = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_visualizations/pop_23_5_latin_11/spotify_genre_pie_chart_{i:03d}.png")
    output_file = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_plot_posts/baselines/incorrect/html/{i:03d}_casey_brierly_i.html")
    
    html_content = generate_facebook_post(
        profile_name=PROFILE_NAME,
        post_text=POST_TEXT,
        post_time=POST_TIME,
        reactions=REACTIONS,
        comment_count=COMMENT_COUNT,
        share_count=SHARE_COUNT,
        post_image_path=POST_IMAGE_PATH,
        output_file=output_file,
        verified=VERIFIED,
        profile_image_path=PROFILE_IMAGE_PATH,
    )
    display_facebook_post(html_content)

# %% [markdown]
# # News Outlets

# %%
from post_generator_all_visible_emojis import generate_facebook_post, display_facebook_post

PROFILES = [
    #{"name": "Remy Ashford",  "verified": False, "profile_image_path": None},
    #{"name": "Casey Brierly",    "verified": False, "profile_image_path": None},
    #{"name": "Morgan Fenwick",  "verified": False, "profile_image_path": None},
    
    {"name": "The New York Times", "slug": "ny_times", "verified": True, "profile_image_path": os.path.join(BASE_DIR, "news-profile-images/ny_times_profile.jpg")},
    {"name": "Fox News",           "slug": "fox_news", "verified": True, "profile_image_path": os.path.join(BASE_DIR, "news-profile-images/fox_news_profile.png")},
    {"name": "Reuters",            "slug": "reuters",  "verified": True, "profile_image_path": os.path.join(BASE_DIR, "news-profile-images/reuters_profile.jpg")},
]

POST_TEXTS = {
    "correct":   "The Spotify 2026 music genres distribution has just been released. Looks like Pop was more popular than Latin this year!",
    "incorrect": "The Spotify 2026 music genres distribution has just been released. Looks like Latin was more popular than Pop this year!",
}

POST_TIME = "Today at 2:43 PM"

REACTION_DEFS = {
    "like":  ("👍", "#1877f2"),
    "love":  ("❤️", "#f33e58"),
    "haha":  ("😆", "#f7b928"),
    "wow":   ("😮", "#f7b928"),
    "sad":   ("😢", "#f7b928"),
    "angry": ("😡", "#e9710f"),
}
REACTIONS = {k: 0 for k in REACTION_DEFS}
COMMENT_COUNT = 0
SHARE_COUNT   = 0



for label, post_text in POST_TEXTS.items():
    for profile in PROFILES:
        profile_slug = profile["slug"].lower().replace(" ", "_")
        suffix = "c" if label == "correct" else "i"

        for i in range(1, 101):
            POST_IMAGE_PATH = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_visualizations/pop_23_5_latin_11/spotify_genre_pie_chart_{i:03d}.png")
            output_file = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_plot_posts/baselines/{label}/html/news/{i:03d}_{profile_slug}_{suffix}.html")

            os.makedirs(os.path.dirname(output_file), exist_ok=True)  # creates folder in case it doesn't exist already

            html_content = generate_facebook_post(
                profile_name=profile["name"],
                post_text=post_text,
                post_time=POST_TIME,
                reactions=REACTIONS,
                comment_count=COMMENT_COUNT,
                share_count=SHARE_COUNT,
                post_image_path=POST_IMAGE_PATH,
                output_file=output_file,
                verified=profile["verified"],
                profile_image_path=profile["profile_image_path"],
            )
            display_facebook_post(html_content)

# %% [markdown]
# # For benchmarking
# **Important**: I used image 001 from *f"spotify_pie_plot/pie_visualizations/pop_23_5_latin_11/spotify_genre_pie_chart_001.png"* stand 14-04 to use as base for the benchmarks, meaning alwaysthe same visualization was included! Nothng else waa changed in the post except for the following three examples used for benchmarking
#
# 1) normal user - baseline (no metrics)
# 2) authority with verifciation - baseline (no metrics)
# 3) normal user - with all metrics incorporated

# %% [markdown]
# ## 1) baseline - gender neutral user
#
# Already created above

# %% [markdown]
# ## 2) baseline - ny times - fox news - reuters with verification

# %%
import importlib
import post_generator_all_visible_emojis

importlib.reload(post_generator_all_visible_emojis)

from post_generator_all_visible_emojis import generate_facebook_post, display_facebook_post

from post_generator_all_visible_emojis import generate_facebook_post, display_facebook_post

PROFILE_NAME = "Reuters" # "The New York Times" # "Fox News" 
#POST_TEXT = "The Spotify 2026 music genres distribution has just been released. Looks like Latin was more popular than Pop this year!" #incorrect text
POST_TEXT = "The Spotify 2026 music genres distribution has just been released. Looks like Pop was more popular than Latin this year!" #correct text
POST_TIME = "Today at 2:43 PM"
VERIFIED = True  # Set to True to show verified badge

PROFILE_IMAGE_PATH = "reuters_profile.jpg"# "ny_times_profile.jpg" #"fox_news_profile.png" # None

# missing endearing emoji!
REACTION_DEFS = {
    "like":  ("👍", "#1877f2"),
    "love":  ("❤️", "#f33e58"),
    "haha":  ("😆", "#f7b928"),
    "wow":   ("😮", "#f7b928"),
    "sad":   ("😢", "#f7b928"),
    "angry": ("😡", "#e9710f"),
}

REACTIONS = {
    "like":  0,
    "love":  0,
    "haha":  0,
    "wow":   0,
    "sad":   0,
    "angry": 0,
}
COMMENT_COUNT = 0
SHARE_COUNT   = 0



for i in range(1, 2):
    POST_IMAGE_PATH = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_visualizations/pop_23_5_latin_11/spotify_genre_pie_chart_{i:03d}.png")

    # Correct claim files
    #output_file = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_plot_posts/for_benchmarking/correct/html/ny_times_baseline_{i:03d}_c.html")
    #output_file = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_plot_posts/for_benchmarking/correct/html/fox_news_baseline_{i:03d}_c.html")
    output_file = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_plot_posts/for_benchmarking/correct/html/reuters_baseline_{i:03d}_c.html")

    # Incorrect claim files
    #output_file = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_plot_posts/for_benchmarking/incorrect/html/fox_news_baseline_{i:03d}_i.html")
    #output_file = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_plot_posts/for_benchmarking/incorrect/html/ny_times_baseline_{i:03d}_i.html")
    #output_file = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_plot_posts/for_benchmarking/incorrect/html/reuters_baseline_{i:03d}_i.html")
    
    html_content = generate_facebook_post(
        profile_name=PROFILE_NAME,
        post_text=POST_TEXT,
        post_time=POST_TIME,
        reactions=REACTIONS,
        comment_count=COMMENT_COUNT,
        share_count=SHARE_COUNT,
        post_image_path=POST_IMAGE_PATH,
        output_file=output_file,
        verified=VERIFIED,
        profile_image_path=PROFILE_IMAGE_PATH,
    )
    display_facebook_post(html_content)

# %% [markdown]
# ## 3) with all metrics - gender neutral user - artifially balanced reactions
# Posts were generated under two reaction conditions: uniform, in which all reaction types were set equally, and realistic, in which reactions were distributed using log-scaled weights to approximate empirical engagement patterns on social media.
#
# **correct**:
# - 10 - 100 versions of this post, each with different visualizations but with 10 of each engagement metric (10 likes, 10 hearts, 10 sad faces, ... 10 comments, etc)
# - 100 - 100 versions of this post, each with different visualizations but with 100 of each engagement metric (100 likes, 100 hearts, 100 sad faces, ... 100 comments, etc)
# - ...
#
# **incorrect**
# - 10 - 100 versions of this post, each with different visualizations but with 10 of each engagement metric (10 likes, 10 hearts, 10 sad faces, ... 10 comments, etc)
# - 100 - 100 versions of this post, each with different visualizations but with 100 of each engagement metric (100 likes, 100 hearts, 100 sad faces, ... 100 comments, etc)
# - ...

# %%
import importlib
import post_generator_all_visible_emojis
importlib.reload(post_generator_all_visible_emojis)
from post_generator_all_visible_emojis import generate_facebook_post, display_facebook_post

PROFILE_NAME = "Remy Ashford"
POST_TIME = "Today at 2:43 PM"
VERIFIED = False
PROFILE_IMAGE_PATH = None

REACTION_VALUES = [10, 100, 1000, 10000, 100000, 1000000]

VARIANTS = {
    "incorrect": "The Spotify 2026 music genres distribution has just been released. Looks like Latin was more popular than Pop this year!",
    "correct": "The Spotify 2026 music genres distribution has just been released. Looks like Pop was more popular than Latin this year!",
}

SUFFIX = {"incorrect": "i", "correct": "c"}

for scale_value in REACTION_VALUES:
    REACTIONS = {
        "like":  scale_value,
        "love":  scale_value,
        "haha":  scale_value,
        "wow":   scale_value,
        "sad":   scale_value,
        "angry": scale_value,
    }
    COMMENT_COUNT = scale_value
    SHARE_COUNT = scale_value

    for variant, post_text in VARIANTS.items():
        for i in range(1, 101):
            POST_IMAGE_PATH = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_visualizations/pop_23_5_latin_11/spotify_genre_pie_chart_{i:03d}.png")
           output_file = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_plot_posts/metrics/remy-ashford/{variant}/html/uniform/{scale_value}/{i:03d}_remy_ashford_{SUFFIX[variant]}.html")

            os.makedirs(os.path.dirname(output_file), exist_ok=True)

            html_content = generate_facebook_post(
                profile_name=PROFILE_NAME,
                post_text=post_text,
                post_time=POST_TIME,
                reactions=REACTIONS,
                comment_count=COMMENT_COUNT,
                share_count=SHARE_COUNT,
                post_image_path=POST_IMAGE_PATH,
                output_file=output_file,
                verified=VERIFIED,
                profile_image_path=PROFILE_IMAGE_PATH,
            )

    print(f"✅ Generated scale value: {scale_value}")

print("\n✅ All metric variants complete.")
'''

# %% [markdown]
# # 4) metrics - more realistic -  X total across all reaction types (likes + loves + hahas etc. combined), x being the log numebr so 10, 100, 1000, etc.
# Posts were generated under two reaction conditions: uniform, in which all reaction types were set equally, and realistic, in which reactions were distributed using log-scaled weights to approximate empirical engagement patterns on social media.
#
# With uniform reactions, every post at scale_value=1000 showed exactly 1000 likes, 1000 loves, 1000 hahas etc. — which is something that essentially never occurs on real Facebook and could itself be a signal to the VLM that something artificial is happening. The realistic condition removes that artificiality while keeping scale_value as a clean, interpretable independent variable representing **total engagement volume**.
#
# **Why Jitter Matters**
# The core problem without jitterWithout jitter, every image index at a given scale_value would produce identical reaction counts. For example, at scale_value=1000 every single one of your 100 images would show:

# %% [markdown]
# - Emoji order is always like, love, haha, wow, sad, angry — fixed by the change in the .py file
# - Values vary across images because shares are shuffled using seed=i — so image 001 always gets the same distribution but different from image 002
# - Total reactions always sum to approximately scale_value — Interpretation 1
# - Files land in realistic/ keeping them separate from your uniform/ condition
# - Reproducible — rerunning will generate identical files

# %%
import importlib
import math
import random
import os
import post_generator_all_visible_emojis
importlib.reload(post_generator_all_visible_emojis)
from post_generator_all_visible_emojis import generate_facebook_post, display_facebook_post

PROFILE_NAME = "Remy Ashford"
POST_TIME = "Today at 2:43 PM"
VERIFIED = False
PROFILE_IMAGE_PATH = None
REACTION_VALUES = [10, 100, 1000, 10000, 100000, 1000000] # log scale
VARIANTS = {
    "incorrect": "The Spotify 2026 music genres distribution has just been released. Looks like Latin was more popular than Pop this year!",
    "correct": "The Spotify 2026 music genres distribution has just been released. Looks like Pop was more popular than Latin this year!",
}
SUFFIX = {"incorrect": "i", "correct": "c"}

REACTION_TYPES = ["like", "love", "haha", "wow", "sad", "angry"]

def make_log_reactions(scale_value, jitter=0.10, seed=None):
    rng = random.Random(seed)
    n = len(REACTION_TYPES)
    
    log_weights = [math.log(n + 1 - i) for i in range(n)]
    total_weight = sum(log_weights)
    shares = [w / total_weight for w in log_weights]
    
    # Shuffle the shares, not the reaction types
    rng.shuffle(shares)
    
    reactions = {}
    for emoji, share in zip(REACTION_TYPES, shares):
        base = scale_value * share
        factor = 1 + rng.uniform(-jitter, jitter)
        reactions[emoji] = max(1, round(base * factor))
    return reactions

for scale_value in REACTION_VALUES:
    for variant, post_text in VARIANTS.items():
        for i in range(1, 101):
            REACTIONS = make_log_reactions(scale_value, jitter=0.10, seed=i)
            COMMENT_COUNT = max(1, round(scale_value * 0.08))
            SHARE_COUNT   = max(1, round(scale_value * 0.04))

            POST_IMAGE_PATH = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_visualizations/pop_23_5_latin_11/spotify_genre_pie_chart_{i:03d}.png")
            output_file = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_plot_posts/metrics/remy-ashford/{variant}/html/realistic/{scale_value}/{i:03d}_remy_ashford_{SUFFIX[variant]}.html")

            os.makedirs(os.path.dirname(output_file), exist_ok=True)
            html_content = generate_facebook_post(
                profile_name=PROFILE_NAME,
                post_text=post_text,
                post_time=POST_TIME,
                reactions=REACTIONS,
                comment_count=COMMENT_COUNT,
                share_count=SHARE_COUNT,
                post_image_path=POST_IMAGE_PATH,
                output_file=output_file,
                verified=VERIFIED,
                profile_image_path=PROFILE_IMAGE_PATH,
            )
    print(f"✅ Generated scale value: {scale_value}")
print("\n✅ All metric variants complete.")

# %%
import shutil
import os
from pathlib import Path

BASE_DIR = Path(os.getcwd()).parent

folders = {
    "correct_realistic": BASE_DIR / "spotify_pie_plot/pie_plot_posts/metrics/remy-ashford/correct/realistic/PNGs",
    "incorrect_realistic": BASE_DIR / "spotify_pie_plot/pie_plot_posts/metrics/remy-ashford/incorrect/realistic/PNGs",
}

for variant, folder_path in folders.items():
    zip_name = str(folder_path.parent / variant)  # saves as correct.zip / incorrect.zip inside their own folder
    shutil.make_archive(zip_name, 'zip', folder_path)
    print(f"✅ Zipped: {zip_name}.zip")

# %%
"""
# HERE ANGRY ALWAYS HAS THE LOWEST VALUE FOR REACTIONS, IT IS A DESCENDING  SO THERE ARE ALWAYS THE MOST LIKES, THEN SLIGHTLY LESS LOVE, THEN HAHA, AND SO ON, THIS CAN BE REUSED WHEN INVESTIGATING POSITIVE VS NEGATIVE EMOTION PREDOMINANCE
# direct consequence of the log weight formula — angry is always last in the list so it always gets log(2), the smallest weight, every single time regardless of scale_value.
#This brings you back to the valence problem we discussed earlier. Even though you are deferring valence as a variable to future work, your current realistic condition has an implicit assumption baked in: negative emotions are always minorities. This is worth acknowledging explicitly in your thesis, something like:
#"The realistic condition assigns reaction counts using log-scaled weights ordered by typical engagement frequency on social media, in which positive reactions such as like and love predominate. As a consequence, negative reactions such as sad and angry are consistently underrepresented relative to positive ones. Future work could manipulate this valence distribution as an independent variable."
#This turns a potential weakness into a transparent methodological choice — you are not ignoring it, you are naming it and deferring it deliberately.

import importlib
import math
import random
import os
import post_generator_all_visible_emojis
importlib.reload(post_generator_all_visible_emojis)
from post_generator_all_visible_emojis import generate_facebook_post, display_facebook_post

PROFILE_NAME = "Remy Ashford"
POST_TIME = "Today at 2:43 PM"
VERIFIED = False
PROFILE_IMAGE_PATH = None
REACTION_VALUES = [10, 100, 1000, 10000, 100000, 1000000]
VARIANTS = {
    "incorrect": "The Spotify 2026 music genres distribution has just been released. Looks like Latin was more popular than Pop this year!",
    "correct": "The Spotify 2026 music genres distribution has just been released. Looks like Pop was more popular than Latin this year!",
}
SUFFIX = {"incorrect": "i", "correct": "c"}

REACTION_TYPES = ["like", "love", "haha", "wow", "sad", "angry"]

def make_log_reactions(scale_value, jitter=0.10, seed=None):
    rng = random.Random(seed)
    n = len(REACTION_TYPES)
    log_weights = [math.log(n + 1 - i) for i in range(n)]
    total_weight = sum(log_weights)
    shares = [w / total_weight for w in log_weights]
    reactions = {}
    for emoji, share in zip(REACTION_TYPES, shares):
        base = scale_value * share
        factor = 1 + rng.uniform(-jitter, jitter)
        reactions[emoji] = max(1, round(base * factor))
    return reactions

for scale_value in REACTION_VALUES:
    for variant, post_text in VARIANTS.items():
        for i in range(1, 101):
            REACTIONS = make_log_reactions(scale_value, jitter=0.10, seed=i)
            COMMENT_COUNT = max(1, round(scale_value * 0.08))
            SHARE_COUNT   = max(1, round(scale_value * 0.04))

            POST_IMAGE_PATH = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_visualizations/pop_23_5_latin_11/spotify_genre_pie_chart_{i:03d}.png")
            output_file = os.path.join(BASE_DIR, f"spotify_pie_plot/pie_plot_posts/metrics/remy-ashford/{variant}/html/realistic/{scale_value}/{i:03d}_remy_ashford_{SUFFIX[variant]}.html")

            os.makedirs(os.path.dirname(output_file), exist_ok=True)
            html_content = generate_facebook_post(
                profile_name=PROFILE_NAME,
                post_text=post_text,
                post_time=POST_TIME,
                reactions=REACTIONS,
                comment_count=COMMENT_COUNT,
                share_count=SHARE_COUNT,
                post_image_path=POST_IMAGE_PATH,
                output_file=output_file,
                verified=VERIFIED,
                profile_image_path=PROFILE_IMAGE_PATH,
            )
    print(f"✅ Generated scale value: {scale_value}")
print("\n✅ All metric variants complete.")
"""
