# %% [markdown]
# # Qwen3-VL-4B — Authority x engagement grid (metrics/realistic)
#
# Both posts make the **same, correct** claim. One is from **"Dr. Remy Ashford" (verified)**, the
# other from plain **"Remy Ashford"**. Engagement is varied independently on each side across the
# study's seven levels (0, 10, 100, 1K, 10K, 100K, 1M), giving a 7x7 grid.
#
# | region | cells | question |
# |---|---|---|
# | diagonal (equal engagement) | 7 | does the authority preference survive as popularity rises? |
# | conflict (Dr. has fewer) | 21 | how much popularity outweighs a "Dr."? |
# | aligned (Dr. has more) | 21 | do the cues saturate, and is the effect symmetric? |
#
# Cells run **diagonal -> conflict -> aligned**, most informative first. The run resumes from a
# partial output file, so it can be stopped at any point and still give a complete, analysable
# design.
#
# The no-authority control already exists: the off-diagonal cells of
# `e1_results_metrics_correct_vs_correct_paired.json` are the same engagement contrasts between two
# plain posts. The (0, 0) cell reproduces Stage 1's `pure_authority_both_correct` pairing exactly,
# including its A/B slot assignment.

# %%
import sys, subprocess

subprocess.run([sys.executable, "-m", "pip", "uninstall", "torchaudio", "-y"])

subprocess.run([sys.executable, "-m", "pip", "install",
    "torch==2.6.0", "torchvision==0.21.0",
    "--index-url", "https://download.pytorch.org/whl/cu124",
    "--user", "-q"], check=True)

subprocess.run([sys.executable, "-m", "pip", "install",
    "git+https://github.com/huggingface/transformers",
    "accelerate",
    "--user", "-q"], check=True)

subprocess.run([sys.executable, "-m", "pip", "install",
    "tokenizers>=0.22.0,<=0.23.0",
    "--user", "-q"], check=True)

print("✅ Done — restart the kernel now")
# Out:
# WARNING: Skipping torchaudio as it is not installed.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 5.16.0.dev0 requires tokenizers<=0.23.0,>=0.22.0, but you have tokenizers 0.23.1 which is incompatible.
# ✅ Done — restart the kernel now

# %% [markdown]
# Restart the kernel after running the setup cell above.

# %%
# !nvidia-smi
# Out:
# Fri Aug 21 15:38:52 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.127.08             Driver Version: 550.127.08     CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA H100 80GB HBM3          On  |   00000000:AF:00.0 Off |                    0 |
# | N/A   64C    P0            515W /  700W |   68469MiB /  81559MiB |     54%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
import sys
from huggingface_hub import whoami
try:
    whoami()
except Exception:
    raise RuntimeError("Not logged in to Hugging Face -- run utils/huggingface_login.ipynb once first.")

from pathlib import Path
ROOT_DIR = Path().resolve().parents[2]
sys.path.insert(0, str(ROOT_DIR / "experiments/e1"))

import torch
from transformers import Qwen3VLForConditionalGeneration, AutoProcessor

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

processor = AutoProcessor.from_pretrained("Qwen/Qwen3-VL-4B-Instruct")
model = Qwen3VLForConditionalGeneration.from_pretrained(
    "Qwen/Qwen3-VL-4B-Instruct",
    torch_dtype=torch.bfloat16,
    device_map="auto"
)
print("✅ Loaded successfully")
# Out:
# Using device: cuda
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/713 [00:00<?, ?it/s]
# ✅ Loaded successfully

# %%
import torch
free, total = torch.cuda.mem_get_info(0)          # actual device-wide free memory
print(torch.cuda.get_device_name(0))
print(f"VRAM total     : {total/1e9:.1f} GB")
print(f"VRAM free      : {free/1e9:.1f} GB")       # across ALL processes
print(f"this process   : {torch.cuda.memory_reserved(0)/1e9:.1f} GB reserved")
# Out:
# NVIDIA H100 80GB HBM3
# VRAM total     : 84.9 GB
# VRAM free      : 3.7 GB
# this process   : 8.9 GB reserved

# %%
from e1_utils.inference_qwen import run_inference_qwen

# %%
INFERENCE_FN = run_inference_qwen

# %% [markdown]
# ## Configuration — asserts every stimulus directory before running

# %%
from pathlib import Path
import json

from e1_utils.e1_optimized import LIKE_PROMPT_PAIR
from e1_utils.e1_profile_grid import (run_e1_profile_grid_paired, analyse_profile_grid,
                                      build_grid_cells)

EXPERIMENT_DIR = Path().resolve().parent          # experiments/e1_authority_grid/
OUTPUT_DIR = Path().resolve() / "outputs"
SEED = 42

# the same 100 posts as the main study and the Stage 1 authority run
selected_numbers = json.loads(
    (EXPERIMENT_DIR / "selected_images.json").read_text())["selected_numbers"]

DR_METRICS     = ROOT_DIR / "benchmarking/correct/dr-remy-ashford/metrics/realistic"
PLAIN_METRICS  = ROOT_DIR / "benchmarking/correct/remy-ashford/metrics/realistic"
DR_BASELINE    = ROOT_DIR / "benchmarking/correct/dr-remy-ashford"       # scale 0
PLAIN_BASELINE = ROOT_DIR / "benchmarking/correct/remy-ashford"          # scale 0

CELLS = build_grid_cells()

# fail here, not 4900 trials in
for d in (DR_METRICS, PLAIN_METRICS, DR_BASELINE, PLAIN_BASELINE):
    assert d.is_dir(), f"missing stimulus dir: {d}"
probe = selected_numbers[0]
for dr_s, pl_s, _ in CELLS:
    for base, bl, s in ((DR_METRICS, DR_BASELINE, dr_s), (PLAIN_METRICS, PLAIN_BASELINE, pl_s)):
        d = bl if s == 0 else base / str(s)
        assert (d / f"{probe}_remy_ashford_c.png").exists(), f"missing stimulus: {d}"

print(f"{len(selected_numbers)} posts x {len(CELLS)} cells "
      f"= {len(selected_numbers) * len(CELLS)} trials")
# Out:
# 100 posts x 49 cells = 4900 trials

# %% [markdown]
# ## Run the grid (diagonal → conflict → aligned; resumable)

# %%
import time
start = time.time()

run_e1_profile_grid_paired(
    selected_numbers,
    dr_metrics_base=DR_METRICS, plain_metrics_base=PLAIN_METRICS,
    dr_baseline_dir=DR_BASELINE, plain_baseline_dir=PLAIN_BASELINE,
    model=model, processor=processor, device=device,
    output_dir=OUTPUT_DIR, seed=SEED, prompt=LIKE_PROMPT_PAIR,
    output_filename="e1_results_authority_grid_metrics.json",
    inference_fn=INFERENCE_FN, cells=CELLS)

elapsed = time.time() - start
print(f"\n⏱ Total runtime: {int(elapsed // 3600)}h "
      f"{int(elapsed % 3600 // 60)}m {int(elapsed % 60)}s")
# Out:
# Grid: 49 cells x 100 posts = 4900 trials
# ✅ 001_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 002_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 003_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 004_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 005_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 006_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 007_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 008_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 009_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 010_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 011_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 012_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 013_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 014_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 015_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 016_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 017_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 018_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 019_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 020_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 021_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 022_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 023_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 024_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 025_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 026_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 027_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 028_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 029_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 030_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 031_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 032_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 033_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 034_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 035_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 036_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 037_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 038_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 039_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 040_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 041_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 042_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 043_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 044_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 045_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 046_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 047_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 048_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 049_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 050_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 051_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 052_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 053_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 054_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 055_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 056_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 057_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 058_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 059_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 060_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 061_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 062_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 063_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 064_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 065_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 066_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 067_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 068_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 069_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 070_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 071_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 072_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 073_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 074_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 075_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 076_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 077_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 078_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 079_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 080_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 081_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 082_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 083_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 084_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 085_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 086_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 087_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 088_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 089_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 090_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 091_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 092_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 093_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 094_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 095_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 096_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 097_dr0_vs_plain0 [diagonal] → dr (answered A)
# ✅ 098_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 099_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 100_dr0_vs_plain0 [diagonal] → dr (answered B)
# ✅ 001_dr10_vs_plain10 [diagonal] → dr (answered A)
# ✅
dr1000000_vs_plain10000 [aligned] → dr (answered A)
# ✅ 099_dr1000000_vs_plain10000 [aligned] → dr (answered B)
# ✅ 100_dr1000000_vs_plain10000 [aligned] → dr (answered A)
# ✅ 001_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 002_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 003_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 004_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 005_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 006_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 007_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 008_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 009_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 010_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 011_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 012_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 013_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 014_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 015_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 016_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 017_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 018_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 019_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 020_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 021_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 022_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 023_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 024_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 025_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 026_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 027_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 028_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 029_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 030_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 031_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 032_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 033_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 034_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 035_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 036_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 037_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 038_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 039_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 040_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 041_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 042_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 043_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 044_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 045_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 046_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 047_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 048_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 049_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 050_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 051_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 052_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 053_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 054_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 055_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 056_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 057_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 058_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 059_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 060_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 061_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 062_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 063_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 064_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 065_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 066_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 067_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 068_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 069_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 070_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 071_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 072_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 073_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 074_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 075_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 076_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 077_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 078_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 079_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 080_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 081_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 082_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 083_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 084_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 085_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 086_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 087_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 088_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 089_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 090_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 091_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 092_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 093_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 094_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 095_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 096_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 097_dr1000000_vs_plain100000 [aligned] → dr (answered A)
# ✅ 098_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 099_dr1000000_vs_plain100000 [aligned] → dr (answered B)
# ✅ 100_dr1000000_vs_plain100000 [aligned] → dr (answered B)
#
# ✅ Done. Results saved to /home/jovyan/conformity-llms-facebook-posts/experiments/e1_authority_grid/qwen3-vl-4b/outputs/e1_results_authority_grid_metrics.json
#
# ⏱ Total runtime: 0h 46m 10s

# %% [markdown]
# ## Results — read the position split, not just the aggregate

# %%
analyse_profile_grid(OUTPUT_DIR, "e1_results_authority_grid_metrics.json")
# Out:
# === e1_results_authority_grid_metrics.json ===
#   n=4900 valid=4900 invalid=0
#
#   [diagonal]  n=700
#     chose the 'Dr.' post : 100.0%   (it sat in slot A 51.7% of trials)
#     answered 'A'         :  51.7%
#       'Dr.' in slot A ( 362 trials) → chose it 100.0%
#       'Dr.' in slot B ( 338 trials) → chose it 100.0%
#
#   [conflict]  n=2100
#     chose the 'Dr.' post :  12.1%   (it sat in slot A 52.0% of trials)
#     answered 'A'         :  42.6%
#       'Dr.' in slot A (1091 trials) → chose it   6.4%
#       'Dr.' in slot B (1009 trials) → chose it  18.2%
#
#   [aligned]  n=2100
#     chose the 'Dr.' post :  98.9%   (it sat in slot A 52.0% of trials)
#     answered 'A'         :  50.8%
#       'Dr.' in slot A (1091 trials) → chose it  97.8%
#       'Dr.' in slot B (1009 trials) → chose it 100.0%
#
#   [exchange rate]  Dr. at 0 engagement vs plain post at:
#            0 likes → chose 'Dr.' 100.0%  (n=100)
#           10 likes → chose 'Dr.'   5.0%  (n=100)  ← crossover
#          100 likes → chose 'Dr.'   5.0%  (n=100)  ← crossover
#        1,000 likes → chose 'Dr.'   1.0%  (n=100)  ← crossover
#       10,000 likes → chose 'Dr.'   2.0%  (n=100)  ← crossover
#      100,000 likes → chose 'Dr.'   0.0%  (n=100)  ← crossover
#     1,000,000 likes → chose 'Dr.'   0.0%  (n=100)  ← crossover
# {'diagonal': {'n': 700, 'pct_dr': 100.0, 'a_rate': 51.714285714285715},
#  'conflict': {'n': 2100,
#   'pct_dr': 12.095238095238095,
#   'a_rate': 42.61904761904762},
#  'aligned': {'n': 2100,
#   'pct_dr': 98.85714285714286,
#   'a_rate': 50.8095238095238}}
