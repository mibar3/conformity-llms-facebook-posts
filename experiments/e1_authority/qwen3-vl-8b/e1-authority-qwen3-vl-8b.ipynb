# %% [markdown]
# # Qwen3-VL-8B — Authority pilot, Stage 1 (baseline, 0 engagement)
#
# Does an authority cue in the poster's identity outrank factual correctness?
#
# Every pairing puts **one "Dr. Remy Ashford" post (verified badge) against one plain
# "Remy Ashford" post** — never Dr-vs-Dr. The two stimulus sets are identical apart from the
# profile name and badge: same 100 pie charts, same claim texts, no engagement shown.
#
# | # | Post A | Post B | tests |
# |---|---|---|---|
# | 1 | Dr. + **incorrect** | plain + **correct** | authority vs correctness — the headline |
# | 2 | Dr. + correct | plain + correct | pure authority (correctness held equal) |
# | 3 | Dr. + incorrect | plain + incorrect | pure authority (both wrong) |
# | 4 | Dr. + correct | plain + incorrect | both cues agree — sanity check |
#
# Pairings 2 and 3 make 1 interpretable: without them, choosing the Dr. post cannot be
# distinguished from a blanket preference for "Dr." regardless of what the post claims.
#
# **Read the A-rate before the preference.** Several models here answer a fixed slot on 96–100% of
# trials and score ~50% mechanically (Section 5.1). `analyse_profile_paired` prints the A-rate and
# declines to endorse a preference when one slot dominates. It runs after inference, reads only the
# saved JSON, and cannot influence any answer.
#
# Run top to bottom; restart the kernel after the setup cell as usual.
#
# *Caveat: "Dr." and the verified badge vary together, so a positive result identifies an authority
# bundle, not which cue did the work.*

# %%
import sys, subprocess

# 1. Uninstall torchaudio
subprocess.run([sys.executable, "-m", "pip", "uninstall", "torchaudio", "-y"])

# 2. Install PyTorch with CUDA 12.4
subprocess.run([sys.executable, "-m", "pip", "install",
    "torch==2.6.0", "torchvision==0.21.0",
    "--index-url", "https://download.pytorch.org/whl/cu124",
    "--user", "-q"], check=True)

# 3. Install latest transformers and accelerate (allowing pip to pull compatible tokenizers naturally)
subprocess.run([sys.executable, "-m", "pip", "install",
    "git+https://github.com/huggingface/transformers",
    "accelerate",
    "--user", "-q"], check=True)

print("✅ Installation complete — restart the kernel now")
# Out:
# WARNING: Skipping torchaudio as it is not installed.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 5.16.0.dev0 requires tokenizers<=0.23.0,>=0.22.0, but you have tokenizers 0.23.1 which is incompatible.
# ✅ Done — restart the kernel now

# %% [markdown]
# Restart the kernel after running the setup cell above.

# %%
# !nvidia-smi
# Out:
# Fri Aug 21 14:02:57 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.127.08             Driver Version: 550.127.08     CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA H100 80GB HBM3          On  |   00000000:AF:00.0 Off |                    0 |
# | N/A   34C    P0             81W /  700W |       1MiB /  81559MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import sys
sys.path.append("/home/jovyan")
from config_hf_token import HF_TOKEN
from huggingface_hub import login
login(token=HF_TOKEN)

from pathlib import Path
ROOT_DIR = Path().resolve().parents[2]
sys.path.insert(0, str(ROOT_DIR / "experiments/e1"))

import torch
from transformers import Qwen3VLForConditionalGeneration, AutoProcessor

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

processor = AutoProcessor.from_pretrained("Qwen/Qwen3-VL-8B-Instruct")
model = Qwen3VLForConditionalGeneration.from_pretrained(
    "Qwen/Qwen3-VL-8B-Instruct",
    torch_dtype=torch.bfloat16,
    device_map="auto"
)
print("✅ Loaded successfully")
# Out:
# Using device: cuda
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/750 [00:00<?, ?it/s]
# ✅ Loaded successfully

# %%
import torch
free, total = torch.cuda.mem_get_info(0)          # actual device-wide free memory
print(torch.cuda.get_device_name(0))
print(f"VRAM total     : {total/1e9:.1f} GB")
print(f"VRAM free      : {free/1e9:.1f} GB")       # across ALL processes
print(f"this process   : {torch.cuda.memory_reserved(0)/1e9:.1f} GB reserved")
# Out:
# NVIDIA H100 80GB HBM3
# VRAM total     : 84.9 GB
# VRAM free      : 65.8 GB
# this process   : 18.4 GB reserved

# %%
from e1_utils.inference_qwen import run_inference_qwen

# %%
from e1_utils.sampling import build_paired_sample
from e1_utils.e1_optimized import LIKE_PROMPT_PAIR
from e1_utils.e1_profile import run_e1_profile_paired, analyse_profile_paired

EXPERIMENT_DIR = Path().resolve().parent          # experiments/e1_authority/
OUTPUT_DIR = Path().resolve() / "outputs"
SEED = 42
SAMPLE_SIZE = 100                                  # selected_images.json copied from experiments/e1/

DR_C    = ROOT_DIR / "benchmarking/correct/dr-remy-ashford"
DR_I    = ROOT_DIR / "benchmarking/incorrect/dr-remy-ashford"
PLAIN_C = ROOT_DIR / "benchmarking/correct/remy-ashford"
PLAIN_I = ROOT_DIR / "benchmarking/incorrect/remy-ashford"
for d in (DR_C, DR_I, PLAIN_C, PLAIN_I):
    assert d.is_dir(), f"missing stimulus dir: {d}"

all_images = build_paired_sample(PLAIN_C, PLAIN_I, SEED, SAMPLE_SIZE, EXPERIMENT_DIR)
selected_numbers = [n.replace("_correct", "") for n, _ in all_images if "_correct" in n]
print(f"{len(selected_numbers)} posts")

PAIRINGS = {
    "1_authority_vs_correctness":      ({"dir": DR_I, "variant": "incorrect", "label": "dr"},
                                        {"dir": PLAIN_C, "variant": "correct",   "label": "plain"}),
    "2_pure_authority_both_correct":   ({"dir": DR_C, "variant": "correct",   "label": "dr"},
                                        {"dir": PLAIN_C, "variant": "correct",   "label": "plain"}),
    "3_pure_authority_both_incorrect": ({"dir": DR_I, "variant": "incorrect", "label": "dr"},
                                        {"dir": PLAIN_I, "variant": "incorrect", "label": "plain"}),
    "4_both_cues_agree":               ({"dir": DR_C, "variant": "correct",   "label": "dr"},
                                        {"dir": PLAIN_I, "variant": "incorrect", "label": "plain"}),
}
# Out:
# 📋 Loading existing selection from /home/jovyan/conformity-llms-facebook-posts/experiments/e1_authority/selected_images.json
# ✅ All selected numbers verified in both correct and incorrect folders.
# Selected 100 pairs → 200 images total
# 100 posts

# %%
INFERENCE_FN = run_inference_qwen

# %% [markdown]
# ## Run the four pairings

# %%
for name, (side_a, side_b) in PAIRINGS.items():
    print(f"\n{'='*70}\n{name}\n{'='*70}")
    run_e1_profile_paired(selected_numbers, side_a, side_b, model, processor, device,
                          OUTPUT_DIR, SEED, prompt=LIKE_PROMPT_PAIR,
                          output_filename=f"e1_results_authority_{name}.json",
                          inference_fn=INFERENCE_FN)
# Out:
# ======================================================================
# 1_authority_vs_correctness
# ======================================================================
# 📋 Resuming — 100 pairs already processed.
#
# ✅ Done. Results saved to /home/jovyan/conformity-llms-facebook-posts/experiments/e1_authority/qwen3-vl-8b/outputs/e1_results_authority_1_authority_vs_correctness.json
#
# ======================================================================
# 2_pure_authority_both_correct
# ======================================================================
# 📋 Resuming — 17 pairs already processed.
# ✅ 018 → dr/correct (answered A)
# ✅ 019 → dr/correct (answered A)
# ✅ 020 → dr/correct (answered B)
# ✅ 021 → dr/correct (answered A)
# ✅ 022 → dr/correct (answered A)
# ✅ 023 → dr/correct (answered A)
# ✅ 024 → dr/correct (answered A)
# ✅ 025 → dr/correct (answered A)
# ✅ 026 → dr/correct (answered B)
# ✅ 027 → dr/correct (answered B)
# ✅ 028 → dr/correct (answered B)
# ✅ 029 → dr/correct (answered A)
# ✅ 030 → dr/correct (answered A)
# ✅ 031 → dr/correct (answered A)
# ✅ 032 → dr/correct (answered B)
# ✅ 033 → dr/correct (answered A)
# ✅ 034 → dr/correct (answered A)
# ✅ 035 → dr/correct (answered B)
# ✅ 036 → dr/correct (answered B)
# ✅ 037 → dr/correct (answered A)
# ✅ 038 → dr/correct (answered A)
# ✅ 039 → dr/correct (answered B)
# ✅ 040 → dr/correct (answered A)
# ✅ 041 → dr/correct (answered A)
# ✅ 042 → dr/correct (answered B)
# ✅ 043 → plain/correct (answered B)
# ✅ 044 → dr/correct (answered B)
# ✅ 045 → dr/correct (answered A)
# ✅ 046 → dr/correct (answered A)
# ✅ 047 → dr/correct (answered A)
# ✅ 048 → dr/correct (answered A)
# ✅ 049 → dr/correct (answered A)
# ✅ 050 → dr/correct (answered A)
# ✅ 051 → dr/correct (answered B)
# ✅ 052 → dr/correct (answered B)
# ✅ 053 → dr/correct (answered B)
# ✅ 054 → dr/correct (answered A)
# ✅ 055 → dr/correct (answered A)
# ✅ 056 → dr/correct (answered A)
# ✅ 057 → dr/correct (answered A)
# ✅ 058 → dr/correct (answered A)
# ✅ 059 → dr/correct (answered B)
# ✅ 060 → dr/correct (answered A)
# ✅ 061 → dr/correct (answered B)
# ✅ 062 → dr/correct (answered B)
# ✅ 063 → dr/correct (answered B)
# ✅ 064 → dr/correct (answered B)
# ✅ 065 → dr/correct (answered A)
# ✅ 066 → dr/correct (answered A)
# ✅ 067 → dr/correct (answered A)
# ✅ 068 → dr/correct (answered B)
# ✅ 069 → dr/correct (answered B)
# ✅ 070 → dr/correct (answered A)
# ✅ 071 → dr/correct (answered A)
# ✅ 072 → dr/correct (answered A)
# ✅ 073 → dr/correct (answered B)
# ✅ 074 → dr/correct (answered B)
# ✅ 075 → dr/correct (answered A)
# ✅ 076 → dr/correct (answered B)
# ✅ 077 → dr/correct (answered B)
# ✅ 078 → dr/correct (answered B)
# ✅ 079 → dr/correct (answered A)
# ✅ 080 → dr/correct (answered B)
# ✅ 081 → dr/correct (answered A)
# ✅ 082 → dr/correct (answered B)
# ✅ 083 → dr/correct (answered B)
# ✅ 084 → dr/correct (answered B)
# ✅ 085 → dr/correct (answered A)
# ✅ 086 → dr/correct (answered B)
# ✅ 087 → dr/correct (answered B)
# ✅ 088 → dr/correct (answered B)
# ✅ 089 → dr/correct (answered A)
# ✅ 090 → dr/correct (answered A)
# ✅ 091 → dr/correct (answered A)
# ✅ 092 → dr/correct (answered A)
# ✅ 093 → dr/correct (answered B)
# ✅ 094 → dr/correct (answered B)
# ✅ 095 → dr/correct (answered A)
# ✅ 096 → dr/correct (answered A)
# ✅ 097 → dr/correct (answered A)
# ✅ 098 → dr/correct (answered B)
# ✅ 099 → dr/correct (answered B)
# ✅ 100 → dr/correct (answered B)
#
# ✅ Done. Results saved to /home/jovyan/conformity-llms-facebook-posts/experiments/e1_authority/qwen3-vl-8b/outputs/e1_results_authority_2_pure_authority_both_correct.json
#
# ======================================================================
# 3_pure_authority_both_incorrect
# ======================================================================
# ✅ 001 → dr/incorrect (answered A)
# ✅ 002 → dr/incorrect (answered A)
# ✅ 003 → dr/incorrect (answered A)
# ✅ 004 → dr/incorrect (answered B)
# ✅ 005 → dr/incorrect (answered A)
# ✅ 006 → dr/incorrect (answered B)
# ✅ 007 → dr/incorrect (answered A)
# ✅ 008 → dr/incorrect (answered A)
# ✅ 009 → dr/incorrect (answered A)
# ✅ 010 → dr/incorrect (answered B)
# ✅ 011 → dr/incorrect (answered B)
# ✅ 012 → dr/incorrect (answered B)
# ✅ 013 → dr/incorrect (answered A)
# ✅ 014 → dr/incorrect (answered B)
# ✅ 015 → dr/incorrect (answered A)
# ✅ 016 → dr/incorrect (answered B)
# ✅ 017 → dr/incorrect (answered A)
# ✅ 018 → dr/incorrect (answered A)
# ✅ 019 → dr/incorrect (answered A)
# ✅ 020 → dr/incorrect (answered B)
# ✅ 021 → dr/incorrect (answered A)
# ✅ 022 → dr/incorrect (answered A)
# ✅ 023 → dr/incorrect (answered A)
# ✅ 024 → dr/incorrect (answered A)
# ✅ 025 → dr/incorrect (answered A)
# ✅ 026 → dr/incorrect (answered B)
# ✅ 027 → dr/incorrect (answered B)
# ✅ 028 → dr/incorrect (answered B)
# ✅ 029 → dr/incorrect (answered A)
# ✅ 030 → dr/incorrect (answered A)
# ✅ 031 → dr/incorrect (answered A)
# ✅ 032 → dr/incorrect (answered B)
# ✅ 033 → dr/incorrect (answered A)
# ✅ 034 → dr/incorrect (answered A)
# ✅ 035 → dr/incorrect (answered B)
# ✅ 036 → dr/incorrect (answered B)
# ✅ 037 → dr/incorrect (answered A)
# ✅ 038 → dr/incorrect (answered A)
# ✅ 039 → dr/incorrect (answered B)
# ✅ 040 → dr/incorrect (answered A)
# ✅ 041 → dr/incorrect (answered A)
# ✅ 042 → dr/incorrect (answered B)
# ✅ 043 → plain/incorrect (answered B)
# ✅ 044 → dr/incorrect (answered B)
# ✅ 045 → dr/incorrect (answered A)
# ✅ 046 → dr/incorrect (answered A)
# ✅ 047 → dr/incorrect (answered A)
# ✅ 048 → dr/incorrect (answered A)
# ✅ 049 → dr/incorrect (answered A)
# ✅ 050 → dr/incorrect (answered A)
# ✅ 051 → dr/incorrect (answered B)
# ✅ 052 → dr/incorrect (answered B)
# ✅ 053 → dr/incorrect (answered B)
# ✅ 054 → dr/incorrect (answered A)
# ✅ 055 → dr/incorrect (answered A)
# ✅ 056 → dr/incorrect (answered A)
# ✅ 057 → dr/incorrect (answered A)
# ✅ 058 → dr/incorrect (answered A)
# ✅ 059 → dr/incorrect (answered B)
# ✅ 060 → dr/incorrect (answered A)
# ✅ 061 → dr/incorrect (answered B)
# ✅ 062 → dr/incorrect (answered B)
# ✅ 063 → dr/incorrect (answered B)
# ✅ 064 → dr/incorrect (answered B)
# ✅ 065 → dr/incorrect (answered A)
# ✅ 066 → dr/incorrect (answered A)
# ✅ 067 → dr/incorrect (answered A)
# ✅ 068 → dr/incorrect (answered B)
# ✅ 069 → dr/incorrect (answered B)
# ✅ 070 → dr/incorrect (answered A)
# ✅ 071 → dr/incorrect (answered A)
# ✅ 072 → dr/incorrect (answered A)
# ✅ 073 → dr/incorrect (answered B)
# ✅ 074 → dr/incorrect (answered B)
# ✅ 075 → dr/incorrect (answered A)
# ✅ 076 → dr/incorrect (answered B)
# ✅ 077 → dr/incorrect (answered B)
# ✅ 078 → dr/incorrect (answered B)
# ✅ 079 → dr/incorrect (answered A)
# ✅ 080 → dr/incorrect (answered B)
# ✅ 081 → dr/incorrect (answered A)
# ✅ 082 → dr/incorrect (answered B)
# ✅ 083 → dr/incorrect (answered B)
# ✅ 084 → dr/incorrect (answered B)
# ✅ 085 → dr/incorrect (answered A)
# ✅ 086 → dr/incorrect (answered B)
# ✅ 087 → dr/incorrect (answered B)
# ✅ 088 → dr/incorrect (answered B)
# ✅ 089 → dr/incorrect (answered A)
# ✅ 090 → dr/incorrect (answered A)
# ✅ 091 → dr/incorrect (answered A)
# ✅ 092 → dr/incorrect (answered A)
# ✅ 093 → dr/incorrect (answered B)
# ✅ 094 → dr/incorrect (answered B)
# ✅ 095 → dr/incorrect (answered A)
# ✅ 096 → dr/incorrect (answered A)
# ✅ 097 → dr/incorrect (answered A)
# ✅ 098 → dr/incorrect (answered B)
# ✅ 099 → dr/incorrect (answered B)
# ✅ 100 → dr/incorrect (answered B)
#
# ✅ Done. Results saved to /home/jovyan/conformity-llms-facebook-posts/experiments/e1_authority/qwen3-vl-8b/outputs/e1_results_authority_3_pure_authority_both_incorrect.json
#
# ======================================================================
# 4_both_cues_agree
# ======================================================================
# ✅ 001 → plain/incorrect (answered B)
# ✅ 002 → plain/incorrect (answered B)
# ✅ 003 → plain/incorrect (answered B)
# ✅ 004 → dr/correct (answered B)
# ✅ 005 → plain/incorrect (answered B)
# ✅ 006 → dr/correct (answered B)
# ✅ 007 → plain/incorrect (answered B)
# ✅ 008 → plain/incorrect (answered B)
# ✅ 009 → plain/incorrect (answered B)
# ✅ 010 → dr/correct (answered B)
# ✅ 011 → dr/correct (answered B)
# ✅ 012 → dr/correct (answered B)
# ✅ 013 → plain/incorrect (answered B)
# ✅ 014 → dr/correct (answered B)
# ✅ 015 → plain/incorrect (answered B)
# ✅ 016 → dr/correct (answered B)
# ✅ 017 → plain/incorrect (answered B)
# ✅ 018 → plain/incorrect (answered B)
# ✅ 019 → plain/incorrect (answered B)
# ✅ 020 → dr/correct (answered B)
# ✅ 021 → plain/incorrect (answered B)
# ✅ 022 → plain/incorrect (answered B)
# ✅ 023 → plain/incorrect (answered B)
# ✅ 024 → plain/incorrect (answered B)
# ✅ 025 → plain/incorrect (answered B)
# ✅ 026 → dr/correct (answered B)
# ✅ 027 → dr/correct (answered B)
# ✅ 028 → dr/correct (answered B)
# ✅ 029 → plain/incorrect (answered B)
# ✅ 030 → plain/incorrect (answered B)
# ✅ 031 → plain/incorrect (answered B)
# ✅ 032 → dr/correct (answered B)
# ✅ 033 → plain/incorrect (answered B)
# ✅ 034 → plain/incorrect (answered B)
# ✅ 035 → dr/correct (answered B)
# ✅ 036 → dr/correct (answered B)
# ✅ 037 → plain/incorrect (answered B)
# ✅ 038 → plain/incorrect (answered B)
# ✅ 039 → dr/correct (answered B)
# ✅ 040 → plain/incorrect (answered B)
# ✅ 041 → plain/incorrect (answered B)
# ✅ 042 → dr/correct (answered B)
# ✅ 043 → plain/incorrect (answered B)
# ✅ 044 → dr/correct (answered B)
# ✅ 045 → plain/incorrect (answered B)
# ✅ 046 → plain/incorrect (answered B)
# ✅ 047 → plain/incorrect (answered B)
# ✅ 048 → plain/incorrect (answered B)
# ✅ 049 → plain/incorrect (answered B)
# ✅ 050 → dr/correct (answered A)
# ✅ 051 → dr/correct (answered B)
# ✅ 052 → dr/correct (answered B)
# ✅ 053 → dr/correct (answered B)
# ✅ 054 → plain/incorrect (answered B)
# ✅ 055 → plain/incorrect (answered B)
# ✅ 056 → plain/incorrect (answered B)
# ✅ 057 → plain/incorrect (answered B)
# ✅ 058 → plain/incorrect (answered B)
# ✅ 059 → dr/correct (answered B)
# ✅ 060 → plain/incorrect (answered B)
# ✅ 061 → dr/correct (answered B)
# ✅ 062 → dr/correct (answered B)
# ✅ 063 → dr/correct (answered B)
# ✅ 064 → dr/correct (answered B)
# ✅ 065 → plain/incorrect (answered B)
# ✅ 066 → plain/incorrect (answered B)
# ✅ 067 → plain/incorrect (answered B)
# ✅ 068 → dr/correct (answered B)
# ✅ 069 → dr/correct (answered B)
# ✅ 070 → plain/incorrect (answered B)
# ✅ 071 → plain/incorrect (answered B)
# ✅ 072 → plain/incorrect (answered B)
# ✅ 073 → dr/correct (answered B)
# ✅ 074 → dr/correct (answered B)
# ✅ 075 → plain/incorrect (answered B)
# ✅ 076 → dr/correct (answered B)
# ✅ 077 → dr/correct (answered B)
# ✅ 078 → dr/correct (answered B)
# ✅ 079 → plain/incorrect (answered B)
# ✅ 080 → dr/correct (answered B)
# ✅ 081 → plain/incorrect (answered B)
# ✅ 082 → dr/correct (answered B)
# ✅ 083 → dr/correct (answered B)
# ✅ 084 → dr/correct (answered B)
# ✅ 085 → plain/incorrect (answered B)
# ✅ 086 → dr/correct (answered B)
# ✅ 087 → dr/correct (answered B)
# ✅ 088 → dr/correct (answered B)
# ✅ 089 → plain/incorrect (answered B)
# ✅ 090 → plain/incorrect (answered B)
# ✅ 091 → plain/incorrect (answered B)
# ✅ 092 → plain/incorrect (answered B)
# ✅ 093 → dr/correct (answered B)
# ✅ 094 → dr/correct (answered B)
# ✅ 095 → plain/incorrect (answered B)
# ✅ 096 → plain/incorrect (answered B)
# ✅ 097 → plain/incorrect (answered B)
# ✅ 098 → dr/correct (answered B)
# ✅ 099 → dr/correct (answered B)
# ✅ 100 → dr/correct (answered B)
#
# ✅ Done. Results saved to /home/jovyan/conformity-llms-facebook-posts/experiments/e1_authority/qwen3-vl-8b/outputs/e1_results_authority_4_both_cues_agree.json

# %% [markdown]
# ## Results — read the A-rate first

# %%
for name in PAIRINGS:
    analyse_profile_paired(OUTPUT_DIR, f"e1_results_authority_{name}.json")
# Out:
# === e1_results_authority_1_authority_vs_correctness.json ===
#   n=100 valid=100 invalid=0
#   chose the 'dr' post :  45.0%   (it sat in slot A 56.0% of trials)
#   chose the CORRECT post      :  55.0%
#   answered 'A'                :   3.0%
#   ⚠ POSITIONAL DEFAULT — the model answers one slot on 97.0% of trials.
#     Any preference above is an artifact of where each post happened to land, not a choice.
#     Do not report it as a profile or correctness effect.
#
# === e1_results_authority_2_pure_authority_both_correct.json ===
#   n=100 valid=100 invalid=0
#   chose the 'dr' post :  99.0%   (it sat in slot A 56.0% of trials)
#   (both sides correct — correctness is held constant, so any preference is pure profile)
#   answered 'A'                :  55.0%
#
# === e1_results_authority_3_pure_authority_both_incorrect.json ===
#   n=100 valid=100 invalid=0
#   chose the 'dr' post :  99.0%   (it sat in slot A 56.0% of trials)
#   (both sides incorrect — correctness is held constant, so any preference is pure profile)
#   answered 'A'                :  55.0%
#
# === e1_results_authority_4_both_cues_agree.json ===
#   n=100 valid=100 invalid=0
#   chose the 'dr' post :  45.0%   (it sat in slot A 56.0% of trials)
#   chose the CORRECT post      :  45.0%
#   answered 'A'                :   1.0%
#   ⚠ POSITIONAL DEFAULT — the model answers one slot on 99.0% of trials.
#     Any preference above is an artifact of where each post happened to land, not a choice.
#     Do not report it as a profile or correctness effect.
