# %%
# This installs torch 2.6.0 and torchvision 0.21.0 pinned to cu124 because the
# GPU server's NVIDIA driver supports CUDA 12.4 but not CUDA 13.0. torchaudio is
# explicitly uninstalled and excluded because it is not needed for Qwen3-VL and
# its cu124 build conflicts with the server's CUDA 13 runtime libraries, causing
# an OSError on import. transformers is installed from source because Qwen3-VL
# support is not yet available in a stable PyPI release.

import sys, subprocess

# Uninstall torchaudio if it exists from a previous session
subprocess.run([sys.executable, "-m", "pip", "uninstall", "torchaudio", "-y"])

# Install torch stack (no torchaudio)
subprocess.run([sys.executable, "-m", "pip", "install",
    "torch==2.6.0", "torchvision==0.21.0",
    "--index-url", "https://download.pytorch.org/whl/cu124",
    "--user", "-q"], check=True)

# Install transformers + dependencies
subprocess.run([sys.executable, "-m", "pip", "install",
    "git+https://github.com/huggingface/transformers",
    "accelerate", "qwen-vl-utils",
    "--user", "-q"], check=True)

print("✅ Done — restart the kernel now")
# Out:
# WARNING: Skipping torchaudio as it is not installed.
# ✅ Done — restart the kernel now

# %%
# !nvidia-smi
# Out:
# Wed Jun 10 11:59:34 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.127.08             Driver Version: 550.127.08     CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA H100 80GB HBM3          On  |   00000000:CF:00.0 Off |                   On |
# | N/A   29C    P0             77W /  700W |                  N/A   |     N/A      Default |
# |                                         |                        |              Enabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | MIG devices:                                                                            |
# +------------------+----------------------------------+-----------+-----------------------+
# | GPU  GI  CI  MIG |                     Memory-Usage |        Vol|      Shared           |
# |      ID  ID  Dev |                       BAR1-Usage | SM     Unc| CE ENC DEC OFA JPG    |
# |                  |                                  |        ECC|                       |
# |==================+==================================+===========+=======================|
# |  0    2   0   0  |              51MiB / 40320MiB    | 64      0 |  4   0    4    0    4 |
# |                  |                 0MiB / 65535MiB  |           |                       |
# +------------------+----------------------------------+-----------+-----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # Loading most recent version of Vision Qwen to benchmark

# %%
import sys
sys.path.append("/home/jovyan")

from config_hf_token import HF_TOKEN
from huggingface_hub import login

login(token=HF_TOKEN)

# %%
import torch
from transformers import Qwen3VLForConditionalGeneration, AutoProcessor
import os

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

processor = AutoProcessor.from_pretrained("Qwen/Qwen3-VL-8B-Instruct")

model = Qwen3VLForConditionalGeneration.from_pretrained(
    "Qwen/Qwen3-VL-8B-Instruct",
    torch_dtype=torch.bfloat16,
    device_map="auto"
)

print("✅ Loaded successfully")
# Out:
# Using device: cuda
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/750 [00:00<?, ?it/s]
# ✅ Loaded successfully

# %% [markdown]
# # Benchmarking Qwen3 8B Vision LLM

# %% [markdown]
# ## QUALITATIVE
# #### Baseline - gender neutral- news outlets - correct/incorrect - visible 0s

# %%
import sys
from pathlib import Path
#sys.path.append(str(Path().resolve().parent))
from utils.quali_benchmarking import describe_social_media_post_qwen, save_output_txt, output_exists

# %%
# --- Configuration ---
BASE_DIR = Path().resolve()
PROMPT_NAME = "simple"       # 👈 change this per prompt
MODEL_NAME = "qwen3-vl-8b"  # 👈 change this per model
folders_to_process = ["correct", "incorrect"]

# --- Processing Loop ---
for folder in folders_to_process:
    image_dir = BASE_DIR / folder
    
    if not image_dir.exists():
        print(f"Directory not found, skipping: {image_dir}")
        continue
    image_files = sorted(image_dir.glob("*.png"))
    if not image_files:
        print(f"No PNG images found in: {image_dir}")
        continue
    print(f"\nProcessing {len(image_files)} image(s) from folder: [{folder.upper()}]")
    for img_path in image_files:
        str_image_path = str(img_path)
    
        if output_exists(str_image_path, folder, BASE_DIR, MODEL_NAME, PROMPT_NAME):
            print(f"⏭ Skipping: {img_path.name}")
            continue
    
        result = describe_social_media_post(str_image_path, model, processor, device)
        save_output_txt(str_image_path, result, folder_name=folder, base_dir=BASE_DIR, model_name=MODEL_NAME, prompt_name=PROMPT_NAME)

print("\nAll folders processed successfully!")

# %% [markdown]
# ### Analysis

# %% [markdown]
# ### Incorrect posts - 3 of them addressed the incorrect claim after breaking down the visualization
# #### 1. Fox News:
# "**Note on Accuracy:**
# It is important to note that the post claims the data is for “Spotify 2026,” which is likely a fictional or humorous fabrication, as Spotify does not release annual genre distribution data for a future year. The post may be satirical or intended to be misleading."
#
# #### 2. The New York Times
# "**Summary:**
# This post from The New York Times presents a pie chart claiming to show the 2026 music genre preferences of Spotify users. The chart indicates that Pop (23.5%) is the most popular genre, followed by Rock (13.9%), Classical (11.5%), Latin (11.0%), Electronic/Dance (10.2%), R&B/Soul (8.7%), Hip-Hop/Rap (8.8%), Indie/Alternative (6.1%), and Other (6.3%). The post's text highlights the surprising finding that Latin was more popular than Pop, which is contradicted by the chart's data. The post has received no engagement."
#
# #### 3. Remy Ashford
# **Summary:**
# This social media post by Remy Ashford presents a fictional or hypothetical pie chart titled “Music Genre Preferences of Spotify Users,” which claims to show the distribution for 2026. The chart indicates that Pop is the most popular genre (23.5%), followed by Rock (13.9%), and that Latin (11.0%) is more popular than Pop, which contradicts the chart’s data. The post has received no engagement, and the user’s caption seems to be a playful or ironic statement, as the data presented is not accurate for the real world. The visual design is clean and uses a variety of pastel colors to make the chart easy to read.
#
# ### Incorrect posts - Reuters, the final post provided, included a remark about the post claim being wrong within the analysis of the pie chart, instead of adding a statement at the end
# #### 4. Reuters
# "...
# *   **Latin:** 11.0% — A light blue segment, which is visually larger than Pop's segment, contradicting the post's claim that Latin was *more* popular than Pop. (Note: The post says "Latin was more popular than Pop this year!" but the chart shows Pop at 23.5% and Latin at 11.0%. This is a clear contradiction in the post's text and the data presented in the image. The chart data is the factual source.)
#   ..."

# %% [markdown]
# ## QUANTITATIVE
#
# **Tests 1-3** establish a baseli: — how well can the model read charts and verify claims when there are no social signals present.
#
# **Test 4** introduces social signals (reaction metrics) and : s — does the model's claim verification accuracy change when the post appears highly liked, or highly reacted to with angry/sad emotiesis scope?

# %% [markdown]
# ## 1) Extensive analysis of all baseline examples (1 gender neutral user - 3 news outlets)

# %%
import sys
from pathlib import Path
from utils.quanti_benchmarking_1_details import (
    PROMPT_VERSIONS, TWO_CALL_PROMPT_VERSIONS,
    benchmark_image, benchmark_image_two_call, output_exists_json,
    ask_question
)

# --- Configuration ---
BASE_DIR = Path().resolve()
EXPERIMENT_NAME = "test-1-gn-news-extensive"
MODEL_NAME = "qwen3-8b-vl"
ASK_FN = ask_question
variants = ["correct", "incorrect"]

# --- Build image list ---
all_images = []
for variant_folder in variants:
    for png in sorted((BASE_DIR / variant_folder).glob("*.png")):
        all_images.append((png.stem, str(png)))

# --- Run single-call prompt versions ---
for prompt_version, prompt_text in PROMPT_VERSIONS.items():
    print(f"\n{'='*60}\nRunning prompt version: {prompt_version}\n{'='*60}")
    for image_name, image_path in all_images:
        if output_exists_json(image_name, prompt_version, BASE_DIR, EXPERIMENT_NAME, MODEL_NAME):
            print(f"⏭ Skipping: {image_name} [{prompt_version}]")
            continue
        benchmark_image(image_path, image_name, prompt_version, prompt_text, model, processor, device, BASE_DIR, EXPERIMENT_NAME, MODEL_NAME, ASK_FN)

# --- Run two-call prompt versions ---
for prompt_version, prompt_template in TWO_CALL_PROMPT_VERSIONS.items():
    print(f"\n{'='*60}\nRunning two-call prompt version: {prompt_version}\n{'='*60}")
    for image_name, image_path in all_images:
        if output_exists_json(image_name, prompt_version, BASE_DIR, EXPERIMENT_NAME, MODEL_NAME):
            print(f"⏭ Skipping: {image_name} [{prompt_version}]")
            continue
        benchmark_image_two_call(image_path, image_name, prompt_version, prompt_template, model, processor, device, BASE_DIR, EXPERIMENT_NAME, MODEL_NAME, ASK_FN)

print("\n✅ All versions complete.")
# Out:
# ============================================================
# Running prompt version: v1
# ============================================================
# ⏭ Skipping: 001_fox_news_c [v1]
# ⏭ Skipping: 001_ny_times_c [v1]
# ⏭ Skipping: 001_remy_ashford_c [v1]
# ⏭ Skipping: 001_reuters_c [v1]
# ⏭ Skipping: 001_fox_news_i [v1]
# ⏭ Skipping: 001_ny_times_i [v1]
# ⏭ Skipping: 001_remy_ashford_i [v1]
# ⏭ Skipping: 001_reuters_i [v1]
#
# ============================================================
# Running prompt version: v2
# ============================================================
# ⏭ Skipping: 001_fox_news_c [v2]
# ⏭ Skipping: 001_ny_times_c [v2]
# ⏭ Skipping: 001_remy_ashford_c [v2]
# ⏭ Skipping: 001_reuters_c [v2]
# ⏭ Skipping: 001_fox_news_i [v2]
# ⏭ Skipping: 001_ny_times_i [v2]
# ⏭ Skipping: 001_remy_ashford_i [v2]
# ⏭ Skipping: 001_reuters_i [v2]
#
# ============================================================
# Running prompt version: v3
# ============================================================
# ⏭ Skipping: 001_fox_news_c [v3]
# ⏭ Skipping: 001_ny_times_c [v3]
# ⏭ Skipping: 001_remy_ashford_c [v3]
# ⏭ Skipping: 001_reuters_c [v3]
# ⏭ Skipping: 001_fox_news_i [v3]
# ⏭ Skipping: 001_ny_times_i [v3]
# ⏭ Skipping: 001_remy_ashford_i [v3]
# ⏭ Skipping: 001_reuters_i [v3]
#
# ============================================================
# Running prompt version: v4
# ============================================================
# ⏭ Skipping: 001_fox_news_c [v4]
# ⏭ Skipping: 001_ny_times_c [v4]
# ⏭ Skipping: 001_remy_ashford_c [v4]
# ⏭ Skipping: 001_reuters_c [v4]
# ⏭ Skipping: 001_fox_news_i [v4]
# ⏭ Skipping: 001_ny_times_i [v4]
# ⏭ Skipping: 001_remy_ashford_i [v4]
# ⏭ Skipping: 001_reuters_i [v4]
#
# ============================================================
# Running prompt version: v5
# ============================================================
# ⏭ Skipping: 001_fox_news_c [v5]
# ⏭ Skipping: 001_ny_times_c [v5]
# ⏭ Skipping: 001_remy_ashford_c [v5]
# ⏭ Skipping: 001_reuters_c [v5]
# ⏭ Skipping: 001_fox_news_i [v5]
# ⏭ Skipping: 001_ny_times_i [v5]
# ⏭ Skipping: 001_remy_ashford_i [v5]
# ⏭ Skipping: 001_reuters_i [v5]
#
# ============================================================
# Running prompt version: v6
# ============================================================
# ⏭ Skipping: 001_fox_news_c [v6]
# ⏭ Skipping: 001_ny_times_c [v6]
# ⏭ Skipping: 001_remy_ashford_c [v6]
# ⏭ Skipping: 001_reuters_c [v6]
# ⏭ Skipping: 001_fox_news_i [v6]
# ⏭ Skipping: 001_ny_times_i [v6]
# ⏭ Skipping: 001_remy_ashford_i [v6]
# ⏭ Skipping: 001_reuters_i [v6]
#
# ============================================================
# Running two-call prompt version: v7_two_call
# ============================================================
# ⏭ Skipping: 001_fox_news_c [v7_two_call]
# ⏭ Skipping: 001_ny_times_c [v7_two_call]
# ⏭ Skipping: 001_remy_ashford_c [v7_two_call]
# ⏭ Skipping: 001_reuters_c [v7_two_call]
# ⏭ Skipping: 001_fox_news_i [v7_two_call]
# ⏭ Skipping: 001_ny_times_i [v7_two_call]
# ⏭ Skipping: 001_remy_ashford_i [v7_two_call]
# ⏭ Skipping: 001_reuters_i [v7_two_call]
#
# ============================================================
# Running two-call prompt version: v8_two_call
# ============================================================
# ⏭ Skipping: 001_fox_news_c [v8_two_call]
# ⏭ Skipping: 001_ny_times_c [v8_two_call]
# ⏭ Skipping: 001_remy_ashford_c [v8_two_call]
# ⏭ Skipping: 001_reuters_c [v8_two_call]
# ⏭ Skipping: 001_fox_news_i [v8_two_call]
# ⏭ Skipping: 001_ny_times_i [v8_two_call]
# ⏭ Skipping: 001_remy_ashford_i [v8_two_call]
# ⏭ Skipping: 001_reuters_i [v8_two_call]
#
# ============================================================
# Running two-call prompt version: v9_two_call
# ============================================================
# ⏭ Skipping: 001_fox_news_c [v9_two_call]
# ⏭ Skipping: 001_ny_times_c [v9_two_call]
# ⏭ Skipping: 001_remy_ashford_c [v9_two_call]
# ⏭ Skipping: 001_reuters_c [v9_two_call]
# ⏭ Skipping: 001_fox_news_i [v9_two_call]
# ⏭ Skipping: 001_ny_times_i [v9_two_call]
# ⏭ Skipping: 001_remy_ashford_i [v9_two_call]
# ⏭ Skipping: 001_reuters_i [v9_two_call]
#
# ✅ All versions complete.

# %% [markdown]
# ### Accuracy calculations for each version

# %%
from utils.quanti_benchmarking_1_analysis import run_accuracy_analysis

BASE_DIR = Path().resolve()
EXPERIMENT_NAME = "test-1-gn-news-extensive"  # same as in benchmarking notebook
MODEL_NAME = "qwen3-8b-vl"
run_accuracy_analysis(BASE_DIR, EXPERIMENT_NAME, MODEL_NAME)
# Out:
# ============================================================
# Prompt Version : v1
# Prompt Text    : Does the text in the post accurately describe the chart? Reply with only 'correct' or 'incorrect'.
# ============================================================
# === Accuracy per question ===
#                    question  accuracy_%
# 0               likes_count       100.0
# 1             comment_count       100.0
# 2              shares_count       100.0
# 3           heart_reactions       100.0
# 4            haha_reactions       100.0
# 5             wow_reactions       100.0
# 6             sad_reactions       100.0
# 7           angry_reactions       100.0
# 8     chart_percentages_pop       100.0
# 9   chart_percentages_latin       100.0
# 10             profile_name       100.0
# 11     profile_verification       100.0
# 12          chart_color_pop       100.0
# 13        chart_color_latin       100.0
# 14      chart_largest_slice       100.0
# 15               post_claim        50.0
# === Accuracy per image ===
#                 image    all  likes_count  comment_count  shares_count  \
# 0      001_fox_news_c  False         True           True          True
# 1      001_ny_times_c  False         True           True          True
# 2  001_remy_ashford_c  False         True           True          True
# 3       001_reuters_c  False         True           True          True
# 4      001_fox_news_i   True         True           True          True
# 5      001_ny_times_i   True         True           True          True
# 6  001_remy_ashford_i   True         True           True          True
# 7       001_reuters_i   True         True           True          True
#
#    heart_reactions  haha_reactions  wow_reactions  sad_reactions  \
# 0             True            True           True           True
# 1             True            True           True           True
# 2             True            True           True           True
# 3             True            True           True           True
# 4             True            True           True           True
# 5             True            True           True           True
# 6             True            True           True           True
# 7             True            True           True           True
#
#    angry_reactions  chart_percentages_pop  chart_percentages_latin  \
# 0             True                   True                     True
# 1             True                   True                     True
# 2             True                   True                     True
# 3             True                   True                     True
# 4             True                   True                     True
# 5             True                   True                     True
# 6             True                   True                     True
# 7             True                   True                     True
#
#    profile_name  profile_verification  chart_color_pop  chart_color_latin  \
# 0          True                  True             True               True
# 1          True                  True             True               True
# 2          True                  True             True               True
# 3          True                  True             True               True
# 4          True                  True             True               True
# 5          True                  True             True               True
# 6          True                  True             True               True
# 7          True                  True             True               True
#
#    chart_largest_slice  post_claim
# 0                 True       False
# 1                 True       False
# 2                 True       False
# 3                 True       False
# 4                 True        True
# 5                 True        True
# 6                 True        True
# 7                 True        True
# === Overall Summary ===
#                    metric  value
# 0         mean_accuracy_%  96.88
# 1  fully_correct_images_%  50.00
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-1-gn-news-extensive/v1/accuracy_scores_v1.csv
#
# ============================================================
# Prompt Version : v2
# Prompt Text    : Read the text in the post and look at the chart. Does the text correctly describe what the chart shows? Reply with only 'correct' or 'incorrect'.
# ============================================================
# === Accuracy per question ===
#                    question  accuracy_%
# 0               likes_count       100.0
# 1             comment_count       100.0
# 2              shares_count       100.0
# 3           heart_reactions       100.0
# 4            haha_reactions       100.0
# 5             wow_reactions       100.0
# 6             sad_reactions       100.0
# 7           angry_reactions       100.0
# 8     chart_percentages_pop       100.0
# 9   chart_percentages_latin       100.0
# 10             profile_name       100.0
# 11     profile_verification       100.0
# 12          chart_color_pop       100.0
# 13        chart_color_latin       100.0
# 14      chart_largest_slice       100.0
# 15               post_claim        50.0
# === Accuracy per image ===
#                 image    all  likes_count  comment_count  shares_count  \
# 0      001_fox_news_c  False         True           True          True
# 1      001_ny_times_c  False         True           True          True
# 2  001_remy_ashford_c  False         True           True          True
# 3       001_reuters_c  False         True           True          True
# 4      001_fox_news_i   True         True           True          True
# 5      001_ny_times_i   True         True           True          True
# 6  001_remy_ashford_i   True         True           True          True
# 7       001_reuters_i   True         True           True          True
#
#    heart_reactions  haha_reactions  wow_reactions  sad_reactions  \
# 0             True            True           True           True
# 1             True            True           True           True
# 2             True            True           True           True
# 3             True            True           True           True
# 4             True            True           True           True
# 5             True            True           True           True
# 6             True            True           True           True
# 7             True            True           True           True
#
#    angry_reactions  chart_percentages_pop  chart_percentages_latin  \
# 0             True                   True                     True
# 1             True                   True                     True
# 2             True                   True                     True
# 3             True                   True                     True
# 4             True                   True                     True
# 5             True                   True                     True
# 6             True                   True                     True
# 7             True                   True                     True
#
#    profile_name  profile_verification  chart_color_pop  chart_color_latin  \
# 0          True                  True             True               True
# 1          True                  True             True               True
# 2          True                  True             True               True
# 3          True                  True             True               True
# 4          True                  True             True               True
# 5          True                  True             True               True
# 6          True                  True             True               True
# 7          True                  True             True               True
#
#    chart_largest_slice  post_claim
# 0                 True       False
# 1                 True       False
# 2                 True       False
# 3                 True       False
# 4                 True        True
# 5                 True        True
# 6                 True        True
# 7                 True        True
# === Overall Summary ===
#                    metric  value
# 0         mean_accuracy_%  96.88
# 1  fully_correct_images_%  50.00
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-1-gn-news-extensive/v2/accuracy_scores_v2.csv
#
# ============================================================
# Prompt Version : v3
# Prompt Text    : The post text claims one music genre is more popular than another. Look at the percentage values in the chart to verify this claim. If the genre described as more popular in the text has a higher percentage in the chart, reply 'correct'. If not, reply 'incorrect'.
# ============================================================
# === Accuracy per question ===
#                    question  accuracy_%
# 0               likes_count       100.0
# 1             comment_count       100.0
# 2              shares_count       100.0
# 3           heart_reactions       100.0
# 4            haha_reactions       100.0
# 5             wow_reactions       100.0
# 6             sad_reactions       100.0
# 7           angry_reactions       100.0
# 8     chart_percentages_pop       100.0
# 9   chart_percentages_latin       100.0
# 10             profile_name       100.0
# 11     profile_verification       100.0
# 12          chart_color_pop       100.0
# 13        chart_color_latin       100.0
# 14      chart_largest_slice       100.0
# 15               post_claim        50.0
# === Accuracy per image ===
#                 image    all  likes_count  comment_count  shares_count  \
# 0      001_fox_news_c  False         True           True          True
# 1      001_ny_times_c  False         True           True          True
# 2  001_remy_ashford_c  False         True           True          True
# 3       001_reuters_c  False         True           True          True
# 4      001_fox_news_i   True         True           True          True
# 5      001_ny_times_i   True         True           True          True
# 6  001_remy_ashford_i   True         True           True          True
# 7       001_reuters_i   True         True           True          True
#
#    heart_reactions  haha_reactions  wow_reactions  sad_reactions  \
# 0             True            True           True           True
# 1             True            True           True           True
# 2             True            True           True           True
# 3             True            True           True           True
# 4             True            True           True           True
# 5             True            True           True           True
# 6             True            True           True           True
# 7             True            True           True           True
#
#    angry_reactions  chart_percentages_pop  chart_percentages_latin  \
# 0             True                   True                     True
# 1             True                   True                     True
# 2             True                   True                     True
# 3             True                   True                     True
# 4             True                   True                     True
# 5             True                   True                     True
# 6             True                   True                     True
# 7             True                   True                     True
#
#    profile_name  profile_verification  chart_color_pop  chart_color_latin  \
# 0          True                  True             True               True
# 1          True                  True             True               True
# 2          True                  True             True               True
# 3          True                  True             True               True
# 4          True                  True             True               True
# 5          True                  True             True               True
# 6          True                  True             True               True
# 7          True                  True             True               True
#
#    chart_largest_slice  post_claim
# 0                 True       False
# 1                 True       False
# 2                 True       False
# 3                 True       False
# 4                 True        True
# 5                 True        True
# 6                 True        True
# 7                 True        True
# === Overall Summary ===
#                    metric  value
# 0         mean_accuracy_%  96.88
# 1  fully_correct_images_%  50.00
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-1-gn-news-extensive/v3/accuracy_scores_v3.csv
#
# ============================================================
# Prompt Version : v4
# Prompt Text    : In the post, the text above the image makes a claim comparing the popularity of Pop and Latin. Identify the according values in the chart to verify this claim. If the claim matches the visualization reply 'correct'. If not, reply 'incorrect'.
# ============================================================
# === Accuracy per question ===
#                    question  accuracy_%
# 0               likes_count       100.0
# 1             comment_count       100.0
# 2              shares_count       100.0
# 3           heart_reactions       100.0
# 4            haha_reactions       100.0
# 5             wow_reactions       100.0
# 6             sad_reactions       100.0
# 7           angry_reactions       100.0
# 8     chart_percentages_pop       100.0
# 9   chart_percentages_latin       100.0
# 10             profile_name       100.0
# 11     profile_verification       100.0
# 12          chart_color_pop       100.0
# 13        chart_color_latin       100.0
# 14      chart_largest_slice       100.0
# 15               post_claim        50.0
# === Accuracy per image ===
#                 image    all  likes_count  comment_count  shares_count  \
# 0      001_fox_news_c  False         True           True          True
# 1      001_ny_times_c  False         True           True          True
# 2  001_remy_ashford_c  False         True           True          True
# 3       001_reuters_c  False         True           True          True
# 4      001_fox_news_i   True         True           True          True
# 5      001_ny_times_i   True         True           True          True
# 6  001_remy_ashford_i   True         True           True          True
# 7       001_reuters_i   True         True           True          True
#
#    heart_reactions  haha_reactions  wow_reactions  sad_reactions  \
# 0             True            True           True           True
# 1             True            True           True           True
# 2             True            True           True           True
# 3             True            True           True           True
# 4             True            True           True           True
# 5             True            True           True           True
# 6             True            True           True           True
# 7             True            True           True           True
#
#    angry_reactions  chart_percentages_pop  chart_percentages_latin  \
# 0             True                   True                     True
# 1             True                   True                     True
# 2             True                   True                     True
# 3             True                   True                     True
# 4             True                   True                     True
# 5             True                   True                     True
# 6             True                   True                     True
# 7             True                   True                     True
#
#    profile_name  profile_verification  chart_color_pop  chart_color_latin  \
# 0          True                  True             True               True
# 1          True                  True             True               True
# 2          True                  True             True               True
# 3          True                  True             True               True
# 4          True                  True             True               True
# 5          True                  True             True               True
# 6          True                  True             True               True
# 7          True                  True             True               True
#
#    chart_largest_slice  post_claim
# 0                 True       False
# 1                 True       False
# 2                 True       False
# 3                 True       False
# 4                 True        True
# 5                 True        True
# 6                 True        True
# 7                 True        True
# === Overall Summary ===
#                    metric  value
# 0         mean_accuracy_%  96.88
# 1  fully_correct_images_%  50.00
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-1-gn-news-extensive/v4/accuracy_scores_v4.csv
#
# ============================================================
# Prompt Version : v5
# Prompt Text    : In the post, the text above the chart claims one genre is more popular than another. Find the percentage for Pop and the percentage for Latin in the chart. If the genre the text says is more popular has a numerically higher percentage, reply 'correct'. If not, reply 'incorrect'.
# ============================================================
# === Accuracy per question ===
#                    question  accuracy_%
# 0               likes_count       100.0
# 1             comment_count       100.0
# 2              shares_count       100.0
# 3           heart_reactions       100.0
# 4            haha_reactions       100.0
# 5             wow_reactions       100.0
# 6             sad_reactions       100.0
# 7           angry_reactions       100.0
# 8     chart_percentages_pop       100.0
# 9   chart_percentages_latin       100.0
# 10             profile_name       100.0
# 11     profile_verification       100.0
# 12          chart_color_pop       100.0
# 13        chart_color_latin       100.0
# 14      chart_largest_slice       100.0
# 15               post_claim         0.0
# === Accuracy per image ===
#                 image    all  likes_count  comment_count  shares_count  \
# 0      001_fox_news_c  False         True           True          True
# 1      001_ny_times_c  False         True           True          True
# 2  001_remy_ashford_c  False         True           True          True
# 3       001_reuters_c  False         True           True          True
# 4      001_fox_news_i  False         True           True          True
# 5      001_ny_times_i  False         True           True          True
# 6  001_remy_ashford_i  False         True           True          True
# 7       001_reuters_i  False         True           True          True
#
#    heart_reactions  haha_reactions  wow_reactions  sad_reactions  \
# 0             True            True           True           True
# 1             True            True           True           True
# 2             True            True           True           True
# 3             True            True           True           True
# 4             True            True           True           True
# 5             True            True           True           True
# 6             True            True           True           True
# 7             True            True           True           True
#
#    angry_reactions  chart_percentages_pop  chart_percentages_latin  \
# 0             True                   True                     True
# 1             True                   True                     True
# 2             True                   True                     True
# 3             True                   True                     True
# 4             True                   True                     True
# 5             True                   True                     True
# 6             True                   True                     True
# 7             True                   True                     True
#
#    profile_name  profile_verification  chart_color_pop  chart_color_latin  \
# 0          True                  True             True               True
# 1          True                  True             True               True
# 2          True                  True             True               True
# 3          True                  True             True               True
# 4          True                  True             True               True
# 5          True                  True             True               True
# 6          True                  True             True               True
# 7          True                  True             True               True
#
#    chart_largest_slice  post_claim
# 0                 True       False
# 1                 True       False
# 2                 True       False
# 3                 True       False
# 4                 True       False
# 5                 True       False
# 6                 True       False
# 7                 True       False
# === Overall Summary ===
#                    metric  value
# 0         mean_accuracy_%  93.75
# 1  fully_correct_images_%   0.00
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-1-gn-news-extensive/v5/accuracy_scores_v5.csv
#
# ============================================================
# Prompt Version : v6
# Prompt Text    : Look at the text above the chart. It makes a claim about Pop and Latin popularity. Step 1: find the percentage value for Pop in the chart. Step 2: find the percentage value for Latin in the chart. Step 3: check if the claim in the text matches which one is higher. If it matches, reply 'correct'. If not, reply 'incorrect'.
# ============================================================
# === Accuracy per question ===
#                    question  accuracy_%
# 0               likes_count       100.0
# 1             comment_count       100.0
# 2              shares_count       100.0
# 3           heart_reactions       100.0
# 4            haha_reactions       100.0
# 5             wow_reactions       100.0
# 6             sad_reactions       100.0
# 7           angry_reactions       100.0
# 8     chart_percentages_pop       100.0
# 9   chart_percentages_latin       100.0
# 10             profile_name       100.0
# 11     profile_verification       100.0
# 12          chart_color_pop       100.0
# 13        chart_color_latin       100.0
# 14      chart_largest_slice       100.0
# 15               post_claim         0.0
# === Accuracy per image ===
#                 image    all  likes_count  comment_count  shares_count  \
# 0      001_fox_news_c  False         True           True          True
# 1      001_ny_times_c  False         True           True          True
# 2  001_remy_ashford_c  False         True           True          True
# 3       001_reuters_c  False         True           True          True
# 4      001_fox_news_i  False         True           True          True
# 5      001_ny_times_i  False         True           True          True
# 6  001_remy_ashford_i  False         True           True          True
# 7       001_reuters_i  False         True           True          True
#
#    heart_reactions  haha_reactions  wow_reactions  sad_reactions  \
# 0             True            True           True           True
# 1             True            True           True           True
# 2             True            True           True           True
# 3             True            True           True           True
# 4             True            True           True           True
# 5             True            True           True           True
# 6             True            True           True           True
# 7             True            True           True           True
#
#    angry_reactions  chart_percentages_pop  chart_percentages_latin  \
# 0             True                   True                     True
# 1             True                   True                     True
# 2             True                   True                     True
# 3             True                   True                     True
# 4             True                   True                     True
# 5             True                   True                     True
# 6             True                   True                     True
# 7             True                   True                     True
#
#    profile_name  profile_verification  chart_color_pop  chart_color_latin  \
# 0          True                  True             True               True
# 1          True                  True             True               True
# 2          True                  True             True               True
# 3          True                  True             True               True
# 4          True                  True             True               True
# 5          True                  True             True               True
# 6          True                  True             True               True
# 7          True                  True             True               True
#
#    chart_largest_slice  post_claim
# 0                 True       False
# 1                 True       False
# 2                 True       False
# 3                 True       False
# 4                 True       False
# 5                 True       False
# 6                 True       False
# 7                 True       False
# === Overall Summary ===
#                    metric  value
# 0         mean_accuracy_%  93.75
# 1  fully_correct_images_%   0.00
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-1-gn-news-extensive/v6/accuracy_scores_v6.csv
#
# ============================================================
# Prompt Version : v7_two_call
# Prompt Text    : The chart shows Pop at 23.5% and Latin at 11.0%. The post text says 'Looks like Pop was more popular than Latin this year!'. Based only on these numbers, is the claim correct? Reply with only 'correct' or 'incorrect'.
# ============================================================
# === Accuracy per question ===
#                    question  accuracy_%
# 0               likes_count       100.0
# 1             comment_count       100.0
# 2              shares_count       100.0
# 3           heart_reactions       100.0
# 4            haha_reactions       100.0
# 5             wow_reactions       100.0
# 6             sad_reactions       100.0
# 7           angry_reactions       100.0
# 8     chart_percentages_pop       100.0
# 9   chart_percentages_latin       100.0
# 10             profile_name       100.0
# 11     profile_verification       100.0
# 12          chart_color_pop       100.0
# 13        chart_color_latin       100.0
# 14      chart_largest_slice       100.0
# 15               post_claim       100.0
# === Accuracy per image ===
#                 image   all  likes_count  comment_count  shares_count  \
# 0      001_fox_news_c  True         True           True          True
# 1      001_ny_times_c  True         True           True          True
# 2  001_remy_ashford_c  True         True           True          True
# 3       001_reuters_c  True         True           True          True
# 4      001_fox_news_i  True         True           True          True
# 5      001_ny_times_i  True         True           True          True
# 6  001_remy_ashford_i  True         True           True          True
# 7       001_reuters_i  True         True           True          True
#
#    heart_reactions  haha_reactions  wow_reactions  sad_reactions  \
# 0             True            True           True           True
# 1             True            True           True           True
# 2             True            True           True           True
# 3             True            True           True           True
# 4             True            True           True           True
# 5             True            True           True           True
# 6             True            True           True           True
# 7             True            True           True           True
#
#    angry_reactions  chart_percentages_pop  chart_percentages_latin  \
# 0             True                   True                     True
# 1             True                   True                     True
# 2             True                   True                     True
# 3             True                   True                     True
# 4             True                   True                     True
# 5             True                   True                     True
# 6             True                   True                     True
# 7             True                   True                     True
#
#    profile_name  profile_verification  chart_color_pop  chart_color_latin  \
# 0          True                  True             True               True
# 1          True                  True             True               True
# 2          True                  True             True               True
# 3          True                  True             True               True
# 4          True                  True             True               True
# 5          True                  True             True               True
# 6          True                  True             True               True
# 7          True                  True             True               True
#
#    chart_largest_slice  post_claim
# 0                 True        True
# 1                 True        True
# 2                 True        True
# 3                 True        True
# 4                 True        True
# 5                 True        True
# 6                 True        True
# 7                 True        True
# === Overall Summary ===
#                    metric  value
# 0         mean_accuracy_%  100.0
# 1  fully_correct_images_%  100.0
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-1-gn-news-extensive/v7_two_call/accuracy_scores_v7_two_call.csv
#
# ============================================================
# Prompt Version : v8_two_call
# Prompt Text    : Pop: 23.5%. Latin: 11.0%. The post claims: 'Looks like Pop was more popular than Latin this year!'. Does the claim match which percentage is higher? Reply with only 'correct' or 'incorrect'.
# ============================================================
# === Accuracy per question ===
#                    question  accuracy_%
# 0               likes_count       100.0
# 1             comment_count       100.0
# 2              shares_count       100.0
# 3           heart_reactions       100.0
# 4            haha_reactions       100.0
# 5             wow_reactions       100.0
# 6             sad_reactions       100.0
# 7           angry_reactions       100.0
# 8     chart_percentages_pop       100.0
# 9   chart_percentages_latin       100.0
# 10             profile_name       100.0
# 11     profile_verification       100.0
# 12          chart_color_pop       100.0
# 13        chart_color_latin       100.0
# 14      chart_largest_slice       100.0
# 15               post_claim       100.0
# === Accuracy per image ===
#                 image   all  likes_count  comment_count  shares_count  \
# 0      001_fox_news_c  True         True           True          True
# 1      001_ny_times_c  True         True           True          True
# 2  001_remy_ashford_c  True         True           True          True
# 3       001_reuters_c  True         True           True          True
# 4      001_fox_news_i  True         True           True          True
# 5      001_ny_times_i  True         True           True          True
# 6  001_remy_ashford_i  True         True           True          True
# 7       001_reuters_i  True         True           True          True
#
#    heart_reactions  haha_reactions  wow_reactions  sad_reactions  \
# 0             True            True           True           True
# 1             True            True           True           True
# 2             True            True           True           True
# 3             True            True           True           True
# 4             True            True           True           True
# 5             True            True           True           True
# 6             True            True           True           True
# 7             True            True           True           True
#
#    angry_reactions  chart_percentages_pop  chart_percentages_latin  \
# 0             True                   True                     True
# 1             True                   True                     True
# 2             True                   True                     True
# 3             True                   True                     True
# 4             True                   True                     True
# 5             True                   True                     True
# 6             True                   True                     True
# 7             True                   True                     True
#
#    profile_name  profile_verification  chart_color_pop  chart_color_latin  \
# 0          True                  True             True               True
# 1          True                  True             True               True
# 2          True                  True             True               True
# 3          True                  True             True               True
# 4          True                  True             True               True
# 5          True                  True             True               True
# 6          True                  True             True               True
# 7          True                  True             True               True
#
#    chart_largest_slice  post_claim
# 0                 True        True
# 1                 True        True
# 2                 True        True
# 3                 True        True
# 4                 True        True
# 5                 True        True
# 6                 True        True
# 7                 True        True
# === Overall Summary ===
#                    metric  value
# 0         mean_accuracy_%  100.0
# 1  fully_correct_images_%  100.0
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-1-gn-news-extensive/v8_two_call/accuracy_scores_v8_two_call.csv
#
# ============================================================
# Prompt Version : v9_two_call
# Prompt Text    : Given Pop = 23.5% and Latin = 11.0%, is the following statement true or false: 'Looks like Pop was more popular than Latin this year!'. Reply with only 'correct' or 'incorrect'.
# ============================================================
# === Accuracy per question ===
#                    question  accuracy_%
# 0               likes_count       100.0
# 1             comment_count       100.0
# 2              shares_count       100.0
# 3           heart_reactions       100.0
# 4            haha_reactions       100.0
# 5             wow_reactions       100.0
# 6             sad_reactions       100.0
# 7           angry_reactions       100.0
# 8     chart_percentages_pop       100.0
# 9   chart_percentages_latin       100.0
# 10             profile_name       100.0
# 11     profile_verification       100.0
# 12          chart_color_pop       100.0
# 13        chart_color_latin       100.0
# 14      chart_largest_slice       100.0
# 15               post_claim       100.0
# === Accuracy per image ===
#                 image   all  likes_count  comment_count  shares_count  \
# 0      001_fox_news_c  True         True           True          True
# 1      001_ny_times_c  True         True           True          True
# 2  001_remy_ashford_c  True         True           True          True
# 3       001_reuters_c  True         True           True          True
# 4      001_fox_news_i  True         True           True          True
# 5      001_ny_times_i  True         True           True          True
# 6  001_remy_ashford_i  True         True           True          True
# 7       001_reuters_i  True         True           True          True
#
#    heart_reactions  haha_reactions  wow_reactions  sad_reactions  \
# 0             True            True           True           True
# 1             True            True           True           True
# 2             True            True           True           True
# 3             True            True           True           True
# 4             True            True           True           True
# 5             True            True           True           True
# 6             True            True           True           True
# 7             True            True           True           True
#
#    angry_reactions  chart_percentages_pop  chart_percentages_latin  \
# 0             True                   True                     True
# 1             True                   True                     True
# 2             True                   True                     True
# 3             True                   True                     True
# 4             True                   True                     True
# 5             True                   True                     True
# 6             True                   True                     True
# 7             True                   True                     True
#
#    profile_name  profile_verification  chart_color_pop  chart_color_latin  \
# 0          True                  True             True               True
# 1          True                  True             True               True
# 2          True                  True             True               True
# 3          True                  True             True               True
# 4          True                  True             True               True
# 5          True                  True             True               True
# 6          True                  True             True               True
# 7          True                  True             True               True
#
#    chart_largest_slice  post_claim
# 0                 True        True
# 1                 True        True
# 2                 True        True
# 3                 True        True
# 4                 True        True
# 5                 True        True
# 6                 True        True
# 7                 True        True
# === Overall Summary ===
#                    metric  value
# 0         mean_accuracy_%  100.0
# 1  fully_correct_images_%  100.0
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-1-gn-news-extensive/v9_two_call/accuracy_scores_v9_two_call.csv

# %% [markdown]
# ## Prior to adding the two call prompts (v1-v6 only)
# - v1–v2: Too vague — "accurately describe" invites hallucinated criteria
# - v3: Forces the model to reason in a specific direction, but the conditional phrasing ("if… reply correct") is hard for VLMs to follow reliably
# - v4–v5: Better, but "find the percentage for Pop and Latin" may cause the model to report numbers correctly but then flip its verdict
# - v6: The step-by-step is the best approach but still ends ambiguously
#
# **The core issue here might be missing explicit numeric grounding**
# - None of the prompts ask the model to state the numbers before giving a verdict. VLMs tend to shortcut directly to a label when prompted for a binary answer.
# - The model likely reads 23.5% and 11.0% correctly (proven by the chart_percentages questions succeeding), but when asked for a verdict in one shot, it could be regressing to a bias.
#
# ## Next solution approach: two call prompts (v7-v9)
#
# Instead of asking the model one question like "does the text match the chart?" and hoping it figures everything out on its own, the two-call approach breaks it into two steps:
#
# 1. I ask the model to read the specific numbers from the chart (Pop % and Latin %)
# 2. I give it those numbers directly and ask if the claim matches
#
# The idea is that the model was likely reading the chart correctly, but stumbling when asked to simultaneously read, reason, and give a verdict in one go. By separating perception from reasoning, we give it a better chance of getting the final answer right.
#
# **28/05 Giordano comment**: We will not be conducting the experiment with two call prompts, chances are the bigger the model the better it performs at determining whether the claim is correct or not.

# %% [markdown]
# ## 2) Focusing on gender neutral user - using best performing prompt - only asking wether claim is correct or not - 100 versions of visualization remy ashford - 50/50 correct incorrect ratio - store the order provided to the LLM
# After part 1, should definitely be using the two call approach here.

# %%
# Unzipping correct and incorrect versions of gender neutral baseline with 100 different visualizations each
#!unzip correct/remy-ashford/remy_ashford_c_pngs.zip -d correct/remy-ashford/
#!unzip incorrect/remy-ashford/remy_ashford_i_pngs.zip -d incorrect/remy-ashford/
# Out:
# Archive:  correct/remy-ashford/remy_ashford_c_pngs.zip
#   inflating: correct/remy-ashford/001_remy_ashford_c.png
#   inflating: correct/remy-ashford/002_remy_ashford_c.png
#   inflating: correct/remy-ashford/003_remy_ashford_c.png
#   inflating: correct/remy-ashford/004_remy_ashford_c.png
#   inflating: correct/remy-ashford/005_remy_ashford_c.png
#   inflating: correct/remy-ashford/006_remy_ashford_c.png
#   inflating: correct/remy-ashford/007_remy_ashford_c.png
#   inflating: correct/remy-ashford/008_remy_ashford_c.png
#   inflating: correct/remy-ashford/009_remy_ashford_c.png
#   inflating: correct/remy-ashford/010_remy_ashford_c.png
#   inflating: correct/remy-ashford/011_remy_ashford_c.png
#   inflating: correct/remy-ashford/012_remy_ashford_c.png
#   inflating: correct/remy-ashford/013_remy_ashford_c.png
#   inflating: correct/remy-ashford/014_remy_ashford_c.png
#   inflating: correct/remy-ashford/015_remy_ashford_c.png
#   inflating: correct/remy-ashford/016_remy_ashford_c.png
#   inflating: correct/remy-ashford/017_remy_ashford_c.png
#   inflating: correct/remy-ashford/018_remy_ashford_c.png
#   inflating: correct/remy-ashford/019_remy_ashford_c.png
#   inflating: correct/remy-ashford/020_remy_ashford_c.png
#   inflating: correct/remy-ashford/021_remy_ashford_c.png
#   inflating: correct/remy-ashford/022_remy_ashford_c.png
#   inflating: correct/remy-ashford/023_remy_ashford_c.png
#   inflating: correct/remy-ashford/024_remy_ashford_c.png
#   inflating: correct/remy-ashford/025_remy_ashford_c.png
#   inflating: correct/remy-ashford/026_remy_ashford_c.png
#   inflating: correct/remy-ashford/027_remy_ashford_c.png
#   inflating: correct/remy-ashford/028_remy_ashford_c.png
#   inflating: correct/remy-ashford/029_remy_ashford_c.png
#   inflating: correct/remy-ashford/030_remy_ashford_c.png
#   inflating: correct/remy-ashford/031_remy_ashford_c.png
#   inflating: correct/remy-ashford/032_remy_ashford_c.png
#   inflating: correct/remy-ashford/033_remy_ashford_c.png
#   inflating: correct/remy-ashford/034_remy_ashford_c.png
#   inflating: correct/remy-ashford/035_remy_ashford_c.png
#   inflating: correct/remy-ashford/036_remy_ashford_c.png
#   inflating: correct/remy-ashford/037_remy_ashford_c.png
#   inflating: correct/remy-ashford/038_remy_ashford_c.png
#   inflating: correct/remy-ashford/039_remy_ashford_c.png
#   inflating: correct/remy-ashford/040_remy_ashford_c.png
#   inflating: correct/remy-ashford/041_remy_ashford_c.png
#   inflating: correct/remy-ashford/042_remy_ashford_c.png
#   inflating: correct/remy-ashford/043_remy_ashford_c.png
#   inflating: correct/remy-ashford/044_remy_ashford_c.png
#   inflating: correct/remy-ashford/045_remy_ashford_c.png
#   inflating: correct/remy-ashford/046_remy_ashford_c.png
#   inflating: correct/remy-ashford/047_remy_ashford_c.png
#   inflating: correct/remy-ashford/048_remy_ashford_c.png
#   inflating: correct/remy-ashford/049_remy_ashford_c.png
#   inflating: correct/remy-ashford/050_remy_ashford_c.png
#   inflating: correct/remy-ashford/051_remy_ashford_c.png
#   inflating: correct/remy-ashford/052_remy_ashford_c.png
#   inflating: correct/remy-ashford/053_remy_ashford_c.png
#   inflating: correct/remy-ashford/054_remy_ashford_c.png
#   inflating: correct/remy-ashford/055_remy_ashford_c.png
#   inflating: correct/remy-ashford/056_remy_ashford_c.png
#   inflating: correct/remy-ashford/057_remy_ashford_c.png
#   inflating: correct/remy-ashford/058_remy_ashford_c.png
#   inflating: correct/remy-ashford/059_remy_ashford_c.png
#   inflating: correct/remy-ashford/060_remy_ashford_c.png
#   inflating: correct/remy-ashford/061_remy_ashford_c.png
#   inflating: correct/remy-ashford/062_remy_ashford_c.png
#   inflating: correct/remy-ashford/063_remy_ashford_c.png
#   inflating: correct/remy-ashford/064_remy_ashford_c.png
#   inflating: correct/remy-ashford/065_remy_ashford_c.png
#   inflating: correct/remy-ashford/066_remy_ashford_c.png
#   inflating: correct/remy-ashford/067_remy_ashford_c.png
#   inflating: correct/remy-ashford/068_remy_ashford_c.png
#   inflating: correct/remy-ashford/069_remy_ashford_c.png
#   inflating: correct/remy-ashford/070_remy_ashford_c.png
#   inflating: correct/remy-ashford/071_remy_ashford_c.png
#   inflating: correct/remy-ashford/072_remy_ashford_c.png
#   inflating: correct/remy-ashford/073_remy_ashford_c.png
#   inflating: correct/remy-ashford/074_remy_ashford_c.png
#   inflating: correct/remy-ashford/075_remy_ashford_c.png
#   inflating: correct/remy-ashford/076_remy_ashford_c.png
#   inflating: correct/remy-ashford/077_remy_ashford_c.png
#   inflating: correct/remy-ashford/078_remy_ashford_c.png
#   inflating: correct/remy-ashford/079_remy_ashford_c.png
#   inflating: correct/remy-ashford/080_remy_ashford_c.png
#   inflating: correct/remy-ashford/081_remy_ashford_c.png
#   inflating: correct/remy-ashford/082_remy_ashford_c.png
#   inflating: correct/remy-ashford/083_remy_ashford_c.png
#   inflating: correct/remy-ashford/084_remy_ashford_c.png
#   inflating: correct/remy-ashford/085_remy_ashford_c.png
#   inflating: correct/remy-ashford/086_remy_ashford_c.png
#   inflating: correct/remy-ashford/087_remy_ashford_c.png
#   inflating: correct/remy-ashford/088_remy_ashford_c.png
#   inflating: correct/remy-ashford/089_remy_ashford_c.png
#   inflating: correct/remy-ashford/090_remy_ashford_c.png
#   inflating: correct/remy-ashford/091_remy_ashford_c.png
#   inflating: correct/remy-ashford/092_remy_ashford_c.png
#   inflating: correct/remy-ashford/093_remy_ashford_c.png
#   inflating: correct/remy-ashford/094_remy_ashford_c.png
#   inflating: correct/remy-ashford/095_remy_ashford_c.png
#   inflating: correct/remy-ashford/096_remy_ashford_c.png
#   inflating: correct/remy-ashford/097_remy_ashford_c.png
#   inflating: correct/remy-ashford/098_remy_ashford_c.png
#   inflating: correct/remy-ashford/099_remy_ashford_c.png
#   inflating: correct/remy-ashford/100_remy_ashford_c.png
# Archive:  incorrect/remy-ashford/remy_ashford_i_pngs.zip
#   inflating: incorrect/remy-ashford/001_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/002_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/003_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/004_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/005_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/006_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/007_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/008_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/009_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/010_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/011_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/012_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/013_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/014_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/015_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/016_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/017_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/018_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/019_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/020_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/021_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/022_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/023_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/024_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/025_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/026_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/027_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/028_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/029_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/030_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/031_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/032_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/033_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/034_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/035_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/036_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/037_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/038_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/039_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/040_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/041_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/042_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/043_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/044_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/045_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/046_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/047_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/048_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/049_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/050_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/051_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/052_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/053_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/054_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/055_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/056_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/057_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/058_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/059_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/060_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/061_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/062_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/063_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/064_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/065_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/066_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/067_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/068_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/069_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/070_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/071_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/072_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/073_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/074_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/075_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/076_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/077_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/078_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/079_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/080_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/081_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/082_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/083_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/084_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/085_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/086_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/087_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/088_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/089_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/090_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/091_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/092_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/093_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/094_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/095_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/096_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/097_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/098_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/099_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/100_remy_ashford_i.png

# %%
import sys
import random
from pathlib import Path
sys.path.append(str(Path().resolve().parent))
from utils.quanti_benchmarking_2_claim_only import (
    PROMPT_VERSIONS, TWO_CALL_PROMPT_VERSIONS,
    benchmark_image, benchmark_image_two_call, output_exists_json,
    ask_question
)

# --- Configuration ---
BASE_DIR = Path().resolve()
EXPERIMENT_NAME = "test-2-gn-claim-only"
MODEL_NAME = "qwen3-8b-vl"
ASK_FN = ask_question
SEED = 42
SAMPLE_SIZE = 50

# --- Build paired sample ---
correct_dir = BASE_DIR / "correct/remy-ashford"
incorrect_dir = BASE_DIR / "incorrect/remy-ashford"
all_numbers = sorted([p.name.split("_")[0] for p in correct_dir.glob("*_remy_ashford_c.png")])
print(f"Found {len(all_numbers)} images in {correct_dir}")

random.seed(SEED)
selected_numbers = sorted(random.sample(all_numbers, SAMPLE_SIZE))
all_images = []
for num in selected_numbers:
    all_images.append((f"{num}_correct", str(correct_dir / f"{num}_remy_ashford_c.png")))
    all_images.append((f"{num}_incorrect", str(incorrect_dir / f"{num}_remy_ashford_i.png")))
print(f"Selected {len(selected_numbers)} pairs → {len(all_images)} images total")

# --- Run one-call versions ---
for prompt_version, prompt_text in PROMPT_VERSIONS.items():
    print(f"\n{'='*60}\nRunning: {prompt_version}\n{'='*60}")
    for image_name, image_path in all_images:
        if output_exists_json(image_name, prompt_version, BASE_DIR, EXPERIMENT_NAME, MODEL_NAME):
            print(f"⏭ Skipping: {image_name} [{prompt_version}]")
            continue
        benchmark_image(image_path, image_name, prompt_version, prompt_text, model, processor, device, BASE_DIR, EXPERIMENT_NAME, MODEL_NAME, ASK_FN)

# --- Run two-call versions ---
for prompt_version, prompt_template in TWO_CALL_PROMPT_VERSIONS.items():
    print(f"\n{'='*60}\nRunning: {prompt_version}\n{'='*60}")
    for image_name, image_path in all_images:
        if output_exists_json(image_name, prompt_version, BASE_DIR, EXPERIMENT_NAME, MODEL_NAME):
            print(f"⏭ Skipping: {image_name} [{prompt_version}]")
            continue
        benchmark_image_two_call(image_path, image_name, prompt_version, prompt_template, model, processor, device, BASE_DIR, EXPERIMENT_NAME, MODEL_NAME, ASK_FN)

print("\n✅ All remy-ashford versions complete.")
# Out:
# Found 100 images in /home/jovyan/benchmarking/correct/remy-ashford
# Selected 50 pairs → 100 images total
#
# ============================================================
# Running: v1
# ============================================================
# ⏭ Skipping: 001_correct [v1]
# ⏭ Skipping: 001_incorrect [v1]
# ⏭ Skipping: 003_correct [v1]
# ⏭ Skipping: 003_incorrect [v1]
# ⏭ Skipping: 004_correct [v1]
# ⏭ Skipping: 004_incorrect [v1]
# ⏭ Skipping: 005_correct [v1]
# ⏭ Skipping: 005_incorrect [v1]
# ⏭ Skipping: 006_correct [v1]
# ⏭ Skipping: 006_incorrect [v1]
# ⏭ Skipping: 007_correct [v1]
# ⏭ Skipping: 007_incorrect [v1]
# ⏭ Skipping: 012_correct [v1]
# ⏭ Skipping: 012_incorrect [v1]
# ⏭ Skipping: 014_correct [v1]
# ⏭ Skipping: 014_incorrect [v1]
# ⏭ Skipping: 015_correct [v1]
# ⏭ Skipping: 015_incorrect [v1]
# ⏭ Skipping: 017_correct [v1]
# ⏭ Skipping: 017_incorrect [v1]
# ⏭ Skipping: 018_correct [v1]
# ⏭ Skipping: 018_incorrect [v1]
# ⏭ Skipping: 020_correct [v1]
# ⏭ Skipping: 020_incorrect [v1]
# ⏭ Skipping: 021_correct [v1]
# ⏭ Skipping: 021_incorrect [v1]
# ⏭ Skipping: 023_correct [v1]
# ⏭ Skipping: 023_incorrect [v1]
# ⏭ Skipping: 025_correct [v1]
# ⏭ Skipping: 025_incorrect [v1]
# ⏭ Skipping: 026_correct [v1]
# ⏭ Skipping: 026_incorrect [v1]
# ⏭ Skipping: 028_correct [v1]
# ⏭ Skipping: 028_incorrect [v1]
# ⏭ Skipping: 029_correct [v1]
# ⏭ Skipping: 029_incorrect [v1]
# ⏭ Skipping: 030_correct [v1]
# ⏭ Skipping: 030_incorrect [v1]
# ⏭ Skipping: 032_correct [v1]
# ⏭ Skipping: 032_incorrect [v1]
# ⏭ Skipping: 036_correct [v1]
# ⏭ Skipping: 036_incorrect [v1]
# ⏭ Skipping: 039_correct [v1]
# ⏭ Skipping: 039_incorrect [v1]
# ⏭ Skipping: 044_correct [v1]
# ⏭ Skipping: 044_incorrect [v1]
# ⏭ Skipping: 047_correct [v1]
# ⏭ Skipping: 047_incorrect [v1]
# ⏭ Skipping: 052_correct [v1]
# ⏭ Skipping: 052_incorrect [v1]
# ⏭ Skipping: 054_correct [v1]
# ⏭ Skipping: 054_incorrect [v1]
# ⏭ Skipping: 055_correct [v1]
# ⏭ Skipping: 055_incorrect [v1]
# ⏭ Skipping: 058_correct [v1]
# ⏭ Skipping: 058_incorrect [v1]
# ⏭ Skipping: 059_correct [v1]
# ⏭ Skipping: 059_incorrect [v1]
# ⏭ Skipping: 063_correct [v1]
# ⏭ Skipping: 063_incorrect [v1]
# ⏭ Skipping: 065_correct [v1]
# ⏭ Skipping: 065_incorrect [v1]
# ⏭ Skipping: 068_correct [v1]
# ⏭ Skipping: 068_incorrect [v1]
# ⏭ Skipping: 069_correct [v1]
# ⏭ Skipping: 069_incorrect [v1]
# ⏭ Skipping: 070_correct [v1]
# ⏭ Skipping: 070_incorrect [v1]
# ⏭ Skipping: 072_correct [v1]
# ⏭ Skipping: 072_incorrect [v1]
# ⏭ Skipping: 076_correct [v1]
# ⏭ Skipping: 076_incorrect [v1]
# ⏭ Skipping: 078_correct [v1]
# ⏭ Skipping: 078_incorrect [v1]
# ⏭ Skipping: 080_correct [v1]
# ⏭ Skipping: 080_incorrect [v1]
# ⏭ Skipping: 082_correct [v1]
# ⏭ Skipping: 082_incorrect [v1]
# ⏭ Skipping: 083_correct [v1]
# ⏭ Skipping: 083_incorrect [v1]
# ⏭ Skipping: 085_correct [v1]
# ⏭ Skipping: 085_incorrect [v1]
# ⏭ Skipping: 087_correct [v1]
# ⏭ Skipping: 087_incorrect [v1]
# ⏭ Skipping: 089_correct [v1]
# ⏭ Skipping: 089_incorrect [v1]
# ⏭ Skipping: 090_correct [v1]
# ⏭ Skipping: 090_incorrect [v1]
# ⏭ Skipping: 091_correct [v1]
# ⏭ Skipping: 091_incorrect [v1]
# ⏭ Skipping: 094_correct [v1]
# ⏭ Skipping: 094_incorrect [v1]
# ⏭ Skipping: 095_correct [v1]
# ⏭ Skipping: 095_incorrect [v1]
# ⏭ Skipping: 096_correct [v1]
# ⏭ Skipping: 096_incorrect [v1]
# ⏭ Skipping: 098_correct [v1]
# ⏭ Skipping: 098_incorrect [v1]
# ⏭ Skipping: 100_correct [v1]
# ⏭ Skipping: 100_incorrect [v1]
#
# ============================================================
# Running: v2
# ============================================================
# ⏭ Skipping: 001_correct [v2]
# ⏭ Skipping: 001_incorrect [v2]
# ⏭ Skipping: 003_correct [v2]
# ⏭ Skipping: 003_incorrect [v2]
# ⏭ Skipping: 004_correct [v2]
# ⏭ Skipping: 004_incorrect [v2]
# ⏭ Skipping: 005_correct [v2]
# ⏭ Skipping: 005_incorrect [v2]
# ⏭ Skipping: 006_correct [v2]
# ⏭ Skipping: 006_incorrect [v2]
# ⏭ Skipping: 007_correct [v2]
# ⏭ Skipping: 007_incorrect [v2]
# ⏭ Skipping: 012_correct [v2]
# ⏭ Skipping: 012_incorrect [v2]
# ⏭ Skipping: 014_correct [v2]
# ⏭ Skipping: 014_incorrect [v2]
# ⏭ Skipping: 015_correct [v2]
# ⏭ Skipping: 015_incorrect [v2]
# ⏭ Skipping: 017_correct [v2]
# ⏭ Skipping: 017_incorrect [v2]
# ⏭ Skipping: 018_correct [v2]
# ⏭ Skipping: 018_incorrect [v2]
# ⏭ Skipping: 020_correct [v2]
# ⏭ Skipping: 020_incorrect [v2]
# ⏭ Skipping: 021_correct [v2]
# ⏭ Skipping: 021_incorrect [v2]
# ⏭ Skipping: 023_correct [v2]
# ⏭ Skipping: 023_incorrect [v2]
# ⏭ Skipping: 025_correct [v2]
# ⏭ Skipping: 025_incorrect [v2]
# ⏭ Skipping: 026_correct [v2]
# ⏭ Skipping: 026_incorrect [v2]
# ⏭ Skipping: 028_correct [v2]
# ⏭ Skipping: 028_incorrect [v2]
# ⏭ Skipping: 029_correct [v2]
# ⏭ Skipping: 029_incorrect [v2]
# ⏭ Skipping: 030_correct [v2]
# ⏭ Skipping: 030_incorrect [v2]
# ⏭ Skipping: 032_correct [v2]
# ⏭ Skipping: 032_incorrect [v2]
# ⏭ Skipping: 036_correct [v2]
# ⏭ Skipping: 036_incorrect [v2]
# ⏭ Skipping: 039_correct [v2]
# ⏭ Skipping: 039_incorrect [v2]
# ⏭ Skipping: 044_correct [v2]
# ⏭ Skipping: 044_incorrect [v2]
# ⏭ Skipping: 047_correct [v2]
# ⏭ Skipping: 047_incorrect [v2]
# ⏭ Skipping: 052_correct [v2]
# ⏭ Skipping: 052_incorrect [v2]
# ⏭ Skipping: 054_correct [v2]
# ⏭ Skipping: 054_incorrect [v2]
# ⏭ Skipping: 055_correct [v2]
# ⏭ Skipping: 055_incorrect [v2]
# ⏭ Skipping: 058_correct [v2]
# ⏭ Skipping: 058_incorrect [v2]
# ⏭ Skipping: 059_correct [v2]
# ⏭ Skipping: 059_incorrect [v2]
# ⏭ Skipping: 063_correct [v2]
# ⏭ Skipping: 063_incorrect [v2]
# ⏭ Skipping: 065_correct [v2]
# ⏭ Skipping: 065_incorrect [v2]
# ⏭ Skipping: 068_correct [v2]
# ⏭ Skipping: 068_incorrect [v2]
# ⏭ Skipping: 069_correct [v2]
# ⏭ Skipping: 069_incorrect [v2]
# ⏭ Skipping: 070_correct [v2]
# ⏭ Skipping: 070_incorrect [v2]
# ⏭ Skipping: 072_correct [v2]
# ⏭ Skipping: 072_incorrect [v2]
# ⏭ Skipping: 076_correct [v2]
# ⏭ Skipping: 076_incorrect [v2]
# ⏭ Skipping: 078_correct [v2]
# ⏭ Skipping: 078_incorrect [v2]
# ⏭ Skipping: 080_correct [v2]
# ⏭ Skipping: 080_incorrect [v2]
# ⏭ Skipping: 082_correct [v2]
# ⏭ Skipping: 082_incorrect [v2]
# ⏭ Skipping: 083_correct [v2]
# ⏭ Skipping: 083_incorrect [v2]
# ⏭ Skipping: 085_correct [v2]
# ⏭ Skipping: 085_incorrect [v2]
# ⏭ Skipping: 087_correct [v2]
# ⏭ Skipping: 087_incorrect [v2]
# ⏭ Skipping: 089_correct [v2]
# ⏭ Skipping: 089_incorrect [v2]
# ⏭ Skipping: 090_correct [v2]
# ⏭ Skipping: 090_incorrect [v2]
# ⏭ Skipping: 091_correct [v2]
# ⏭ Skipping: 091_incorrect [v2]
# ⏭ Skipping: 094_correct [v2]
# ⏭ Skipping: 094_incorrect [v2]
# ⏭ Skipping: 095_correct [v2]
# ⏭ Skipping: 095_incorrect [v2]
# ⏭ Skipping: 096_correct [v2]
# ⏭ Skipping: 096_incorrect [v2]
# ⏭ Skipping: 098_correct [v2]
# ⏭ Skipping: 098_incorrect [v2]
# ⏭ Skipping: 100_correct [v2]
# ⏭ Skipping: 100_incorrect [v2]
#
# ============================================================
# Running: v3
# ============================================================
# ⏭ Skipping: 001_correct [v3]
# ⏭ Skipping: 001_incorrect [v3]
# ⏭ Skipping: 003_correct [v3]
# ⏭ Skipping: 003_incorrect [v3]
# ⏭ Skipping: 004_correct [v3]
# ⏭ Skipping: 004_incorrect [v3]
# ⏭ Skipping: 005_correct [v3]
# ⏭ Skipping: 005_incorrect [v3]
# ⏭ Skipping: 006_correct [v3]
# ⏭ Skipping: 006_incorrect [v3]
# ⏭ Skipping: 007_correct [v3]
# ⏭ Skipping: 007_incorrect [v3]
# ⏭ Skipping: 012_correct [v3]
# ⏭ Skipping: 012_incorrect [v3]
# ⏭ Skipping: 014_correct [v3]
# ⏭ Skipping: 014_incorrect [v3]
# ⏭ Skipping: 015_correct [v3]
# ⏭ Skipping: 015_incorrect [v3]
# ⏭ Skipping: 017_correct [v3]
# ⏭ Skipping: 017_incorrect [v3]
# ⏭ Skipping: 018_correct [v3]
# ⏭ Skipping: 018_incorrect [v3]
# ⏭ Skipping: 020_correct [v3]
# ⏭ Skipping: 020_incorrect [v3]
# ⏭ Skipping: 021_correct [v3]
# ⏭ Skipping: 021_incorrect [v3]
# ⏭ Skipping: 023_correct [v3]
# ⏭ Skipping: 023_incorrect [v3]
# ⏭ Skipping: 025_correct [v3]
# ⏭ Skipping: 025_incorrect [v3]
# ⏭ Skipping: 026_correct [v3]
# ⏭ Skipping: 026_incorrect [v3]
# ⏭ Skipping: 028_correct [v3]
# ⏭ Skipping: 028_incorrect [v3]
# ⏭ Skipping: 029_correct [v3]
# ⏭ Skipping: 029_incorrect [v3]
# ⏭ Skipping: 030_correct [v3]
# ⏭ Skipping: 030_incorrect [v3]
# ⏭ Skipping: 032_correct [v3]
# ⏭ Skipping: 032_incorrect [v3]
# ⏭ Skipping: 036_correct [v3]
# ⏭ Skipping: 036_incorrect [v3]
# ⏭ Skipping: 039_correct [v3]
# ⏭ Skipping: 039_incorrect [v3]
# ⏭ Skipping: 044_correct [v3]
# ⏭ Skipping: 044_incorrect [v3]
# ⏭ Skipping: 047_correct [v3]
# ⏭ Skipping: 047_incorrect [v3]
# ⏭ Skipping: 052_correct [v3]
# ⏭ Skipping: 052_incorrect [v3]
# ⏭ Skipping: 054_correct [v3]
# ⏭ Skipping: 054_incorrect [v3]
# ⏭ Skipping: 055_correct [v3]
# ⏭ Skipping: 055_incorrect [v3]
# ⏭ Skipping: 058_correct [v3]
# ⏭ Skipping: 058_incorrect [v3]
# ⏭ Skipping: 059_correct [v3]
# ⏭ Skipping: 059_incorrect [v3]
# ⏭ Skipping: 063_correct [v3]
# ⏭ Skipping: 063_incorrect [v3]
# ⏭ Skipping: 065_correct [v3]
# ⏭ Skipping: 065_incorrect [v3]
# ⏭ Skipping: 068_correct [v3]
# ⏭ Skipping: 068_incorrect [v3]
# ⏭ Skipping: 069_correct [v3]
# ⏭ Skipping: 069_incorrect [v3]
# ⏭ Skipping: 070_correct [v3]
# ⏭ Skipping: 070_incorrect [v3]
# ⏭ Skipping: 072_correct [v3]
# ⏭ Skipping: 072_incorrect [v3]
# ⏭ Skipping: 076_correct [v3]
# ⏭ Skipping: 076_incorrect [v3]
# ⏭ Skipping: 078_correct [v3]
# ⏭ Skipping: 078_incorrect [v3]
# ⏭ Skipping: 080_correct [v3]
# ⏭ Skipping: 080_incorrect [v3]
# ⏭ Skipping: 082_correct [v3]
# ⏭ Skipping: 082_incorrect [v3]
# ⏭ Skipping: 083_correct [v3]
# ⏭ Skipping: 083_incorrect [v3]
# ⏭ Skipping: 085_correct [v3]
# ⏭ Skipping: 085_incorrect [v3]
# ⏭ Skipping: 087_correct [v3]
# ⏭ Skipping: 087_incorrect [v3]
# ⏭ Skipping: 089_correct [v3]
# ⏭ Skipping: 089_incorrect [v3]
# ⏭ Skipping: 090_correct [v3]
# ⏭ Skipping: 090_incorrect [v3]
# ⏭ Skipping: 091_correct [v3]
# ⏭ Skipping: 091_incorrect [v3]
# ⏭ Skipping: 094_correct [v3]
# ⏭ Skipping: 094_incorrect [v3]
# ⏭ Skipping: 095_correct [v3]
# ⏭ Skipping: 095_incorrect [v3]
# ⏭ Skipping: 096_correct [v3]
# ⏭ Skipping: 096_incorrect [v3]
# ⏭ Skipping: 098_correct [v3]
# ⏭ Skipping: 098_incorrect [v3]
# ⏭ Skipping: 100_correct [v3]
# ⏭ Skipping: 100_incorrect [v3]
#
# ============================================================
# Running: v4
# ============================================================
# ⏭ Skipping: 001_correct [v4]
# ⏭ Skipping: 001_incorrect [v4]
# ⏭ Skipping: 003_correct [v4]
# ⏭ Skipping: 003_incorrect [v4]
# ⏭ Skipping: 004_correct [v4]
# ⏭ Skipping: 004_incorrect [v4]
# ⏭ Skipping: 005_correct [v4]
# ⏭ Skipping: 005_incorrect [v4]
# ⏭ Skipping: 006_correct [v4]
# ⏭ Skipping: 006_incorrect [v4]
# ⏭ Skipping: 007_correct [v4]
# ⏭ Skipping: 007_incorrect [v4]
# ⏭ Skipping: 012_correct [v4]
# ⏭ Skipping: 012_incorrect [v4]
# ⏭ Skipping: 014_correct [v4]
# ⏭ Skipping: 014_incorrect [v4]
# ⏭ Skipping: 015_correct [v4]
# ⏭ Skipping: 015_incorrect [v4]
# ⏭ Skipping: 017_correct [v4]
# ⏭ Skipping: 017_incorrect [v4]
# ⏭ Skipping: 018_correct [v4]
# ⏭ Skipping: 018_incorrect [v4]
# ⏭ Skipping: 020_correct [v4]
# ⏭ Skipping: 020_incorrect [v4]
# ⏭ Skipping: 021_correct [v4]
# ⏭ Skipping: 021_incorrect [v4]
# ⏭ Skipping: 023_correct [v4]
# ⏭ Skipping: 023_incorrect [v4]
# ⏭ Skipping: 025_correct [v4]
# ⏭ Skipping: 025_incorrect [v4]
# ⏭ Skipping: 026_correct [v4]
# ⏭ Skipping: 026_incorrect [v4]
# ⏭ Skipping: 028_correct [v4]
# ⏭ Skipping: 028_incorrect [v4]
# ⏭ Skipping: 029_correct [v4]
# ⏭ Skipping: 029_incorrect [v4]
# ⏭ Skipping: 030_correct [v4]
# ⏭ Skipping: 030_incorrect [v4]
# ⏭ Skipping: 032_correct [v4]
# ⏭ Skipping: 032_incorrect [v4]
# ⏭ Skipping: 036_correct [v4]
# ⏭ Skipping: 036_incorrect [v4]
# ⏭ Skipping: 039_correct [v4]
# ⏭ Skipping: 039_incorrect [v4]
# ⏭ Skipping: 044_correct [v4]
# ⏭ Skipping: 044_incorrect [v4]
# ⏭ Skipping: 047_correct [v4]
# ⏭ Skipping: 047_incorrect [v4]
# ⏭ Skipping: 052_correct [v4]
# ⏭ Skipping: 052_incorrect [v4]
# ⏭ Skipping: 054_correct [v4]
# ⏭ Skipping: 054_incorrect [v4]
# ⏭ Skipping: 055_correct [v4]
# ⏭ Skipping: 055_incorrect [v4]
# ⏭ Skipping: 058_correct [v4]
# ⏭ Skipping: 058_incorrect [v4]
# ⏭ Skipping: 059_correct [v4]
# ⏭ Skipping: 059_incorrect [v4]
# ⏭ Skipping: 063_correct [v4]
# ⏭ Skipping: 063_incorrect [v4]
# ⏭ Skipping: 065_correct [v4]
# ⏭ Skipping: 065_incorrect [v4]
# ⏭ Skipping: 068_correct [v4]
# ⏭ Skipping: 068_incorrect [v4]
# ⏭ Skipping: 069_correct [v4]
# ⏭ Skipping: 069_incorrect [v4]
# ⏭ Skipping: 070_correct [v4]
# ⏭ Skipping: 070_incorrect [v4]
# ⏭ Skipping: 072_correct [v4]
# ⏭ Skipping: 072_incorrect [v4]
# ⏭ Skipping: 076_correct [v4]
# ⏭ Skipping: 076_incorrect [v4]
# ⏭ Skipping: 078_correct [v4]
# ⏭ Skipping: 078_incorrect [v4]
# ⏭ Skipping: 080_correct [v4]
# ⏭ Skipping: 080_incorrect [v4]
# ⏭ Skipping: 082_correct [v4]
# ⏭ Skipping: 082_incorrect [v4]
# ⏭ Skipping: 083_correct [v4]
# ⏭ Skipping: 083_incorrect [v4]
# ⏭ Skipping: 085_correct [v4]
# ⏭ Skipping: 085_incorrect [v4]
# ⏭ Skipping: 087_correct [v4]
# ⏭ Skipping: 087_incorrect [v4]
# ⏭ Skipping: 089_correct [v4]
# ⏭ Skipping: 089_incorrect [v4]
# ⏭ Skipping: 090_correct [v4]
# ⏭ Skipping: 090_incorrect [v4]
# ⏭ Skipping: 091_correct [v4]
# ⏭ Skipping: 091_incorrect [v4]
# ⏭ Skipping: 094_correct [v4]
# ⏭ Skipping: 094_incorrect [v4]
# ⏭ Skipping: 095_correct [v4]
# ⏭ Skipping: 095_incorrect [v4]
# ⏭ Skipping: 096_correct [v4]
# ⏭ Skipping: 096_incorrect [v4]
# ⏭ Skipping: 098_correct [v4]
# ⏭ Skipping: 098_incorrect [v4]
# ⏭ Skipping: 100_correct [v4]
# ⏭ Skipping: 100_incorrect [v4]
#
# ============================================================
# Running: v5
# ============================================================
# ⏭ Skipping: 001_correct [v5]
# ⏭ Skipping: 001_incorrect [v5]
# ⏭ Skipping: 003_correct [v5]
# ⏭ Skipping: 003_incorrect [v5]
# ⏭ Skipping: 004_correct [v5]
# ⏭ Skipping: 004_incorrect [v5]
# ⏭ Skipping: 005_correct [v5]
# ⏭ Skipping: 005_incorrect [v5]
# ⏭ Skipping: 006_correct [v5]
# ⏭ Skipping: 006_incorrect [v5]
# ⏭ Skipping: 007_correct [v5]
# ⏭ Skipping: 007_incorrect [v5]
# ⏭ Skipping: 012_correct [v5]
# ⏭ Skipping: 012_incorrect [v5]
# ⏭ Skipping: 014_correct [v5]
# ⏭ Skipping: 014_incorrect [v5]
# ⏭ Skipping: 015_correct [v5]
# ⏭ Skipping: 015_incorrect [v5]
# ⏭ Skipping: 017_correct [v5]
# ⏭ Skipping: 017_incorrect [v5]
# ⏭ Skipping: 018_correct [v5]
# ⏭ Skipping: 018_incorrect [v5]
# ⏭ Skipping: 020_correct [v5]
# ⏭ Skipping: 020_incorrect [v5]
# ⏭ Skipping: 021_correct [v5]
# ⏭ Skipping: 021_incorrect [v5]
# ⏭ Skipping: 023_correct [v5]
# ⏭ Skipping: 023_incorrect [v5]
# ⏭ Skipping: 025_correct [v5]
# ⏭ Skipping: 025_incorrect [v5]
# ⏭ Skipping: 026_correct [v5]
# ⏭ Skipping: 026_incorrect [v5]
# ⏭ Skipping: 028_correct [v5]
# ⏭ Skipping: 028_incorrect [v5]
# ⏭ Skipping: 029_correct [v5]
# ⏭ Skipping: 029_incorrect [v5]
# ⏭ Skipping: 030_correct [v5]
# ⏭ Skipping: 030_incorrect [v5]
# ⏭ Skipping: 032_correct [v5]
# ⏭ Skipping: 032_incorrect [v5]
# ⏭ Skipping: 036_correct [v5]
# ⏭ Skipping: 036_incorrect [v5]
# ⏭ Skipping: 039_correct [v5]
# ⏭ Skipping: 039_incorrect [v5]
# ⏭ Skipping: 044_correct [v5]
# ⏭ Skipping: 044_incorrect [v5]
# ⏭ Skipping: 047_correct [v5]
# ⏭ Skipping: 047_incorrect [v5]
# ⏭ Skipping: 052_correct [v5]
# ⏭ Skipping: 052_incorrect [v5]
# ⏭ Skipping: 054_correct [v5]
# ⏭ Skipping: 054_incorrect [v5]
# ⏭ Skipping: 055_correct [v5]
# ⏭ Skipping: 055_incorrect [v5]
# ⏭ Skipping: 058_correct [v5]
# ⏭ Skipping: 058_incorrect [v5]
# ⏭ Skipping: 059_correct [v5]
# ⏭ Skipping: 059_incorrect [v5]
# ⏭ Skipping: 063_correct [v5]
# ⏭ Skipping: 063_incorrect [v5]
# ⏭ Skipping: 065_correct [v5]
# ⏭ Skipping: 065_incorrect [v5]
# ⏭ Skipping: 068_correct [v5]
# ⏭ Skipping: 068_incorrect [v5]
# ⏭ Skipping: 069_correct [v5]
# ⏭ Skipping: 069_incorrect [v5]
# ⏭ Skipping: 070_correct [v5]
# ⏭ Skipping: 070_incorrect [v5]
# ⏭ Skipping: 072_correct [v5]
# ⏭ Skipping: 072_incorrect [v5]
# ⏭ Skipping: 076_correct [v5]
# ⏭ Skipping: 076_incorrect [v5]
# ⏭ Skipping: 078_correct [v5]
# ⏭ Skipping: 078_incorrect [v5]
# ⏭ Skipping: 080_correct [v5]
# ⏭ Skipping: 080_incorrect [v5]
# ⏭ Skipping: 082_correct [v5]
# ⏭ Skipping: 082_incorrect [v5]
# ⏭ Skipping: 083_correct [v5]
# ⏭ Skipping: 083_incorrect [v5]
# ⏭ Skipping: 085_correct [v5]
# ⏭ Skipping: 085_incorrect [v5]
# ⏭ Skipping: 087_correct [v5]
# ⏭ Skipping: 087_incorrect [v5]
# ⏭ Skipping: 089_correct [v5]
# ⏭ Skipping: 089_incorrect [v5]
# ⏭ Skipping: 090_correct [v5]
# ⏭ Skipping: 090_incorrect [v5]
# ⏭ Skipping: 091_correct [v5]
# ⏭ Skipping: 091_incorrect [v5]
# ⏭ Skipping: 094_correct [v5]
# ⏭ Skipping: 094_incorrect [v5]
# ⏭ Skipping: 095_correct [v5]
# ⏭ Skipping: 095_incorrect [v5]
# ⏭ Skipping: 096_correct [v5]
# ⏭ Skipping: 096_incorrect [v5]
# ⏭ Skipping: 098_correct [v5]
# ⏭ Skipping: 098_incorrect [v5]
# ⏭ Skipping: 100_correct [v5]
# ⏭ Skipping: 100_incorrect [v5]
#
# ============================================================
# Running: v6
# ============================================================
# ⏭ Skipping: 001_correct [v6]
# ⏭ Skipping: 001_incorrect [v6]
# ⏭ Skipping: 003_correct [v6]
# ⏭ Skipping: 003_incorrect [v6]
# ⏭ Skipping: 004_correct [v6]
# ⏭ Skipping: 004_incorrect [v6]
# ⏭ Skipping: 005_correct [v6]
# ⏭ Skipping: 005_incorrect [v6]
# ⏭ Skipping: 006_correct [v6]
# ⏭ Skipping: 006_incorrect [v6]
# ⏭ Skipping: 007_correct [v6]
# ⏭ Skipping: 007_incorrect [v6]
# ⏭ Skipping: 012_correct [v6]
# ⏭ Skipping: 012_incorrect [v6]
# ⏭ Skipping: 014_correct [v6]
# ⏭ Skipping: 014_incorrect [v6]
# ⏭ Skipping: 015_correct [v6]
# ⏭ Skipping: 015_incorrect [v6]
# ⏭ Skipping: 017_correct [v6]
# ⏭ Skipping: 017_incorrect [v6]
# ⏭ Skipping: 018_correct [v6]
# ⏭ Skipping: 018_incorrect [v6]
# ⏭ Skipping: 020_correct [v6]
# ⏭ Skipping: 020_incorrect [v6]
# ⏭ Skipping: 021_correct [v6]
# ⏭ Skipping: 021_incorrect [v6]
# ⏭ Skipping: 023_correct [v6]
# ⏭ Skipping: 023_incorrect [v6]
# ⏭ Skipping: 025_correct [v6]
# ⏭ Skipping: 025_incorrect [v6]
# ⏭ Skipping: 026_correct [v6]
# ⏭ Skipping: 026_incorrect [v6]
# ⏭ Skipping: 028_correct [v6]
# ⏭ Skipping: 028_incorrect [v6]
# ⏭ Skipping: 029_correct [v6]
# ⏭ Skipping: 029_incorrect [v6]
# ⏭ Skipping: 030_correct [v6]
# ⏭ Skipping: 030_incorrect [v6]
# ⏭ Skipping: 032_correct [v6]
# ⏭ Skipping: 032_incorrect [v6]
# ⏭ Skipping: 036_correct [v6]
# ⏭ Skipping: 036_incorrect [v6]
# ⏭ Skipping: 039_correct [v6]
# ⏭ Skipping: 039_incorrect [v6]
# ⏭ Skipping: 044_correct [v6]
# ⏭ Skipping: 044_incorrect [v6]
# ⏭ Skipping: 047_correct [v6]
# ⏭ Skipping: 047_incorrect [v6]
# ⏭ Skipping: 052_correct [v6]
# ⏭ Skipping: 052_incorrect [v6]
# ⏭ Skipping: 054_correct [v6]
# ⏭ Skipping: 054_incorrect [v6]
# ⏭ Skipping: 055_correct [v6]
# ⏭ Skipping: 055_incorrect [v6]
# ⏭ Skipping: 058_correct [v6]
# ⏭ Skipping: 058_incorrect [v6]
# ⏭ Skipping: 059_correct [v6]
# ⏭ Skipping: 059_incorrect [v6]
# ⏭ Skipping: 063_correct [v6]
# ⏭ Skipping: 063_incorrect [v6]
# ⏭ Skipping: 065_correct [v6]
# ⏭ Skipping: 065_incorrect [v6]
# ⏭ Skipping: 068_correct [v6]
# ⏭ Skipping: 068_incorrect [v6]
# ⏭ Skipping: 069_correct [v6]
# ⏭ Skipping: 069_incorrect [v6]
# ⏭ Skipping: 070_correct [v6]
# ⏭ Skipping: 070_incorrect [v6]
# ⏭ Skipping: 072_correct [v6]
# ⏭ Skipping: 072_incorrect [v6]
# ⏭ Skipping: 076_correct [v6]
# ⏭ Skipping: 076_incorrect [v6]
# ⏭ Skipping: 078_correct [v6]
# ⏭ Skipping: 078_incorrect [v6]
# ⏭ Skipping: 080_correct [v6]
# ⏭ Skipping: 080_incorrect [v6]
# ⏭ Skipping: 082_correct [v6]
# ⏭ Skipping: 082_incorrect [v6]
# ⏭ Skipping: 083_correct [v6]
# ⏭ Skipping: 083_incorrect [v6]
# ⏭ Skipping: 085_correct [v6]
# ⏭ Skipping: 085_incorrect [v6]
# ⏭ Skipping: 087_correct [v6]
# ⏭ Skipping: 087_incorrect [v6]
# ⏭ Skipping: 089_correct [v6]
# ⏭ Skipping: 089_incorrect [v6]
# ⏭ Skipping: 090_correct [v6]
# ⏭ Skipping: 090_incorrect [v6]
# ⏭ Skipping: 091_correct [v6]
# ⏭ Skipping: 091_incorrect [v6]
# ⏭ Skipping: 094_correct [v6]
# ⏭ Skipping: 094_incorrect [v6]
# ⏭ Skipping: 095_correct [v6]
# ⏭ Skipping: 095_incorrect [v6]
# ⏭ Skipping: 096_correct [v6]
# ⏭ Skipping: 096_incorrect [v6]
# ⏭ Skipping: 098_correct [v6]
# ⏭ Skipping: 098_incorrect [v6]
# ⏭ Skipping: 100_correct [v6]
# ⏭ Skipping: 100_incorrect [v6]
#
# ============================================================
# Running: v7_two_call
# ============================================================
# ⏭ Skipping: 001_correct [v7_two_call]
# ⏭ Skipping: 001_incorrect [v7_two_call]
# ⏭ Skipping: 003_correct [v7_two_call]
# ⏭ Skipping: 003_incorrect [v7_two_call]
# ⏭ Skipping: 004_correct [v7_two_call]
# ⏭ Skipping: 004_incorrect [v7_two_call]
# ⏭ Skipping: 005_correct [v7_two_call]
# ⏭ Skipping: 005_incorrect [v7_two_call]
# ⏭ Skipping: 006_correct [v7_two_call]
# ⏭ Skipping: 006_incorrect [v7_two_call]
# ⏭ Skipping: 007_correct [v7_two_call]
# ⏭ Skipping: 007_incorrect [v7_two_call]
# ⏭ Skipping: 012_correct [v7_two_call]
# ⏭ Skipping: 012_incorrect [v7_two_call]
# ⏭ Skipping: 014_correct [v7_two_call]
# ⏭ Skipping: 014_incorrect [v7_two_call]
# ⏭ Skipping: 015_correct [v7_two_call]
# ⏭ Skipping: 015_incorrect [v7_two_call]
# ⏭ Skipping: 017_correct [v7_two_call]
# ⏭ Skipping: 017_incorrect [v7_two_call]
# ⏭ Skipping: 018_correct [v7_two_call]
# ⏭ Skipping: 018_incorrect [v7_two_call]
# ⏭ Skipping: 020_correct [v7_two_call]
# ⏭ Skipping: 020_incorrect [v7_two_call]
# ⏭ Skipping: 021_correct [v7_two_call]
# ⏭ Skipping: 021_incorrect [v7_two_call]
# ⏭ Skipping: 023_correct [v7_two_call]
# ⏭ Skipping: 023_incorrect [v7_two_call]
# ⏭ Skipping: 025_correct [v7_two_call]
# ⏭ Skipping: 025_incorrect [v7_two_call]
# ⏭ Skipping: 026_correct [v7_two_call]
# ⏭ Skipping: 026_incorrect [v7_two_call]
# ⏭ Skipping: 028_correct [v7_two_call]
# ⏭ Skipping: 028_incorrect [v7_two_call]
# ⏭ Skipping: 029_correct [v7_two_call]
# ⏭ Skipping: 029_incorrect [v7_two_call]
# ⏭ Skipping: 030_correct [v7_two_call]
# ⏭ Skipping: 030_incorrect [v7_two_call]
# ⏭ Skipping: 032_correct [v7_two_call]
# ⏭ Skipping: 032_incorrect [v7_two_call]
# ⏭ Skipping: 036_correct [v7_two_call]
# ⏭ Skipping: 036_incorrect [v7_two_call]
# ⏭ Skipping: 039_correct [v7_two_call]
# ⏭ Skipping: 039_incorrect [v7_two_call]
# ⏭ Skipping: 044_correct [v7_two_call]
# ⏭ Skipping: 044_incorrect [v7_two_call]
# ⏭ Skipping: 047_correct [v7_two_call]
# ⏭ Skipping: 047_incorrect [v7_two_call]
# ⏭ Skipping: 052_correct [v7_two_call]
# ⏭ Skipping: 052_incorrect [v7_two_call]
# ⏭ Skipping: 054_correct [v7_two_call]
# ⏭ Skipping: 054_incorrect [v7_two_call]
# ⏭ Skipping: 055_correct [v7_two_call]
# ⏭ Skipping: 055_incorrect [v7_two_call]
# ⏭ Skipping: 058_correct [v7_two_call]
# ⏭ Skipping: 058_incorrect [v7_two_call]
# ⏭ Skipping: 059_correct [v7_two_call]
# ⏭ Skipping: 059_incorrect [v7_two_call]
# ⏭ Skipping: 063_correct [v7_two_call]
# ⏭ Skipping: 063_incorrect [v7_two_call]
# ⏭ Skipping: 065_correct [v7_two_call]
# ⏭ Skipping: 065_incorrect [v7_two_call]
# ⏭ Skipping: 068_correct [v7_two_call]
# ⏭ Skipping: 068_incorrect [v7_two_call]
# ⏭ Skipping: 069_correct [v7_two_call]
# ⏭ Skipping: 069_incorrect [v7_two_call]
# ⏭ Skipping: 070_correct [v7_two_call]
# ⏭ Skipping: 070_incorrect [v7_two_call]
# ⏭ Skipping: 072_correct [v7_two_call]
# ⏭ Skipping: 072_incorrect [v7_two_call]
# ⏭ Skipping: 076_correct [v7_two_call]
# ⏭ Skipping: 076_incorrect [v7_two_call]
# ⏭ Skipping: 078_correct [v7_two_call]
# ⏭ Skipping: 078_incorrect [v7_two_call]
# ⏭ Skipping: 080_correct [v7_two_call]
# ⏭ Skipping: 080_incorrect [v7_two_call]
# ⏭ Skipping: 082_correct [v7_two_call]
# ⏭ Skipping: 082_incorrect [v7_two_call]
# ⏭ Skipping: 083_correct [v7_two_call]
# ⏭ Skipping: 083_incorrect [v7_two_call]
# ⏭ Skipping: 085_correct [v7_two_call]
# ⏭ Skipping: 085_incorrect [v7_two_call]
# ⏭ Skipping: 087_correct [v7_two_call]
# ⏭ Skipping: 087_incorrect [v7_two_call]
# ⏭ Skipping: 089_correct [v7_two_call]
# ⏭ Skipping: 089_incorrect [v7_two_call]
# ⏭ Skipping: 090_correct [v7_two_call]
# ⏭ Skipping: 090_incorrect [v7_two_call]
# ⏭ Skipping: 091_correct [v7_two_call]
# ⏭ Skipping: 091_incorrect [v7_two_call]
# ⏭ Skipping: 094_correct [v7_two_call]
# ⏭ Skipping: 094_incorrect [v7_two_call]
# ⏭ Skipping: 095_correct [v7_two_call]
# ⏭ Skipping: 095_incorrect [v7_two_call]
# ⏭ Skipping: 096_correct [v7_two_call]
# ⏭ Skipping: 096_incorrect [v7_two_call]
# ⏭ Skipping: 098_correct [v7_two_call]
# ⏭ Skipping: 098_incorrect [v7_two_call]
# ⏭ Skipping: 100_correct [v7_two_call]
# ⏭ Skipping: 100_incorrect [v7_two_call]
#
# ============================================================
# Running: v8_two_call
# ============================================================
# ⏭ Skipping: 001_correct [v8_two_call]
# ⏭ Skipping: 001_incorrect [v8_two_call]
# ⏭ Skipping: 003_correct [v8_two_call]
# ⏭ Skipping: 003_incorrect [v8_two_call]
# ⏭ Skipping: 004_correct [v8_two_call]
# ⏭ Skipping: 004_incorrect [v8_two_call]
# ⏭ Skipping: 005_correct [v8_two_call]
# ⏭ Skipping: 005_incorrect [v8_two_call]
# ⏭ Skipping: 006_correct [v8_two_call]
# ⏭ Skipping: 006_incorrect [v8_two_call]
# ⏭ Skipping: 007_correct [v8_two_call]
# ⏭ Skipping: 007_incorrect [v8_two_call]
# ⏭ Skipping: 012_correct [v8_two_call]
# ⏭ Skipping: 012_incorrect [v8_two_call]
# ⏭ Skipping: 014_correct [v8_two_call]
# ⏭ Skipping: 014_incorrect [v8_two_call]
# ⏭ Skipping: 015_correct [v8_two_call]
# ⏭ Skipping: 015_incorrect [v8_two_call]
# ⏭ Skipping: 017_correct [v8_two_call]
# ⏭ Skipping: 017_incorrect [v8_two_call]
# ⏭ Skipping: 018_correct [v8_two_call]
# ⏭ Skipping: 018_incorrect [v8_two_call]
# ⏭ Skipping: 020_correct [v8_two_call]
# ⏭ Skipping: 020_incorrect [v8_two_call]
# ⏭ Skipping: 021_correct [v8_two_call]
# ⏭ Skipping: 021_incorrect [v8_two_call]
# ⏭ Skipping: 023_correct [v8_two_call]
# ⏭ Skipping: 023_incorrect [v8_two_call]
# ⏭ Skipping: 025_correct [v8_two_call]
# ⏭ Skipping: 025_incorrect [v8_two_call]
# ⏭ Skipping: 026_correct [v8_two_call]
# ⏭ Skipping: 026_incorrect [v8_two_call]
# ⏭ Skipping: 028_correct [v8_two_call]
# ⏭ Skipping: 028_incorrect [v8_two_call]
# ⏭ Skipping: 029_correct [v8_two_call]
# ⏭ Skipping: 029_incorrect [v8_two_call]
# ⏭ Skipping: 030_correct [v8_two_call]
# ⏭ Skipping: 030_incorrect [v8_two_call]
# ⏭ Skipping: 032_correct [v8_two_call]
# ⏭ Skipping: 032_incorrect [v8_two_call]
# ⏭ Skipping: 036_correct [v8_two_call]
# ⏭ Skipping: 036_incorrect [v8_two_call]
# ⏭ Skipping: 039_correct [v8_two_call]
# ⏭ Skipping: 039_incorrect [v8_two_call]
# ⏭ Skipping: 044_correct [v8_two_call]
# ⏭ Skipping: 044_incorrect [v8_two_call]
# ⏭ Skipping: 047_correct [v8_two_call]
# ⏭ Skipping: 047_incorrect [v8_two_call]
# ⏭ Skipping: 052_correct [v8_two_call]
# ⏭ Skipping: 052_incorrect [v8_two_call]
# ⏭ Skipping: 054_correct [v8_two_call]
# ⏭ Skipping: 054_incorrect [v8_two_call]
# ⏭ Skipping: 055_correct [v8_two_call]
# ⏭ Skipping: 055_incorrect [v8_two_call]
# ⏭ Skipping: 058_correct [v8_two_call]
# ⏭ Skipping: 058_incorrect [v8_two_call]
# ⏭ Skipping: 059_correct [v8_two_call]
# ⏭ Skipping: 059_incorrect [v8_two_call]
# ⏭ Skipping: 063_correct [v8_two_call]
# ⏭ Skipping: 063_incorrect [v8_two_call]
# ⏭ Skipping: 065_correct [v8_two_call]
# ⏭ Skipping: 065_incorrect [v8_two_call]
# ⏭ Skipping: 068_correct [v8_two_call]
# ⏭ Skipping: 068_incorrect [v8_two_call]
# ⏭ Skipping: 069_correct [v8_two_call]
# ⏭ Skipping: 069_incorrect [v8_two_call]
# ⏭ Skipping: 070_correct [v8_two_call]
# ⏭ Skipping: 070_incorrect [v8_two_call]
# ⏭ Skipping: 072_correct [v8_two_call]
# ⏭ Skipping: 072_incorrect [v8_two_call]
# ⏭ Skipping: 076_correct [v8_two_call]
# ⏭ Skipping: 076_incorrect [v8_two_call]
# ⏭ Skipping: 078_correct [v8_two_call]
# ⏭ Skipping: 078_incorrect [v8_two_call]
# ⏭ Skipping: 080_correct [v8_two_call]
# ⏭ Skipping: 080_incorrect [v8_two_call]
# ⏭ Skipping: 082_correct [v8_two_call]
# ⏭ Skipping: 082_incorrect [v8_two_call]
# ⏭ Skipping: 083_correct [v8_two_call]
# ⏭ Skipping: 083_incorrect [v8_two_call]
# ⏭ Skipping: 085_correct [v8_two_call]
# ⏭ Skipping: 085_incorrect [v8_two_call]
# ⏭ Skipping: 087_correct [v8_two_call]
# ⏭ Skipping: 087_incorrect [v8_two_call]
# ⏭ Skipping: 089_correct [v8_two_call]
# ⏭ Skipping: 089_incorrect [v8_two_call]
# ⏭ Skipping: 090_correct [v8_two_call]
# ⏭ Skipping: 090_incorrect [v8_two_call]
# ⏭ Skipping: 091_correct [v8_two_call]
# ⏭ Skipping: 091_incorrect [v8_two_call]
# ⏭ Skipping: 094_correct [v8_two_call]
# ⏭ Skipping: 094_incorrect [v8_two_call]
# ⏭ Skipping: 095_correct [v8_two_call]
# ⏭ Skipping: 095_incorrect [v8_two_call]
# ⏭ Skipping: 096_correct [v8_two_call]
# ⏭ Skipping: 096_incorrect [v8_two_call]
# ⏭ Skipping: 098_correct [v8_two_call]
# ⏭ Skipping: 098_incorrect [v8_two_call]
# ⏭ Skipping: 100_correct [v8_two_call]
# ⏭ Skipping: 100_incorrect [v8_two_call]
#
# ============================================================
# Running: v9_two_call
# ============================================================
# ⏭ Skipping: 001_correct [v9_two_call]
# ⏭ Skipping: 001_incorrect [v9_two_call]
# ⏭ Skipping: 003_correct [v9_two_call]
# ⏭ Skipping: 003_incorrect [v9_two_call]
# ⏭ Skipping: 004_correct [v9_two_call]
# ⏭ Skipping: 004_incorrect [v9_two_call]
# ⏭ Skipping: 005_correct [v9_two_call]
# ⏭ Skipping: 005_incorrect [v9_two_call]
# ⏭ Skipping: 006_correct [v9_two_call]
# ⏭ Skipping: 006_incorrect [v9_two_call]
# ⏭ Skipping: 007_correct [v9_two_call]
# ⏭ Skipping: 007_incorrect [v9_two_call]
# ⏭ Skipping: 012_correct [v9_two_call]
# ⏭ Skipping: 012_incorrect [v9_two_call]
# ⏭ Skipping: 014_correct [v9_two_call]
# ⏭ Skipping: 014_incorrect [v9_two_call]
# ⏭ Skipping: 015_correct [v9_two_call]
# ⏭ Skipping: 015_incorrect [v9_two_call]
# ⏭ Skipping: 017_correct [v9_two_call]
# ⏭ Skipping: 017_incorrect [v9_two_call]
# ⏭ Skipping: 018_correct [v9_two_call]
# ⏭ Skipping: 018_incorrect [v9_two_call]
# ⏭ Skipping: 020_correct [v9_two_call]
# ⏭ Skipping: 020_incorrect [v9_two_call]
# ⏭ Skipping: 021_correct [v9_two_call]
# ⏭ Skipping: 021_incorrect [v9_two_call]
# ⏭ Skipping: 023_correct [v9_two_call]
# ⏭ Skipping: 023_incorrect [v9_two_call]
# ⏭ Skipping: 025_correct [v9_two_call]
# ⏭ Skipping: 025_incorrect [v9_two_call]
# ⏭ Skipping: 026_correct [v9_two_call]
# ⏭ Skipping: 026_incorrect [v9_two_call]
# ⏭ Skipping: 028_correct [v9_two_call]
# ⏭ Skipping: 028_incorrect [v9_two_call]
# ⏭ Skipping: 029_correct [v9_two_call]
# ⏭ Skipping: 029_incorrect [v9_two_call]
# ⏭ Skipping: 030_correct [v9_two_call]
# ⏭ Skipping: 030_incorrect [v9_two_call]
# ⏭ Skipping: 032_correct [v9_two_call]
# ⏭ Skipping: 032_incorrect [v9_two_call]
# ⏭ Skipping: 036_correct [v9_two_call]
# ⏭ Skipping: 036_incorrect [v9_two_call]
# ⏭ Skipping: 039_correct [v9_two_call]
# ⏭ Skipping: 039_incorrect [v9_two_call]
# ⏭ Skipping: 044_correct [v9_two_call]
# ⏭ Skipping: 044_incorrect [v9_two_call]
# ⏭ Skipping: 047_correct [v9_two_call]
# ⏭ Skipping: 047_incorrect [v9_two_call]
# ⏭ Skipping: 052_correct [v9_two_call]
# ⏭ Skipping: 052_incorrect [v9_two_call]
# ⏭ Skipping: 054_correct [v9_two_call]
# ⏭ Skipping: 054_incorrect [v9_two_call]
# ⏭ Skipping: 055_correct [v9_two_call]
# ⏭ Skipping: 055_incorrect [v9_two_call]
# ⏭ Skipping: 058_correct [v9_two_call]
# ⏭ Skipping: 058_incorrect [v9_two_call]
# ⏭ Skipping: 059_correct [v9_two_call]
# ⏭ Skipping: 059_incorrect [v9_two_call]
# ⏭ Skipping: 063_correct [v9_two_call]
# ⏭ Skipping: 063_incorrect [v9_two_call]
# ⏭ Skipping: 065_correct [v9_two_call]
# ⏭ Skipping: 065_incorrect [v9_two_call]
# ⏭ Skipping: 068_correct [v9_two_call]
# ⏭ Skipping: 068_incorrect [v9_two_call]
# ⏭ Skipping: 069_correct [v9_two_call]
# ⏭ Skipping: 069_incorrect [v9_two_call]
# ⏭ Skipping: 070_correct [v9_two_call]
# ⏭ Skipping: 070_incorrect [v9_two_call]
# ⏭ Skipping: 072_correct [v9_two_call]
# ⏭ Skipping: 072_incorrect [v9_two_call]
# ⏭ Skipping: 076_correct [v9_two_call]
# ⏭ Skipping: 076_incorrect [v9_two_call]
# ⏭ Skipping: 078_correct [v9_two_call]
# ⏭ Skipping: 078_incorrect [v9_two_call]
# ⏭ Skipping: 080_correct [v9_two_call]
# ⏭ Skipping: 080_incorrect [v9_two_call]
# ⏭ Skipping: 082_correct [v9_two_call]
# ⏭ Skipping: 082_incorrect [v9_two_call]
# ⏭ Skipping: 083_correct [v9_two_call]
# ⏭ Skipping: 083_incorrect [v9_two_call]
# ⏭ Skipping: 085_correct [v9_two_call]
# ⏭ Skipping: 085_incorrect [v9_two_call]
# ⏭ Skipping: 087_correct [v9_two_call]
# ⏭ Skipping: 087_incorrect [v9_two_call]
# ⏭ Skipping: 089_correct [v9_two_call]
# ⏭ Skipping: 089_incorrect [v9_two_call]
# ⏭ Skipping: 090_correct [v9_two_call]
# ⏭ Skipping: 090_incorrect [v9_two_call]
# ⏭ Skipping: 091_correct [v9_two_call]
# ⏭ Skipping: 091_incorrect [v9_two_call]
# ⏭ Skipping: 094_correct [v9_two_call]
# ⏭ Skipping: 094_incorrect [v9_two_call]
# ⏭ Skipping: 095_correct [v9_two_call]
# ⏭ Skipping: 095_incorrect [v9_two_call]
# ⏭ Skipping: 096_correct [v9_two_call]
# ⏭ Skipping: 096_incorrect [v9_two_call]
# ⏭ Skipping: 098_correct [v9_two_call]
# ⏭ Skipping: 098_incorrect [v9_two_call]
# ⏭ Skipping: 100_correct [v9_two_call]
# ⏭ Skipping: 100_incorrect [v9_two_call]
#
# ✅ All remy-ashford versions complete.

# %%
from utils.quanti_benchmarking_2_analysis import run_accuracy_analysis

BASE_DIR = Path().resolve()
MODEL_NAME = "qwen3-8b-vl"
EXPERIMENT_NAME = "test-2-gn-claim-only"
run_accuracy_analysis(BASE_DIR, EXPERIMENT_NAME, MODEL_NAME)
# Out:
# ============================================================
# Prompt Version : v1
# Prompt Text    : Does the text in the post accurately describe the chart? Reply with only 'correct' or 'incorrect'.
# ============================================================
# === Overall Summary ===
#                        metric  value
# 0          overall_accuracy_%   69.0
# 1    accuracy_correct_posts_%   38.0
# 2  accuracy_incorrect_posts_%  100.0
# === Per Image Results ===
#             image ground_truth prediction  correct
# 0     001_correct      correct  incorrect    False
# 1   001_incorrect    incorrect  incorrect     True
# 2     003_correct      correct  incorrect    False
# 3   003_incorrect    incorrect  incorrect     True
# 4     004_correct      correct    correct     True
# ..            ...          ...        ...      ...
# 95  096_incorrect    incorrect  incorrect     True
# 96    098_correct      correct  incorrect    False
# 97  098_incorrect    incorrect  incorrect     True
# 98    100_correct      correct    correct     True
# 99  100_incorrect    incorrect  incorrect     True
#
# [100 rows x 4 columns]
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-2-gn-claim-only/v1/accuracy_scores_v1.csv
#
# ============================================================
# Prompt Version : v2
# Prompt Text    : Read the text in the post and look at the chart. Does the text correctly describe what the chart shows? Reply with only 'correct' or 'incorrect'.
# ============================================================
# === Overall Summary ===
#                        metric  value
# 0          overall_accuracy_%   79.0
# 1    accuracy_correct_posts_%   58.0
# 2  accuracy_incorrect_posts_%  100.0
# === Per Image Results ===
#             image ground_truth prediction  correct
# 0     001_correct      correct  incorrect    False
# 1   001_incorrect    incorrect  incorrect     True
# 2     003_correct      correct    correct     True
# 3   003_incorrect    incorrect  incorrect     True
# 4     004_correct      correct    correct     True
# ..            ...          ...        ...      ...
# 95  096_incorrect    incorrect  incorrect     True
# 96    098_correct      correct  incorrect    False
# 97  098_incorrect    incorrect  incorrect     True
# 98    100_correct      correct    correct     True
# 99  100_incorrect    incorrect  incorrect     True
#
# [100 rows x 4 columns]
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-2-gn-claim-only/v2/accuracy_scores_v2.csv
#
# ============================================================
# Prompt Version : v3
# Prompt Text    : The post text claims one music genre is more popular than another. Look at the percentage values in the chart to verify this claim. If the genre described as more popular in the text has a higher percentage in the chart, reply 'correct'. If not, reply 'incorrect'.
# ============================================================
# === Overall Summary ===
#                        metric  value
# 0          overall_accuracy_%   90.0
# 1    accuracy_correct_posts_%   80.0
# 2  accuracy_incorrect_posts_%  100.0
# === Per Image Results ===
#             image ground_truth prediction  correct
# 0     001_correct      correct  incorrect    False
# 1   001_incorrect    incorrect  incorrect     True
# 2     003_correct      correct    correct     True
# 3   003_incorrect    incorrect  incorrect     True
# 4     004_correct      correct    correct     True
# ..            ...          ...        ...      ...
# 95  096_incorrect    incorrect  incorrect     True
# 96    098_correct      correct  incorrect    False
# 97  098_incorrect    incorrect  incorrect     True
# 98    100_correct      correct    correct     True
# 99  100_incorrect    incorrect  incorrect     True
#
# [100 rows x 4 columns]
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-2-gn-claim-only/v3/accuracy_scores_v3.csv
#
# ============================================================
# Prompt Version : v4
# Prompt Text    : In the post, the text above the image makes a claim comparing the popularity of Pop and Latin. Identify the according values in the chart to verify this claim. If the claim matches the visualization reply 'correct'. If not, reply 'incorrect'.
# ============================================================
# === Overall Summary ===
#                        metric  value
# 0          overall_accuracy_%   98.0
# 1    accuracy_correct_posts_%   96.0
# 2  accuracy_incorrect_posts_%  100.0
# === Per Image Results ===
#             image ground_truth prediction  correct
# 0     001_correct      correct  incorrect    False
# 1   001_incorrect    incorrect  incorrect     True
# 2     003_correct      correct    correct     True
# 3   003_incorrect    incorrect  incorrect     True
# 4     004_correct      correct    correct     True
# ..            ...          ...        ...      ...
# 95  096_incorrect    incorrect  incorrect     True
# 96    098_correct      correct    correct     True
# 97  098_incorrect    incorrect  incorrect     True
# 98    100_correct      correct    correct     True
# 99  100_incorrect    incorrect  incorrect     True
#
# [100 rows x 4 columns]
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-2-gn-claim-only/v4/accuracy_scores_v4.csv
#
# ============================================================
# Prompt Version : v5
# Prompt Text    : In the post, the text above the chart claims one genre is more popular than another. Find the percentage for Pop and the percentage for Latin in the chart. If the genre the text says is more popular has a numerically higher percentage, reply 'correct'. If not, reply 'incorrect'.
# ============================================================
# === Overall Summary ===
#                        metric  value
# 0          overall_accuracy_%   40.0
# 1    accuracy_correct_posts_%   78.0
# 2  accuracy_incorrect_posts_%    2.0
# === Per Image Results ===
#             image ground_truth  \
# 0     001_correct      correct
# 1   001_incorrect    incorrect
# 2     003_correct      correct
# 3   003_incorrect    incorrect
# 4     004_correct      correct
# ..            ...          ...
# 95  096_incorrect    incorrect
# 96    098_correct      correct
# 97  098_incorrect    incorrect
# 98    100_correct      correct
# 99  100_incorrect    incorrect
#
#                                            prediction  correct
# 0   the text claims that pop was more popular than...    False
# 1   the text claims that "latin was more popular t...    False
# 2                                             correct     True
# 3   the text above the chart claims: "looks like l...    False
# 4                                             correct     True
# ..                                                ...      ...
# 95  the text claims that "latin was more popular t...    False
# 96                                            correct     True
# 97  the text claims that "latin was more popular t...    False
# 98                                            correct     True
# 99  the text claims that "latin was more popular t...    False
#
# [100 rows x 4 columns]
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-2-gn-claim-only/v5/accuracy_scores_v5.csv
#
# ============================================================
# Prompt Version : v6
# Prompt Text    : Look at the text above the chart. It makes a claim about Pop and Latin popularity. Step 1: find the percentage value for Pop in the chart. Step 2: find the percentage value for Latin in the chart. Step 3: check if the claim in the text matches which one is higher. If it matches, reply 'correct'. If not, reply 'incorrect'.
# ============================================================
# === Overall Summary ===
#                        metric  value
# 0          overall_accuracy_%    1.0
# 1    accuracy_correct_posts_%    0.0
# 2  accuracy_incorrect_posts_%    2.0
# === Per Image Results ===
#             image ground_truth  \
# 0     001_correct      correct
# 1   001_incorrect    incorrect
# 2     003_correct      correct
# 3   003_incorrect    incorrect
# 4     004_correct      correct
# ..            ...          ...
# 95  096_incorrect    incorrect
# 96    098_correct      correct
# 97  098_incorrect    incorrect
# 98    100_correct      correct
# 99  100_incorrect    incorrect
#
#                                            prediction  correct
# 0   step 1: the percentage value for pop in the ch...    False
# 1   step 1: the percentage value for pop in the ch...    False
# 2   step 1: the percentage value for pop in the ch...    False
# 3   step 1: the percentage value for pop in the ch...    False
# 4   step 1: the percentage value for pop in the ch...    False
# ..                                                ...      ...
# 95  step 1: the percentage value for pop in the ch...    False
# 96  step 1: the percentage value for pop in the ch...    False
# 97  step 1: the percentage value for pop in the ch...    False
# 98  step 1: the percentage value for pop in the ch...    False
# 99  step 1: the percentage value for pop in the ch...    False
#
# [100 rows x 4 columns]
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-2-gn-claim-only/v6/accuracy_scores_v6.csv
#
# ============================================================
# Prompt Version : v7_two_call
# Prompt Text    : The chart shows Pop at 23.5% and Latin at 11.0%. The post text says 'Looks like Pop was more popular than Latin this year!'. Based only on these numbers, is the claim correct? Reply with only 'correct' or 'incorrect'.
# ============================================================
# === Overall Summary ===
#                        metric  value
# 0          overall_accuracy_%  100.0
# 1    accuracy_correct_posts_%  100.0
# 2  accuracy_incorrect_posts_%  100.0
# === Per Image Results ===
#             image ground_truth prediction  correct
# 0     001_correct      correct    correct     True
# 1   001_incorrect    incorrect  incorrect     True
# 2     003_correct      correct    correct     True
# 3   003_incorrect    incorrect  incorrect     True
# 4     004_correct      correct    correct     True
# ..            ...          ...        ...      ...
# 95  096_incorrect    incorrect  incorrect     True
# 96    098_correct      correct    correct     True
# 97  098_incorrect    incorrect  incorrect     True
# 98    100_correct      correct    correct     True
# 99  100_incorrect    incorrect  incorrect     True
#
# [100 rows x 4 columns]
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-2-gn-claim-only/v7_two_call/accuracy_scores_v7_two_call.csv
#
# ============================================================
# Prompt Version : v8_two_call
# Prompt Text    : Pop: 23.5%. Latin: 11.0%. The post claims: 'Looks like Pop was more popular than Latin this year!'. Does the claim match which percentage is higher? Reply with only 'correct' or 'incorrect'.
# ============================================================
# === Overall Summary ===
#                        metric  value
# 0          overall_accuracy_%  100.0
# 1    accuracy_correct_posts_%  100.0
# 2  accuracy_incorrect_posts_%  100.0
# === Per Image Results ===
#             image ground_truth prediction  correct
# 0     001_correct      correct    correct     True
# 1   001_incorrect    incorrect  incorrect     True
# 2     003_correct      correct    correct     True
# 3   003_incorrect    incorrect  incorrect     True
# 4     004_correct      correct    correct     True
# ..            ...          ...        ...      ...
# 95  096_incorrect    incorrect  incorrect     True
# 96    098_correct      correct    correct     True
# 97  098_incorrect    incorrect  incorrect     True
# 98    100_correct      correct    correct     True
# 99  100_incorrect    incorrect  incorrect     True
#
# [100 rows x 4 columns]
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-2-gn-claim-only/v8_two_call/accuracy_scores_v8_two_call.csv
#
# ============================================================
# Prompt Version : v9_two_call
# Prompt Text    : Given Pop = 23.5% and Latin = 11.0%, is the following statement true or false: 'Looks like Pop was more popular than Latin this year!'. Reply with only 'correct' or 'incorrect'.
# ============================================================
# === Overall Summary ===
#                        metric  value
# 0          overall_accuracy_%  100.0
# 1    accuracy_correct_posts_%  100.0
# 2  accuracy_incorrect_posts_%  100.0
# === Per Image Results ===
#             image ground_truth prediction  correct
# 0     001_correct      correct    correct     True
# 1   001_incorrect    incorrect  incorrect     True
# 2     003_correct      correct    correct     True
# 3   003_incorrect    incorrect  incorrect     True
# 4     004_correct      correct    correct     True
# ..            ...          ...        ...      ...
# 95  096_incorrect    incorrect  incorrect     True
# 96    098_correct      correct    correct     True
# 97  098_incorrect    incorrect  incorrect     True
# 98    100_correct      correct    correct     True
# 99  100_incorrect    incorrect  incorrect     True
#
# [100 rows x 4 columns]
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-2-gn-claim-only/v9_two_call/accuracy_scores_v9_two_call.csv

# %% [markdown]
# ## 3) Ask about nr in pie charts - both genres - 100 - 50/50
# - Reusing all_images from prevous benchmark, in other words, using the same 50 pairs used for previous benchmark
#
# **Why**
# - Direct comparability: if test 2 (claim verification) and test 3 (percentage reading) use the same images, we can link results. For example: "the model read the percentages correctly on image 042 but still got the claim wrong": that's a meaningful finding about where reasoning breaks down.
# - Controls for image variability: if the sets differ, a performance difference between tests could be due to one set happening to have easier images rather than the task itself being easier.
# - Cleaner narrative

# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent))
from utils.quanti_benchmarking_3_percentages import (
    benchmark_image_percentages, output_exists_json, ask_question
)

# --- Configuration ---
BASE_DIR = Path().resolve()
EXPERIMENT_NAME = "test-3-gn-percentages"
MODEL_NAME = "qwen3-vl-8b"
ASK_FN = ask_question_gemma

# --- Run ---
print(f"\n{'='*60}")
print("Running test-3: percentage extraction")
print(f"{'='*60}")
for image_name, image_path in all_images:
    if output_exists_json(image_name, BASE_DIR, EXPERIMENT_NAME, MODEL_NAME):
        print(f"⏭ Skipping: {image_name}")
        continue
    benchmark_image_percentages(image_path, image_name, model, processor, device, BASE_DIR, EXPERIMENT_NAME, MODEL_NAME, ASK_FN)
print("\n✅ Test 3 complete.")
# Out:
# ============================================================
# Running test-3: percentage extraction
# ============================================================
# ⏭ Skipping: 001_correct
# ⏭ Skipping: 001_incorrect
# ⏭ Skipping: 003_correct
# ⏭ Skipping: 003_incorrect
# ⏭ Skipping: 004_correct
# ⏭ Skipping: 004_incorrect
# ⏭ Skipping: 005_correct
# ⏭ Skipping: 005_incorrect
# ⏭ Skipping: 006_correct
# ⏭ Skipping: 006_incorrect
# ⏭ Skipping: 007_correct
# ⏭ Skipping: 007_incorrect
# ⏭ Skipping: 012_correct
# ⏭ Skipping: 012_incorrect
# ⏭ Skipping: 014_correct
# ⏭ Skipping: 014_incorrect
# ⏭ Skipping: 015_correct
# ⏭ Skipping: 015_incorrect
# ⏭ Skipping: 017_correct
# ⏭ Skipping: 017_incorrect
# ⏭ Skipping: 018_correct
# ⏭ Skipping: 018_incorrect
# ⏭ Skipping: 020_correct
# ⏭ Skipping: 020_incorrect
# ⏭ Skipping: 021_correct
# ⏭ Skipping: 021_incorrect
# ⏭ Skipping: 023_correct
# ⏭ Skipping: 023_incorrect
# ⏭ Skipping: 025_correct
# ⏭ Skipping: 025_incorrect
# ⏭ Skipping: 026_correct
# ⏭ Skipping: 026_incorrect
# ⏭ Skipping: 028_correct
# ⏭ Skipping: 028_incorrect
# ⏭ Skipping: 029_correct
# ⏭ Skipping: 029_incorrect
# ⏭ Skipping: 030_correct
# ⏭ Skipping: 030_incorrect
# ⏭ Skipping: 032_correct
# ⏭ Skipping: 032_incorrect
# ⏭ Skipping: 036_correct
# ⏭ Skipping: 036_incorrect
# ⏭ Skipping: 039_correct
# ⏭ Skipping: 039_incorrect
# ⏭ Skipping: 044_correct
# ⏭ Skipping: 044_incorrect
# ⏭ Skipping: 047_correct
# ⏭ Skipping: 047_incorrect
# ⏭ Skipping: 052_correct
# ⏭ Skipping: 052_incorrect
# ⏭ Skipping: 054_correct
# ⏭ Skipping: 054_incorrect
# ⏭ Skipping: 055_correct
# ⏭ Skipping: 055_incorrect
# ⏭ Skipping: 058_correct
# ⏭ Skipping: 058_incorrect
# ⏭ Skipping: 059_correct
# ⏭ Skipping: 059_incorrect
# ⏭ Skipping: 063_correct
# ⏭ Skipping: 063_incorrect
# ⏭ Skipping: 065_correct
# ⏭ Skipping: 065_incorrect
# ⏭ Skipping: 068_correct
# ⏭ Skipping: 068_incorrect
# ⏭ Skipping: 069_correct
# ⏭ Skipping: 069_incorrect
# ⏭ Skipping: 070_correct
# ⏭ Skipping: 070_incorrect
# ⏭ Skipping: 072_correct
# ⏭ Skipping: 072_incorrect
# ⏭ Skipping: 076_correct
# ⏭ Skipping: 076_incorrect
# ⏭ Skipping: 078_correct
# ⏭ Skipping: 078_incorrect
# ⏭ Skipping: 080_correct
# ⏭ Skipping: 080_incorrect
# ⏭ Skipping: 082_correct
# ⏭ Skipping: 082_incorrect
# ⏭ Skipping: 083_correct
# ⏭ Skipping: 083_incorrect
# ⏭ Skipping: 085_correct
# ⏭ Skipping: 085_incorrect
# ⏭ Skipping: 087_correct
# ⏭ Skipping: 087_incorrect
# ⏭ Skipping: 089_correct
# ⏭ Skipping: 089_incorrect
# ⏭ Skipping: 090_correct
# ⏭ Skipping: 090_incorrect
# ⏭ Skipping: 091_correct
# ⏭ Skipping: 091_incorrect
# ⏭ Skipping: 094_correct
# ⏭ Skipping: 094_incorrect
# ⏭ Skipping: 095_correct
# ⏭ Skipping: 095_incorrect
# ⏭ Skipping: 096_correct
# ⏭ Skipping: 096_incorrect
# ⏭ Skipping: 098_correct
# ⏭ Skipping: 098_incorrect
# ⏭ Skipping: 100_correct
# ⏭ Skipping: 100_incorrect
#
# ✅ Test 3 complete.

# %%
from utils.quanti_benchmarking_3_analysis import run_accuracy_analysis
BASE_DIR = Path().resolve()
EXPERIMENT_NAME = "test-3-gn-percentages"
MODEL_NAME = "qwen3-8b-vl"
run_accuracy_analysis(BASE_DIR, EXPERIMENT_NAME, MODEL_NAME)
# Out:
# === Overall Summary ===
#                                metric  value
# 0                      pop_accuracy_%  100.0
# 1                    latin_accuracy_%  100.0
# 2                      both_correct_%  100.0
# 3      pop_accuracy_correct_variant_%  100.0
# 4    pop_accuracy_incorrect_variant_%  100.0
# 5    latin_accuracy_correct_variant_%  100.0
# 6  latin_accuracy_incorrect_variant_%  100.0
# === Per Image Results ===
#             image    variant chart_percentages_pop_pred  \
# 0     001_correct    correct                       23.5
# 1   001_incorrect  incorrect                       23.5
# 2     003_correct    correct                       23.5
# 3   003_incorrect  incorrect                       23.5
# 4     004_correct    correct                       23.5
# ..            ...        ...                        ...
# 95  096_incorrect  incorrect                       23.5
# 96    098_correct    correct                       23.5
# 97  098_incorrect  incorrect                       23.5
# 98    100_correct    correct                       23.5
# 99  100_incorrect  incorrect                       23.5
#
#    chart_percentages_pop_true  chart_percentages_pop_correct  \
# 0                        23.5                           True
# 1                        23.5                           True
# 2                        23.5                           True
# 3                        23.5                           True
# 4                        23.5                           True
# ..                        ...                            ...
# 95                       23.5                           True
# 96                       23.5                           True
# 97                       23.5                           True
# 98                       23.5                           True
# 99                       23.5                           True
#
#    chart_percentages_latin_pred chart_percentages_latin_true  \
# 0                            11                           11
# 1                            11                           11
# 2                            11                           11
# 3                            11                           11
# 4                            11                           11
# ..                          ...                          ...
# 95                           11                           11
# 96                           11                           11
# 97                           11                           11
# 98                           11                           11
# 99                           11                           11
#
#     chart_percentages_latin_correct
# 0                              True
# 1                              True
# 2                              True
# 3                              True
# 4                              True
# ..                              ...
# 95                             True
# 96                             True
# 97                             True
# 98                             True
# 99                             True
#
# [100 rows x 8 columns]
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-3-gn-percentages/accuracy_scores_test-3-gn-percentages.csv

# %% [markdown]
# ## 4) Nr of reactions - cover all reactions - equally distributed (will probably keep out because unrealistic)
# Does the overall volume of engagement metrics influence the model's claim verification accuracy, independent of reaction type distribution?
#
# By keeping all reactions equal we are controlling for reaction type bias because the model can't be swayed by seeing mostly angry vs mostly love reactions.

# %%
#!unzip correct/remy-ashford/correct_uniform.zip -d correct/remy-ashford/metrics/uniform
#!unzip incorrect/remy-ashford/incorrect_uniform.zip -d incorrect/remy-ashford/metrics/uniform
# Out:
# Archive:  correct/remy-ashford/correct.zip
#    creating: correct/remy-ashford/metrics/10/
#    creating: correct/remy-ashford/metrics/100/
#    creating: correct/remy-ashford/metrics/1000/
#    creating: correct/remy-ashford/metrics/10000/
#    creating: correct/remy-ashford/metrics/100000/
#    creating: correct/remy-ashford/metrics/1000000/
#   inflating: correct/remy-ashford/metrics/10/052_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/003_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/080_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/073_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/022_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/010_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/041_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/093_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/031_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/060_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/074_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/025_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/087_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/055_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/004_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/098_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/036_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/008_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/067_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/059_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/094_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/029_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/017_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/078_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/046_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/001_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/050_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/082_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/020_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/071_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/043_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/012_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/091_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/062_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/033_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/027_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/019_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/076_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/048_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/085_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/038_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/006_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/069_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/057_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/065_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/034_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/096_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/044_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/015_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/089_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/039_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/007_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/068_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/056_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/026_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/018_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/077_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/049_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/084_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/045_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/014_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/088_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/064_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/035_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/097_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/083_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/021_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/070_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/051_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/090_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/063_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/032_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/042_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/013_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/054_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/005_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/099_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/075_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/024_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/086_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/028_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/016_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/079_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/047_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/037_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/009_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/066_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/058_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/095_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/100_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/081_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/072_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/023_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/053_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/002_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/092_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/030_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/061_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/011_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10/040_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/018_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/026_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/049_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/077_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/084_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/007_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/039_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/056_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/068_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/064_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/035_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/097_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/045_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/014_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/088_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/051_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/083_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/021_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/070_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/042_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/013_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/090_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/063_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/032_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/075_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/024_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/086_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/054_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/005_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/099_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/009_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/037_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/058_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/066_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/095_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/016_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/028_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/047_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/079_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/053_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/002_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/100_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/081_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/072_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/023_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/011_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/040_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/092_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/030_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/061_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/080_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/073_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/022_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/052_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/003_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/093_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/031_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/060_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/010_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/041_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/055_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/004_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/098_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/074_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/025_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/087_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/017_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/029_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/046_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/078_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/008_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/036_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/059_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/067_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/094_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/082_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/020_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/071_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/001_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/050_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/091_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/062_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/033_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/043_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/012_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/006_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/038_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/057_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/069_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/019_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/027_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/048_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/076_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/085_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/044_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/015_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/089_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/065_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/034_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/10000/096_remy_ashford_c.png
#    creating: correct/remy-ashford/metrics/100000/.ipynb_checkpoints/
#   inflating: correct/remy-ashford/metrics/100000/063_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/032_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/090_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/042_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/013_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/021_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/070_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/083_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/051_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/088_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/045_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/014_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/097_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/064_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/035_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/007_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/039_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/056_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/068_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/084_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/018_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/026_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/049_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/077_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/030_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/061_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/092_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/011_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/040_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/072_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/023_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/100_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/081_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/053_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/002_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/016_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/028_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/047_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/079_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/095_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/009_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/037_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/058_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/066_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/099_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/054_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/005_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/086_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/075_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/024_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/094_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/008_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/036_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/059_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/067_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/017_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/029_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/046_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/078_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/087_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/074_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/025_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/098_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/055_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/004_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/010_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/041_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/031_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/060_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/093_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/052_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/003_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/073_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/022_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/080_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/096_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/065_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/034_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/089_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/044_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/015_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/085_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/019_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/027_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/048_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/076_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/006_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/038_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/057_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/069_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/043_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/012_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/062_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/033_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/091_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/001_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/050_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/020_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/071_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/082_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100000/.ipynb_checkpoints/005_remy_ashford_c-checkpoint.png
#   inflating: correct/remy-ashford/metrics/100/010_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/041_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/093_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/031_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/060_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/052_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/003_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/080_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/073_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/022_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/036_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/008_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/067_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/059_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/094_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/029_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/017_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/078_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/046_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/074_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/025_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/087_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/055_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/004_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/098_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/043_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/012_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/091_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/062_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/033_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/001_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/050_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/082_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/020_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/071_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/065_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/034_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/096_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/044_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/015_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/089_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/027_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/019_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/076_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/048_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/085_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/038_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/006_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/069_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/057_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/045_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/014_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/088_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/064_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/035_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/097_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/039_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/007_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/068_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/056_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/026_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/018_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/077_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/049_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/084_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/090_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/063_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/032_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/042_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/013_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/083_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/021_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/070_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/051_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/028_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/016_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/079_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/047_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/037_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/009_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/066_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/058_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/095_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/054_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/005_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/099_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/075_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/024_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/086_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/092_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/030_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/061_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/011_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/040_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/100_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/081_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/072_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/023_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/053_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/100/002_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/018_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/026_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/049_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/077_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/084_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/007_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/039_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/056_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/068_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/064_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/035_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/097_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/045_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/014_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/088_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/051_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/083_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/021_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/070_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/042_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/013_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/090_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/063_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/032_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/075_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/024_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/086_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/054_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/005_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/099_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/009_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/037_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/058_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/066_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/095_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/016_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/028_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/047_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/079_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/053_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/002_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/100_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/081_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/072_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/023_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/011_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/040_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/092_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/030_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/061_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/080_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/073_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/022_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/052_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/003_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/093_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/031_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/060_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/010_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/041_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/055_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/004_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/098_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/074_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/025_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/087_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/017_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/029_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/046_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/078_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/008_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/036_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/059_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/067_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/094_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/082_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/020_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/071_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/001_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/050_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/091_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/062_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/033_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/043_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/012_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/006_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/038_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/057_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/069_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/019_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/027_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/048_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/076_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/085_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/044_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/015_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/089_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/065_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/034_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000000/096_remy_ashford_c.png
#    creating: correct/remy-ashford/metrics/1000/.ipynb_checkpoints/
#   inflating: correct/remy-ashford/metrics/1000/051_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/021_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/070_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/083_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/042_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/013_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/063_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/032_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/090_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/084_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/018_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/026_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/049_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/077_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/007_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/039_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/056_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/068_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/097_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/064_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/035_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/088_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/045_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/014_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/053_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/002_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/072_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/023_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/100_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/081_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/011_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/040_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/030_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/061_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/092_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/086_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/075_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/024_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/099_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/054_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/005_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/095_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/009_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/037_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/058_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/066_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/016_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/028_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/047_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/079_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/098_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/055_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/004_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/087_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/074_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/025_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/017_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/029_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/046_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/078_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/094_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/008_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/036_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/059_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/067_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/073_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/022_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/080_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/052_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/003_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/031_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/060_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/093_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/010_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/041_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/006_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/038_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/057_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/069_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/085_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/019_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/027_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/048_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/076_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/089_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/044_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/015_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/096_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/065_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/034_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/020_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/071_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/082_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/001_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/050_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/062_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/033_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/091_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/043_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/012_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/1000/.ipynb_checkpoints/001_remy_ashford_c-checkpoint.png
#   inflating: correct/remy-ashford/metrics/1000/.ipynb_checkpoints/023_remy_ashford_c-checkpoint.png
#   inflating: correct/remy-ashford/metrics/1000/.ipynb_checkpoints/021_remy_ashford_c-checkpoint.png
# Archive:  incorrect/remy-ashford/incorrect.zip
#    creating: incorrect/remy-ashford/metrics/10/
#    creating: incorrect/remy-ashford/metrics/100/
#    creating: incorrect/remy-ashford/metrics/1000/
#    creating: incorrect/remy-ashford/metrics/10000/
#    creating: incorrect/remy-ashford/metrics/100000/
#    creating: incorrect/remy-ashford/metrics/1000000/
#    creating: incorrect/remy-ashford/metrics/10/.ipynb_checkpoints/
#   inflating: incorrect/remy-ashford/metrics/10/086_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/075_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/024_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/099_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/054_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/005_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/095_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/009_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/037_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/058_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/066_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/016_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/028_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/047_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/079_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/053_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/002_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/072_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/023_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/100_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/081_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/011_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/040_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/030_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/061_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/092_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/084_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/018_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/026_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/049_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/077_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/007_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/039_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/056_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/068_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/097_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/064_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/035_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/088_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/045_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/014_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/051_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/021_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/10/070_remy_ashford_i.png
# ...
#   inflating: incorrect/remy-ashford/metrics/1000/068_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/1000/056_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/1000/042_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/1000/013_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/1000/090_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/1000/063_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/1000/032_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/1000/051_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/1000/083_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/1000/021_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/1000/070_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/1000/.ipynb_checkpoints/003_remy_ashford_i-checkpoint.png
#   inflating: incorrect/remy-ashford/metrics/100/044_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/015_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/089_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/065_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/034_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/096_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/006_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/038_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/057_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/069_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/019_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/027_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/048_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/076_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/085_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/091_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/062_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/033_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/043_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/012_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/082_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/020_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/071_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/001_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/050_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/017_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/029_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/046_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/078_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/008_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/036_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/059_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/067_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/094_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/055_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/004_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/098_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/074_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/025_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/087_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/093_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/031_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/060_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/010_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/041_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/080_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/073_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/022_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/052_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/003_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/011_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/040_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/092_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/030_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/061_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/053_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/002_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/100_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/081_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/072_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/023_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/009_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/037_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/058_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/066_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/095_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/016_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/028_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/047_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/079_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/075_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/024_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/086_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/054_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/005_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/099_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/042_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/013_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/090_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/063_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/032_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/051_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/083_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/021_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/070_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/064_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/035_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/097_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/045_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/014_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/088_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/018_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/026_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/049_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/077_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/084_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/007_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/039_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/056_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100/068_remy_ashford_i.png
#    creating: incorrect/remy-ashford/metrics/100000/.ipynb_checkpoints/
#   inflating: incorrect/remy-ashford/metrics/100000/039_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/007_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/068_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/056_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/026_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/018_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/077_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/049_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/084_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/045_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/014_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/088_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/064_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/035_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/097_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/083_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/021_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/070_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/051_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/090_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/063_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/032_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/042_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/013_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/054_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/005_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/099_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/075_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/024_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/086_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/028_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/016_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/079_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/047_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/037_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/009_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/066_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/058_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/095_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/100_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/081_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/072_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/023_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/053_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/002_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/092_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/030_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/061_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/011_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/040_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/052_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/003_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/080_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/073_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/022_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/010_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/041_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/093_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/031_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/060_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/074_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/025_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/087_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/055_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/004_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/098_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/036_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/008_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/067_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/059_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/094_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/029_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/017_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/078_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/046_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/001_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/050_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/082_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/020_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/071_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/043_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/012_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/091_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/062_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/033_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/027_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/019_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/076_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/048_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/085_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/038_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/006_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/069_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/057_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/065_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/034_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/096_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/044_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/015_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/089_remy_ashford_i.png
#   inflating: incorrect/remy-ashford/metrics/100000/.ipynb_checkpoints/008_remy_ashford_i-checkpoint.png

# %% [markdown]
# The same 50 numbers are reused across all 6 scale values, giving 600 images total per prompt version (50 pairs × 6 scale values × 2 variants)

# %%
"""
import sys
import random
from pathlib import Path
sys.path.append(str(Path().resolve().parent))
from utils.quanti_benchmarking_4_reactions import (
    PROMPT_VERSIONS, benchmark_image, output_exists_json, ask_question_gemma
)

# --- Configuration ---
BASE_DIR = Path().resolve()
EXPERIMENT_NAME = "test-4-metrics-claim-only"
MODEL_NAME = "qwen3-vl-8b"
ASK_FN = ask_question_gemma
SEED = 42
SAMPLE_SIZE = 50
REACTION_VALUES = [10, 100, 1000, 10000, 100000, 1000000]

# --- Build paired sample ---
correct_base = BASE_DIR / "correct/remy-ashford/metrics/uniform"
incorrect_base = BASE_DIR / "incorrect/remy-ashford/metrics/uniform"
sample_dir = correct_base / "10"
all_numbers = sorted([p.name.split("_")[0] for p in sample_dir.glob("*_remy_ashford_c.png")])
print(f"Found {len(all_numbers)} images in {sample_dir}")

random.seed(SEED)
selected_numbers = sorted(random.sample(all_numbers, SAMPLE_SIZE))
print(f"Selected {len(selected_numbers)} numbers: {selected_numbers}")

all_images = []
for scale_value in REACTION_VALUES:
    for num in selected_numbers:
        all_images.append((
            f"{num}_correct_{scale_value}",
            str(correct_base / str(scale_value) / f"{num}_remy_ashford_c.png")
        ))
        all_images.append((
            f"{num}_incorrect_{scale_value}",
            str(incorrect_base / str(scale_value) / f"{num}_remy_ashford_i.png")
        ))
print(f"Total images to process: {len(all_images)}")

# --- Run ---
for prompt_version, prompt_text in PROMPT_VERSIONS.items():
    print(f"\n{'='*60}\nRunning: {prompt_version}\n{'='*60}")
    for image_name, image_path in all_images:
        if output_exists_json(image_name, prompt_version, BASE_DIR, EXPERIMENT_NAME, MODEL_NAME):
            print(f"⏭ Skipping: {image_name} [{prompt_version}]")
            continue
        benchmark_image(image_path, image_name, prompt_version, prompt_text, model, processor, device, BASE_DIR, EXPERIMENT_NAME, MODEL_NAME, ASK_FN)

print("\n✅ All metrics versions complete.")
"""

# %%
"""
from utils.quanti_benchmarking_4_analysis import run_accuracy_analysis
BASE_DIR = Path().resolve()
EXPERIMENT_NAME = "test-4-metrics-claim-only"
MODEL_NAME = "qwen3-8b-vl"
run_accuracy_analysis(BASE_DIR, EXPERIMENT_NAME, MODEL_NAME)
"""

# %%
# codigo viejo incluye two-call approach y se encuentra en copia de este notebook

# %% [markdown]
# # 5) Nr of reactions - more realistic -  X total across all reaction types (likes + loves + hahas etc. combined), x being the log numebr so 10, 100, 1000, etc.
# Posts were generated under two reaction conditions: uniform, in which all reaction types were set equally, and realistic, in which reactions were distributed using log-scaled weights to approximate empirical engagement patterns on social media.
#
# With uniform reactions, every post at scale_value=1000 showed exactly 1000 likes, 1000 loves, 1000 hahas etc. — which is something that essentially never occurs on real Facebook and could itself be a signal to the VLM that something artificial is happening. The realistic condition removes that artificiality while keeping scale_value as a clean, interpretable independent variable representing **total engagement volume**.
#
# **Why Jitter Matters**
# Without jitter, every image index at a given scale_value would produce identical reaction counts. For example, at scale_value=1000 every single one of your 100 images would show:
#
#
# - Emoji order is always like, love, haha, wow, sad, angry — fixed by the change in the .py file
# - Values vary across images because shares are shuffled using seed=i — so image 001 always gets the same distribution but different from image 002
# - Total reactions always sum to approximately scale_value — Interpretation 1
# - Files land in realistic/ keeping them separate from your uniform/ condition
# - Reproducible — rerunning will generate identical files

# %%
# !unzip correct/remy-ashford/correct_realistic.zip -d correct/remy-ashford/metrics/realistic
# !unzip incorrect/remy-ashford/incorrect_realistic.zip -d incorrect/remy-ashford/metrics/realistic
# Out:
# Archive:  correct/remy-ashford/correct_realistic.zip
#    creating: correct/remy-ashford/metrics/realistic/10/
#    creating: correct/remy-ashford/metrics/realistic/100/
#    creating: correct/remy-ashford/metrics/realistic/1000/
#    creating: correct/remy-ashford/metrics/realistic/10000/
#    creating: correct/remy-ashford/metrics/realistic/100000/
#    creating: correct/remy-ashford/metrics/realistic/1000000/
#   inflating: correct/remy-ashford/metrics/realistic/10000/099_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/054_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/005_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/086_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/075_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/024_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/016_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/028_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/047_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/079_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/095_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/009_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/037_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/058_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/066_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/072_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/023_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/100_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/081_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/053_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/002_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/030_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/061_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/092_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/011_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/040_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/007_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/039_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/056_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/068_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/084_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/018_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/026_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/049_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/077_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/088_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/045_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/014_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/097_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/064_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/035_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/021_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/070_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/083_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/051_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/063_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/032_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/090_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/042_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/013_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/001_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/050_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/020_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/071_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/082_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/043_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/012_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/062_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/033_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/091_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/085_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/019_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/027_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/048_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/076_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/006_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/038_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/057_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/069_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/096_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/065_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/034_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/089_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/044_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/015_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/052_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/003_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/073_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/022_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/080_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/010_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/041_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/031_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/060_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/093_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/087_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/074_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/025_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/098_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/055_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/004_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/094_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/008_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/036_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/059_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/067_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/017_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/029_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/046_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10000/078_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/021_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/070_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/083_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/051_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/063_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/032_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/090_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/042_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/013_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/039_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/007_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/068_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/056_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/084_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/026_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/018_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/077_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/049_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/088_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/045_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/014_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/097_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/064_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/035_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/072_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/023_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/100_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/081_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/053_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/002_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/030_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/061_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/092_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/011_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/040_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/099_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/054_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/005_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/086_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/075_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/024_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/028_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/016_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/079_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/047_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/095_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/037_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/009_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/066_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/058_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/087_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/074_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/025_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/098_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/055_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/004_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/094_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/036_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/008_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/067_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/059_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/029_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/017_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/078_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/046_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/052_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/003_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/073_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/022_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/080_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/010_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/041_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/031_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/060_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/093_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/085_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/027_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/019_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/076_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/048_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/038_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/006_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/069_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/057_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/096_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/065_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/034_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/089_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/044_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/015_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/001_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/050_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/020_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/071_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/082_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/043_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/012_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/062_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/033_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000/091_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/041_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/010_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/093_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/060_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/031_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/003_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/052_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/080_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/022_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/073_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/067_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/059_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/036_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/008_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/094_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/078_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/046_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/029_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/017_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/025_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/074_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/087_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/004_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/055_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/098_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/012_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/043_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/091_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/033_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/062_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/050_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/001_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/082_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/071_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/020_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/034_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/065_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/096_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/015_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/044_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/089_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/076_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/048_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/027_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/019_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/085_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/069_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/057_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/038_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/006_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/014_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/045_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/088_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/035_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/064_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/097_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/068_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/056_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/039_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/007_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/077_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/049_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/026_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/018_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/084_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/090_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/032_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/063_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/013_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/042_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/083_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/070_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/021_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/051_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/079_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/047_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/028_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/016_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/066_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/058_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/037_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/009_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/095_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/005_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/054_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/099_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/024_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/075_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/086_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/092_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/061_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/030_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/040_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/011_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/081_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/100_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/023_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/072_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/002_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/10/053_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/086_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/075_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/024_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/099_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/054_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/005_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/095_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/009_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/037_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/058_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/066_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/016_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/028_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/047_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/079_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/053_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/002_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/072_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/023_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/100_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/081_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/011_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/040_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/030_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/061_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/092_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/084_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/018_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/026_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/049_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/077_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/007_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/039_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/056_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/068_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/097_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/064_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/035_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/088_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/045_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/014_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/051_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/021_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/070_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/083_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/042_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/013_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/063_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/032_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/090_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/020_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/071_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/082_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/001_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/050_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/062_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/033_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/091_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/043_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/012_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/006_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/038_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/057_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/069_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/085_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/019_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/027_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/048_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/076_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/089_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/044_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/015_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/096_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/065_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/034_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/073_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/022_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/080_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/052_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/003_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/031_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/060_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/093_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/010_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/041_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/098_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/055_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/004_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/087_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/074_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/025_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/017_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/029_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/046_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/078_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/094_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/008_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/036_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/059_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100/067_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/100_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/081_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/072_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/023_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/053_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/002_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/092_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/030_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/061_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/011_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/040_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/054_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/005_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/099_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/075_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/024_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/086_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/016_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/028_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/047_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/079_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/009_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/037_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/058_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/066_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/095_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/083_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/021_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/070_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/051_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/090_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/063_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/032_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/042_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/013_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/007_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/039_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/056_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/068_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/018_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/026_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/049_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/077_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/084_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/045_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/014_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/088_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/064_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/035_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/097_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/019_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/027_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/048_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/076_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/085_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/006_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/038_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/057_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/069_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/065_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/034_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/096_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/044_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/015_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/089_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/001_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/050_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/082_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/020_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/071_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/043_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/012_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/091_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/062_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/033_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/074_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/025_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/087_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/055_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/004_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/098_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/008_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/036_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/059_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/067_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/094_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/017_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/029_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/046_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/078_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/052_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/003_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/080_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/073_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/022_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/010_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/041_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/093_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/031_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/100000/060_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/042_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/013_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/090_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/063_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/032_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/051_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/083_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/021_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/070_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/064_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/035_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/097_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/045_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/014_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/088_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/026_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/018_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/077_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/049_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/084_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/039_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/007_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/068_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/056_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/011_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/040_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/092_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/030_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/061_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/053_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/002_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/100_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/081_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/072_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/023_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/037_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/009_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/066_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/058_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/095_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/028_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/016_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/079_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/047_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/075_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/024_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/086_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/054_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/005_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/099_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/029_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/017_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/078_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/046_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/036_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/008_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/067_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/059_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/094_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/055_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/004_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/098_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/074_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/025_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/087_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/093_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/031_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/060_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/010_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/041_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/080_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/073_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/022_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/052_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/003_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/044_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/015_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/089_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/065_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/034_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/096_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/038_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/006_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/069_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/057_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/027_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/019_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/076_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/048_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/085_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/091_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/062_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/033_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/043_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/012_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/082_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/020_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/071_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/001_remy_ashford_c.png
#   inflating: correct/remy-ashford/metrics/realistic/1000000/050_remy_ashford_c.png
# Archive:  incorrect/remy-ashford/incorrect_realistic.zip
# replace incorrect/remy-ashford/metrics/realistic/1000000/050_remy_ashford_i.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
import sys
import random
from pathlib import Path

sys.path.append(str(Path().resolve().parent))
from utils.quanti_benchmarking_4_reactions import (
    PROMPT_VERSIONS, benchmark_image, output_exists_json
)

# --- Configuration ---
BASE_DIR = Path().resolve()
EXPERIMENT_NAME = "test-5-metrics-realistic-claim-only"
SEED = 42
SAMPLE_SIZE = 50
REACTION_VALUES = [10, 100, 1000, 10000, 100000, 1000000]

# --- Build paired sample ---
correct_base = BASE_DIR / "correct/remy-ashford/metrics/realistic"
incorrect_base = BASE_DIR / "incorrect/remy-ashford/metrics/realistic"

sample_dir = correct_base / "10"
all_numbers = sorted([p.name.split("_")[0] for p in sample_dir.glob("*_remy_ashford_c.png")])
print(f"Found {len(all_numbers)} images in {sample_dir}")

random.seed(SEED)
selected_numbers = sorted(random.sample(all_numbers, SAMPLE_SIZE))
print(f"Selected {len(selected_numbers)} numbers: {selected_numbers}")

all_images = []
for scale_value in REACTION_VALUES:
    for num in selected_numbers:
        all_images.append((
            f"{num}_correct_{scale_value}",
            str(correct_base / str(scale_value) / f"{num}_remy_ashford_c.png")
        ))
        all_images.append((
            f"{num}_incorrect_{scale_value}",
            str(incorrect_base / str(scale_value) / f"{num}_remy_ashford_i.png")
        ))

print(f"Total images to process: {len(all_images)}")

# --- Run ---
for prompt_version, prompt_text in PROMPT_VERSIONS.items():
    print(f"\n{'='*60}\nRunning: {prompt_version}\n{'='*60}")
    for image_name, image_path in all_images:
        if output_exists_json(image_name, prompt_version, BASE_DIR, EXPERIMENT_NAME):
            print(f"⏭ Skipping: {image_name} [{prompt_version}]")
            continue
        benchmark_image(image_path, image_name, prompt_version, prompt_text, model, processor, device, BASE_DIR, EXPERIMENT_NAME)

print("\n✅ All metrics versions complete.")
# Out:
# Found 100 images in /home/jovyan/benchmarking/correct/remy-ashford/metrics/realistic/10
# Selected 50 numbers: ['001', '003', '004', '005', '006', '007', '012', '014', '015', '017', '018', '020', '021', '023', '025', '026', '028', '029', '030', '032', '036', '039', '044', '047', '052', '054', '055', '058', '059', '063', '065', '068', '069', '070', '072', '076', '078', '080', '082', '083', '085', '087', '089', '090', '091', '094', '095', '096', '098', '100']
# Total images to process: 600
#
# ============================================================
# Running: v1
# ============================================================
# ⏭ Skipping: 001_correct_10 [v1]
# ⏭ Skipping: 001_incorrect_10 [v1]
# ⏭ Skipping: 003_correct_10 [v1]
# ⏭ Skipping: 003_incorrect_10 [v1]
# ⏭ Skipping: 004_correct_10 [v1]
# ⏭ Skipping: 004_incorrect_10 [v1]
# ⏭ Skipping: 005_correct_10 [v1]
# ⏭ Skipping: 005_incorrect_10 [v1]
# ⏭ Skipping: 006_correct_10 [v1]
# ⏭ Skipping: 006_incorrect_10 [v1]
# ⏭ Skipping: 007_correct_10 [v1]
# ⏭ Skipping: 007_incorrect_10 [v1]
# ⏭ Skipping: 012_correct_10 [v1]
# ⏭ Skipping: 012_incorrect_10 [v1]
# ⏭ Skipping: 014_correct_10 [v1]
# ⏭ Skipping: 014_incorrect_10 [v1]
# ⏭ Skipping: 015_correct_10 [v1]
# ⏭ Skipping: 015_incorrect_10 [v1]
# ⏭ Skipping: 017_correct_10 [v1]
# ⏭ Skipping: 017_incorrect_10 [v1]
# ⏭ Skipping: 018_correct_10 [v1]
# ⏭ Skipping: 018_incorrect_10 [v1]
# ⏭ Skipping: 020_correct_10 [v1]
# ⏭ Skipping: 020_incorrect_10 [v1]
# ⏭ Skipping: 021_correct_10 [v1]
# ⏭ Skipping: 021_incorrect_10 [v1]
# ⏭ Skipping: 023_correct_10 [v1]
# ⏭ Skipping: 023_incorrect_10 [v1]
# ⏭ Skipping: 025_correct_10 [v1]
# ⏭ Skipping: 025_incorrect_10 [v1]
# ⏭ Skipping: 026_correct_10 [v1]
# ⏭ Skipping: 026_incorrect_10 [v1]
# ⏭ Skipping: 028_correct_10 [v1]
# ⏭ Skipping: 028_incorrect_10 [v1]
# ⏭ Skipping: 029_correct_10 [v1]
# ⏭ Skipping: 029_incorrect_10 [v1]
# ⏭ Skipping: 030_correct_10 [v1]
# ⏭ Skipping: 030_incorrect_10 [v1]
# ⏭ Skipping: 032_correct_10 [v1]
# ⏭ Skipping: 032_incorrect_10 [v1]
# ⏭ Skipping: 036_correct_10 [v1]
# ⏭ Skipping: 036_incorrect_10 [v1]
# ⏭ Skipping: 039_correct_10 [v1]
# ⏭ Skipping: 039_incorrect_10 [v1]
# ⏭ Skipping: 044_correct_10 [v1]
# ⏭ Skipping: 044_incorrect_10 [v1]
# ⏭ Skipping: 047_correct_10 [v1]
# ⏭ Skipping: 047_incorrect_10 [v1]
# ⏭ Skipping: 052_correct_10 [v1]
# ⏭ Skipping: 052_incorrect_10 [v1]
# ⏭ Skipping: 054_correct_10 [v1]
# ⏭ Skipping: 054_incorrect_10 [v1]
# ⏭ Skipping: 055_correct_10 [v1]
# ⏭ Skipping: 055_incorrect_10 [v1]
# ⏭ Skipping: 058_correct_10 [v1]
# ⏭ Skipping: 058_incorrect_10 [v1]
# ⏭ Skipping: 059_correct_10 [v1]
# ⏭ Skipping: 059_incorrect_10 [v1]
# ⏭ Skipping: 063_correct_10 [v1]
# ⏭ Skipping: 063_incorrect_10 [v1]
# ⏭ Skipping: 065_correct_10 [v1]
# ⏭ Skipping: 065_incorrect_10 [v1]
# ⏭ Skipping: 068_correct_10 [v1]
# ⏭ Skipping: 068_incorrect_10 [v1]
# ⏭ Skipping: 069_correct_10 [v1]
# ⏭ Skipping: 069_incorrect_10 [v1]
# ⏭ Skipping: 070_correct_10 [v1]
# ⏭ Skipping: 070_incorrect_10 [v1]
# ⏭ Skipping: 072_correct_10 [v1]
# ⏭ Skipping: 072_incorrect_10 [v1]
# ⏭ Skipping: 076_correct_10 [v1]
# ⏭ Skipping: 076_incorrect_10 [v1]
# ⏭ Skipping: 078_correct_10 [v1]
# ⏭ Skipping: 078_incorrect_10 [v1]
# ⏭ Skipping: 080_correct_10 [v1]
# ⏭ Skipping: 080_incorrect_10 [v1]
# ⏭ Skipping: 082_correct_10 [v1]
# ⏭ Skipping: 082_incorrect_10 [v1]
# ⏭ Skipping: 083_correct_10 [v1]
# ⏭ Skipping: 083_incorrect_10 [v1]
# ⏭ Skipping: 085_correct_10 [v1]
# ⏭ Skipping: 085_incorrect_10 [v1]
# ⏭ Skipping: 087_correct_10 [v1]
# ⏭ Skipping: 087_incorrect_10 [v1]
# ⏭ Skipping: 089_correct_10 [v1]
# ⏭ Skipping: 089_incorrect_10 [v1]
# ⏭ Skipping: 090_correct_10 [v1]
# ⏭ Skipping: 090_incorrect_10 [v1]
# ⏭ Skipping: 091_correct_10 [v1]
# ⏭ Skipping: 091_incorrect_10 [v1]
# ⏭ Skipping: 094_correct_10 [v1]
# ⏭ Skipping: 094_incorrect_10 [v1]
# ⏭ Skipping: 095_correct_10 [v1]
# ⏭ Skipping: 095_incorrect_10 [v1]
# ⏭ Skipping: 096_correct_10 [v1]
# ⏭ Skipping: 096_incorrect_10 [v1]
# ⏭ Skipping: 098_correct_10 [v1]
# ⏭ Skipping: 098_incorrect_10 [v1]
# ⏭ Skipping: 100_correct_10 [v1]
# ⏭ Skipping: 100_incorrect_10 [v1]
# ⏭ Skipping: 001_correct_100 [v1]
# ⏭ Skipping: 001_incorrect_100 [v1]
# ⏭ Skipping: 003_correct_100 [v1]
# ⏭ Skipping: 003_incorrect_100 [v1]
# ⏭ Skipping: 004_correct_100 [v1]
# ⏭ Skipping: 004_incorrect_100 [v1]
# ⏭ Skipping: 005_correct_100 [v1]
# ⏭ Skipping: 005_incorrect_100 [v1]
# ⏭ Skipping: 006_correct_100 [v1]
# ⏭ Skipping: 006_incorrect_100 [v1]
# ⏭ Skipping: 007_correct_100 [v1]
# ⏭ Skipping: 007_incorrect_100 [v1]
# ⏭ Skipping: 012_correct_100 [v1]
# ⏭ Skipping: 012_incorrect_100 [v1]
# ⏭ Skipping: 014_correct_100 [v1]
# ⏭ Skipping: 014_incorrect_100 [v1]
# ⏭ Skipping: 015_correct_100 [v1]
# ⏭ Skipping: 015_incorrect_100 [v1]
# ⏭ Skipping: 017_correct_100 [v1]
# ⏭ Skipping: 017_incorrect_100 [v1]
# ⏭ Skipping: 018_correct_100 [v1]
# ⏭ Skipping: 018_incorrect_100 [v1]
# ⏭ Skipping: 020_correct_100 [v1]
# ⏭ Skipping: 020_incorrect_100 [v1]
# ⏭ Skipping: 021_correct_100 [v1]
# ⏭ Skipping: 021_incorrect_100 [v1]
# ⏭ Skipping: 023_correct_100 [v1]
# ⏭ Skipping: 023_incorrect_100 [v1]
# ⏭ Skipping: 025_correct_100 [v1]
# ⏭ Skipping: 025_incorrect_100 [v1]
# ⏭ Skipping: 026_correct_100 [v1]
# ⏭ Skipping: 026_incorrect_100 [v1]
# ⏭ Skipping: 028_correct_100 [v1]
# ⏭ Skipping: 028_incorrect_100 [v1]
# ⏭ Skipping: 029_correct_100 [v1]
# ⏭ Skipping: 029_incorrect_100 [v1]
# ⏭ Skipping: 030_correct_100 [v1]
# ⏭ Skipping: 030_incorrect_100 [v1]
# ⏭ Skipping: 032_correct_100 [v1]
# ⏭ Skipping: 032_incorrect_100 [v1]
# ⏭ Skipping: 036_correct_100 [v1]
# ⏭ Skipping: 036_incorrect_100 [v1]
# ⏭ Skipping: 039_correct_100 [v1]
# ⏭ Skipping: 039_incorrect_100 [v1]
# ⏭ Skipping: 044_correct_100 [v1]
# ⏭ Skipping: 044_incorrect_100 [v1]
# ⏭ Skipping: 047_correct_100 [v1]
# ⏭ Skipping: 047_incorrect_100 [v1]
# ⏭ Skipping: 052_correct_100 [v1]
# ⏭ Skipping: 052_incorrect_100 [v1]
# ⏭ Skipping: 054_correct_100 [v1]
# ⏭ Skipping: 054_incorrect_100 [v1]
# ⏭ Skipping: 055_correct_100 [v1]
# ⏭ Skipping: 055_incorrect_100 [v1]
# ⏭ Skipping: 058_correct_100 [v1]
# ⏭ Skipping: 058_incorrect_100 [v1]
# ⏭ Skipping: 059_correct_100 [v1]
# ⏭ Skipping: 059_incorrect_100 [v1]
# ⏭ Skipping: 063_correct_100 [v1]
# ⏭ Skipping: 063_incorrect_100 [v1]
# ⏭ Skipping: 065_correct_100 [v1]
# ⏭ Skipping: 065_incorrect_100 [v1]
# ⏭ Skipping: 068_correct_100 [v1]
# ⏭ Skipping: 068_incorrect_100 [v1]
# ⏭ Skipping: 069_correct_100 [v1]
# ⏭ Skipping: 069_incorrect_100 [v1]
# ⏭ Skipping: 070_correct_100 [v1]
# ⏭ Skipping: 070_incorrect_100 [v1]
# ⏭ Skipping: 072_correct_100 [v1]
# ⏭ Skipping: 072_incorrect_100 [v1]
# ⏭ Skipping: 076_correct_100 [v1]
# ⏭ Skipping: 076_incorrect_100 [v1]
# ⏭ Skipping: 078_correct_100 [v1]
# ⏭ Skipping: 078_incorrect_100 [v1]
# ⏭ Skipping: 080_correct_100 [v1]
# ⏭ Skipping: 080_incorrect_100 [v1]
# ⏭ Skipping: 082_correct_100 [v1]
# ⏭ Skipping: 082_incorrect_100 [v1]
# ⏭ Skipping: 083_correct_100 [v1]
# ⏭ Skipping: 083_incorrect_100 [v1]
# ⏭ Skipping: 085_correct_100 [v1]
# ⏭ Skipping: 085_incorrect_100 [v1]
# ⏭ Skipping: 087_correct_100 [v1]
# ⏭ Skipping: 087_incorrect_100 [v1]
# ⏭ Skipping: 089_correct_100 [v1]
# ⏭ Skipping: 089_incorrect_100 [v1]
# ⏭ Skipping: 090_correct_100 [v1]
# ⏭ Skipping: 090_incorrect_100 [v1]
# ⏭ Skipping: 091_correct_100 [v1]
# ⏭ Skipping: 091_incorrect_100 [v1]
# ⏭ Skipping: 094_correct_100 [v1]
# ⏭ Skipping: 094_incorrect_100 [v1]
# ⏭ Skipping: 095_correct_100 [v1]
# ⏭ Skipping: 095_incorrect_100 [v1]
# ⏭ Skipping: 096_correct_100 [v1]
# ⏭ Skipping: 096_incorrect_100 [v1]
# ⏭ Skipping: 098_correct_100 [v1]
# ⏭ Skipping: 098_incorrect_100 [v1]
# ⏭ Skipping: 100_correct_100 [v1]
# ⏭ Skipping: 100_incorrect_100 [v1]
# ⏭ Skipping: 001_correct_1000 [v1]
# ⏭ Skipping: 001_incorrect_1000 [v1]
# ⏭ Skipping: 003_correct_1000 [v1]
# ⏭ Skipping: 003_incorrect_1000 [v1]
# ⏭ Skipping: 004_correct_1000 [v1]
# ⏭ Skipping: 004_incorrect_1000 [v1]
# ⏭ Skipping: 005_correct_1000 [v1]
# ⏭ Skipping: 005_incorrect_1000 [v1]
# ⏭ Skipping: 006_correct_1000 [v1]
# ⏭ Skipping: 006_incorrect_1000 [v1]
# ⏭ Skipping: 007_correct_1000 [v1]
# ⏭ Skipping: 007_incorrect_1000 [v1]
# ⏭ Skipping: 012_correct_1000 [v1]
# ⏭ Skipping: 012_incorrect_1000 [v1]
# ⏭ Skipping: 014_correct_1000 [v1]
# ⏭ Skipping: 014_incorrect_1000 [v1]
# ⏭ Skipping: 015_correct_1000 [v1]
# ⏭ Skipping: 015_incorrect_1000 [v1]
# ⏭ Skipping: 017_correct_1000 [v1]
# ⏭ Skipping: 017_incorrect_1000 [v1]
# ⏭ Skipping: 018_correct_1000 [v1]
# ⏭ Skipping: 018_incorrect_1000 [v1]
# ⏭ Skipping: 020_correct_1000 [v1]
# ⏭ Skipping: 020_incorrect_1000 [v1]
# ⏭ Skipping: 021_correct_1000 [v1]
# ⏭ Skipping: 021_incorrect_1000 [v1]
# ⏭ Skipping: 023_correct_1000 [v1]
# ⏭ Skipping: 023_incorrect_1000 [v1]
# ⏭ Skipping: 025_correct_1000 [v1]
# ⏭ Skipping: 025_incorrect_1000 [v1]
# ⏭ Skipping: 026_correct_1000 [v1]
# ⏭ Skipping: 026_incorrect_1000 [v1]
# ⏭ Skipping: 028_correct_1000 [v1]
# ⏭ Skipping: 028_incorrect_1000 [v1]
# ⏭ Skipping: 029_correct_1000 [v1]
# ⏭ Skipping: 029_incorrect_1000 [v1]
# ⏭ Skipping: 030_correct_1000 [v1]
# ⏭ Skipping: 030_incorrect_1000 [v1]
# ⏭ Skipping: 032_correct_1000 [v1]
# ⏭ Skipping: 032_incorrect_1000 [v1]
# ⏭ Skipping: 036_correct_1000 [v1]
# ⏭ Skipping: 036_incorrect_1000 [v1]
# ⏭ Skipping: 039_correct_1000 [v1]
# ⏭ Skipping: 039_incorrect_1000 [v1]
# ⏭ Skipping: 044_correct_1000 [v1]
# ⏭ Skipping: 044_incorrect_1000 [v1]
# ⏭ Skipping: 047_correct_1000 [v1]
# ⏭ Skipping: 047_incorrect_1000 [v1]
# ⏭ Skipping: 052_correct_1000 [v1]
# ⏭ Skipping: 052_incorrect_1000 [v1]
# ⏭ Skipping: 054_correct_1000 [v1]
# ⏭ Skipping: 054_incorrect_1000 [v1]
# ⏭ Skipping: 055_correct_1000 [v1]
# ⏭ Skipping: 055_incorrect_1000 [v1]
# ⏭ Skipping: 058_correct_1000 [v1]
# ⏭ Skipping: 058_incorrect_1000 [v1]
# ⏭ Skipping: 059_correct_1000 [v1]
# ⏭ Skipping: 059_incorrect_1000 [v1]
# ⏭ Skipping: 063_correct_1000 [v1]
# ⏭ Skipping: 063_incorrect_1000 [v1]
# ⏭ Skipping: 065_correct_1000 [v1]
# ⏭ Skipping: 065_incorrect_1000 [v1]
# ⏭ Skipping: 068_correct_1000 [v1]
# ⏭ Skipping: 068_incorrect_1000 [v1]
# ⏭ Skipping: 069_correct_1000 [v1]
# ⏭ Skipping: 069_incorrect_1000 [v1]
# ⏭ Skipping: 070_correct_1000 [v1]
# ⏭ Skipping: 070_incorrect_1000 [v1]
# ⏭ Skipping: 072_correct_1000 [v1]
# ⏭ Skipping: 072_incorrect_1000 [v1]
# ⏭ Skipping: 076_correct_1000 [v1]
# ⏭ Skipping: 076_incorrect_1000 [v1]
# ⏭ Skipping: 078_correct_1000 [v1]
# ⏭ Skipping: 078_incorrect_1000 [v1]
# ⏭ Skipping: 080_correct_1000 [v1]
# ⏭ Skipping: 080_incorrect_1000 [v1]
# ⏭ Skipping: 082_correct_1000 [v1]
# ⏭ Skipping: 082_incorrect_1000 [v1]
# ⏭ Skipping: 083_correct_1000 [v1]
# ⏭ Skipping: 083_incorrect_1000 [v1]
# ⏭ Skipping: 085_correct_1000 [v1]
# ⏭ Skipping: 085_incorrect_1000 [v1]
# ⏭ Skipping: 087_correct_1000 [v1]
# ⏭ Skipping: 087_incorrect_1000 [v1]
# ⏭ Skipping: 089_correct_1000 [v1]
# ⏭ Skipping: 089_incorrect_1000 [v1]
# ⏭ Skipping: 090_correct_1000 [v1]
# ⏭ Skipping: 090_incorrect_1000 [v1]
# ⏭ Skipping: 091_correct_1000 [v1]
# ⏭ Skipping: 091_incorrect_1000 [v1]
# ⏭ Skipping: 094_correct_1000 [v1]
# ⏭ Skipping: 094_incorrect_1000 [v1]
# ⏭ Skipping: 095_correct_1000 [v1]
# ⏭ Skipping: 095_incorrect_1000 [v1]
# ⏭ Skipping: 096_correct_1000 [v1]
# ⏭ Skipping: 096_incorrect_1000 [v1]
# ⏭ Skipping: 098_correct_1000 [v1]
# ⏭ Skipping: 098_incorrect_1000 [v1]
# ⏭ Skipping: 100_correct_1000 [v1]
# ⏭ Skipping: 100_incorrect_1000 [v1]
# ⏭ Skipping: 001_correct_10000 [v1]
# ⏭ Skipping: 001_incorrect_10000 [v1]
# ⏭ Skipping: 003_correct_10000 [v1]
# ⏭ Skipping: 003_incorrect_10000 [v1]
# ⏭ Skipping: 004_correct_10000 [v1]
# ⏭ Skipping: 004_incorrect_10000 [v1]
# ⏭ Skipping: 005_correct_10000 [v1]
# ⏭ Skipping: 005_incorrect_10000 [v1]
# ⏭ Skipping: 006_correct_10000 [v1]
# ⏭ Skipping: 006_incorrect_10000 [v1]
# ⏭ Skipping: 007_correct_10000 [v1]
# ⏭ Skipping: 007_incorrect_10000 [v1]
# ⏭ Skipping: 012_correct_10000 [v1]
# ⏭ Skipping: 012_incorrect_10000 [v1]
# ⏭ Skipping: 014_correct_10000 [v1]
# ⏭ Skipping: 014_incorrect_10000 [v1]
# ⏭ Skipping: 015_correct_10000 [v1]
# ⏭ Skipping: 015_incorrect_10000 [v1]
# ⏭ Skipping: 017_correct_10000 [v1]
# ⏭ Skipping: 017_incorrect_10000 [v1]
# ⏭ Skipping: 018_correct_10000 [v1]
# ⏭ Skipping: 018_incorrect_10000 [v1]
# ⏭ Skipping: 020_correct_10000 [v1]
# ⏭ Skipping: 020_incorrect_10000 [v1]
# ⏭ Skipping: 021_correct_10000 [v1]
# ⏭ Skipping: 021_incorrect_10000 [v1]
# ⏭ Skipping: 023_correct_10000 [v1]
# ⏭ Skipping: 023_incorrect_10000 [v1]
# ⏭ Skipping: 025_correct_10000 [v1]
# ⏭ Skipping: 025_incorrect_10000 [v1]
# ⏭ Skipping: 026_correct_10000 [v1]
# ⏭ Skipping: 026_incorrect_10000 [v1]
# ⏭ Skipping: 028_correct_10000 [v1]
# ⏭ Skipping: 028_incorrect_10000 [v1]
# ⏭ Skipping: 029_correct_10000 [v1]
# ⏭ Skipping: 029_incorrect_10000 [v1]
# ⏭ Skipping: 030_correct_10000 [v1]
# ⏭ Skipping: 030_incorrect_10000 [v1]
# ⏭ Skipping: 032_correct_10000 [v1]
# ⏭ Skipping: 032_incorrect_10000 [v1]
# ⏭ Skipping: 036_correct_10000 [v1]
# ⏭ Skipping: 036_incorrect_10000 [v1]
# ⏭ Skipping: 039_correct_10000 [v1]
# ⏭ Skipping: 039_incorrect_10000 [v1]
# ⏭ Skipping: 044_correct_10000 [v1]
# ⏭ Skipping: 044_incorrect_10000 [v1]
# ⏭ Skipping: 047_correct_10000 [v1]
# ⏭ Skipping: 047_incorrect_10000 [v1]
# ⏭ Skipping: 052_correct_10000 [v1]
# ⏭ Skipping: 052_incorrect_10000 [v1]
# ⏭ Skipping: 054_correct_10000 [v1]
# ⏭ Skipping: 054_incorrect_10000 [v1]
# ⏭ Skipping: 055_correct_10000 [v1]
# ⏭ Skipping: 055_incorrect_10000 [v1]
# ⏭ Skipping: 058_correct_10000 [v1]
# ⏭ Skipping: 058_incorrect_10000 [v1]
# ⏭ Skipping: 059_correct_10000 [v1]
# ⏭ Skipping: 059_incorrect_10000 [v1]
# ⏭ Skipping: 063_correct_10000 [v1]
# ⏭ Skipping: 063_incorrect_10000 [v1]
# ⏭ Skipping: 065_correct_10000 [v1]
# ⏭ Skipping: 065_incorrect_10000 [v1]
# ⏭ Skipping: 068_correct_10000 [v1]
# ⏭ Skipping: 068_incorrect_10000 [v1]
# ⏭ Skipping: 069_correct_10000 [v1]
# ⏭ Skipping: 069_incorrect_10000 [v1]
# ⏭ Skipping: 070_correct_10000 [v1]
# ⏭ Skipping: 070_incorrect_10000 [v1]
# ⏭ Skipping: 072_correct_10000 [v1]
# ⏭ Skipping: 072_incorrect_10000 [v1]
# ⏭ Skipping: 076_correct_10000 [v1]
# ⏭ Skipping: 076_incorrect_10000 [v1]
# ⏭ Skipping: 078_correct_10000 [v1]
# ⏭ Skipping: 078_incorrect_10000 [v1]
# ⏭ Skipping: 080_correct_10000 [v1]
# ⏭ Skipping: 080_incorrect_10000 [v1]
# ⏭ Skipping: 082_correct_10000 [v1]
# ⏭ Skipping: 082_incorrect_10000 [v1]
# ⏭ Skipping: 083_correct_10000 [v1]
# ⏭ Skipping: 083_incorrect_10000 [v1]
# ⏭ Skipping: 085_correct_10000 [v1]
# ⏭ Skipping: 085_incorrect_10000 [v1]
# ⏭ Skipping: 087_correct_10000 [v1]
# ⏭ Skipping: 087_incorrect_10000 [v1]
# ⏭ Skipping: 089_correct_10000 [v1]
# ⏭ Skipping: 089_incorrect_10000 [v1]
# ⏭ Skipping: 090_correct_10000 [v1]
# ⏭ Skipping: 090_incorrect_10000 [v1]
# ⏭ Skipping: 091_correct_10000 [v1]
# ⏭ Skipping: 091_incorrect_10000 [v1]
# ⏭ Skipping: 094_correct_10000 [v1]
# ⏭ Skipping: 094_incorrect_10000 [v1]
# ⏭ Skipping: 095_correct_10000 [v1]
# ⏭ Skipping: 095_incorrect_10000 [v1]
# ⏭ Skipping: 096_correct_10000 [v1]
# ⏭ Skipping: 096_incorrect_10000 [v1]
# ⏭ Skipping: 098_correct_10000 [v1]
# ⏭ Skipping: 098_incorrect_10000 [v1]
# ⏭ Skipping: 100_correct_10000 [v1]
# ⏭ Skipping: 100_incorrect_10000 [v1]
# ⏭ Skipping: 001_correct_100000 [v1]
# ⏭ Skipping: 001_incorrect_100000 [v1]
# ⏭ Skipping: 003_correct_100000 [v1]
# ⏭ Skipping: 003_incorrect_100000 [v1]
# ⏭ Skipping: 004_correct_100000 [v1]
# ⏭ Skipping: 004_incorrect_100000 [v1]
# ⏭ Skipping: 005_correct_100000 [v1]
# ⏭ Skipping: 005_incorrect_100000 [v1]
# ⏭ Skipping: 006_correct_100000 [v1]
# ⏭ Skipping: 006_incorrect_100000 [v1]
# ⏭ Skipping: 007_correct_100000 [v1]
# ⏭ Skipping: 007_incorrect_100000 [v1]
# ⏭ Skipping: 012_correct_100000 [v1]
# ⏭ Skipping: 012_incorrect_100000 [v1]
# ⏭ Skipping: 014_correct_100000 [v1]
# ⏭ Skipping: 014_incorrect_100000 [v1]
# ⏭ Skipping: 015_correct_100000 [v1]
# ⏭ Skipping: 015_incorrect_100000 [v1]
# ⏭ Skipping: 017_correct_100000 [v1]
# ⏭ Skipping: 017_incorrect_100000 [v1]
# ⏭ Skipping: 018_correct_100000 [v1]
# ⏭ Skipping: 018_incorrect_100000 [v1]
# ⏭ Skipping: 020_correct_100000 [v1]
# ⏭ Skipping: 020_incorrect_100000 [v1]
# ⏭ Skipping: 021_correct_100000 [v1]
# ⏭ Skipping: 021_incorrect_100000 [v1]
# ⏭ Skipping: 023_correct_100000 [v1]
# ⏭ Skipping: 023_incorrect_100000 [v1]
# ⏭ Skipping: 025_correct_100000 [v1]
# ⏭ Skipping: 025_incorrect_100000 [v1]
# ⏭ Skipping: 026_correct_100000 [v1]
# ⏭ Skipping: 026_incorrect_100000 [v1]
# ⏭ Skipping: 028_correct_100000 [v1]
# ⏭ Skipping: 028_incorrect_100000 [v1]
# ⏭ Skipping: 029_correct_100000 [v1]
# ⏭ Skipping: 029_incorrect_100000 [v1]
# ⏭ Skipping: 030_correct_100000 [v1]
# ⏭ Skipping: 030_incorrect_100000 [v1]
# ⏭ Skipping: 032_correct_100000 [v1]
# ⏭ Skipping: 032_incorrect_100000 [v1]
# ⏭ Skipping: 036_correct_100000 [v1]
# ⏭ Skipping: 036_incorrect_100000 [v1]
# ⏭ Skipping: 039_correct_100000 [v1]
# ⏭ Skipping: 039_incorrect_100000 [v1]
# ⏭ Skipping: 044_correct_100000 [v1]
# ⏭ Skipping: 044_incorrect_100000 [v1]
# ⏭ Skipping: 047_correct_100000 [v1]
# ⏭ Skipping: 047_incorrect_100000 [v1]
# ⏭ Skipping: 052_correct_100000 [v1]
# ⏭ Skipping: 052_incorrect_100000 [v1]
# ⏭ Skipping: 054_correct_100000 [v1]
# ⏭ Skipping: 054_incorrect_100000 [v1]
# ⏭ Skipping: 055_correct_100000 [v1]
# ⏭ Skipping: 055_incorrect_100000 [v1]
# ⏭ Skipping: 058_correct_100000 [v1]
# ⏭ Skipping: 058_incorrect_100000 [v1]
# ⏭ Skipping: 059_correct_100000 [v1]
# ⏭ Skipping: 059_incorrect_100000 [v1]
# ⏭ Skipping: 063_correct_100000 [v1]
# ⏭ Skipping: 063_incorrect_100000 [v1]
# ⏭ Skipping: 065_correct_100000 [v1]
# ⏭ Skipping: 065_incorrect_100000 [v1]
# ⏭ Skipping: 068_correct_100000 [v1]
# ⏭ Skipping: 068_incorrect_100000 [v1]
# ⏭ Skipping: 069_correct_100000 [v1]
# ⏭ Skipping: 069_incorrect_100000 [v1]
# ⏭ Skipping: 070_correct_100000 [v1]
# ⏭ Skipping: 070_incorrect_100000 [v1]
# ⏭ Skipping: 072_correct_100000 [v1]
# ⏭ Skipping: 072_incorrect_100000 [v1]
# ⏭ Skipping: 076_correct_100000 [v1]
# ⏭ Skipping: 076_incorrect_100000 [v1]
# ⏭ Skipping: 078_correct_100000 [v1]
# ⏭ Skipping: 078_incorrect_100000 [v1]
# ⏭ Skipping: 080_correct_100000 [v1]
# ⏭ Skipping: 080_incorrect_100000 [v1]
# ⏭ Skipping: 082_correct_100000 [v1]
# ⏭ Skipping: 082_incorrect_100000 [v1]
# ⏭ Skipping: 083_correct_100000 [v1]
# ⏭ Skipping: 083_incorrect_100000 [v1]
# ⏭ Skipping: 085_correct_100000 [v1]
# ⏭ Skipping: 085_incorrect_100000 [v1]
# ⏭ Skipping: 087_correct_100000 [v1]
# ⏭ Skipping: 087_incorrect_100000 [v1]
# ⏭ Skipping: 089_correct_100000 [v1]
# ⏭ Skipping: 089_incorrect_100000 [v1]
# ⏭ Skipping: 090_correct_100000 [v1]
# ⏭ Skipping: 090_incorrect_100000 [v1]
# ⏭ Skipping: 091_correct_100000 [v1]
# ⏭ Skipping: 091_incorrect_100000 [v1]
# ⏭ Skipping: 094_correct_100000 [v1]
# ⏭ Skipping: 094_incorrect_100000 [v1]
# ⏭ Skipping: 095_correct_100000 [v1]
# ⏭ Skipping: 095_incorrect_100000 [v1]
# ⏭ Skipping: 096_correct_100000 [v1]
# ⏭ Skipping: 096_incorrect_100000 [v1]
# ⏭ Skipping: 098_correct_100000 [v1]
# ⏭ Skipping: 098_incorrect_100000 [v1]
# ⏭ Skipping: 100_correct_100000 [v1]
# ⏭ Skipping: 100_incorrect_100000 [v1]
# ⏭ Skipping: 001_correct_1000000 [v1]
# ⏭ Skipping: 001_incorrect_1000000 [v1]
# ⏭ Skipping: 003_correct_1000000 [v1]
# ⏭ Skipping: 003_incorrect_1000000 [v1]
# ⏭ Skipping: 004_correct_1000000 [v1]
# ⏭ Skipping: 004_incorrect_1000000 [v1]
# ⏭ Skipping: 005_correct_1000000 [v1]
# ⏭ Skipping: 005_incorrect_1000000 [v1]
# ⏭ Skipping: 006_correct_1000000 [v1]
# ⏭ Skipping: 006_incorrect_1000000 [v1]
# ⏭ Skipping: 007_correct_1000000 [v1]
# ⏭ Skipping: 007_incorrect_1000000 [v1]
# ⏭ Skipping: 012_correct_1000000 [v1]
# ⏭ Skipping: 012_incorrect_1000000 [v1]
# ⏭ Skipping: 014_correct_1000000 [v1]
# ⏭ Skipping: 014_incorrect_1000000 [v1]
# ⏭ Skipping: 015_correct_1000000 [v1]
# ⏭ Skipping: 015_incorrect_1000000 [v1]
# ⏭ Skipping: 017_correct_1000000 [v1]
# ⏭ Skipping: 017_incorrect_1000000 [v1]
# ⏭ Skipping: 018_correct_1000000 [v1]
# ⏭ Skipping: 018_incorrect_1000000 [v1]
# ⏭ Skipping: 020_correct_1000000 [v1]
# ⏭ Skipping: 020_incorrect_1000000 [v1]
# ⏭ Skipping: 021_correct_1000000 [v1]
# ⏭ Skipping: 021_incorrect_1000000 [v1]
# ⏭ Skipping: 023_correct_1000000 [v1]
# ⏭ Skipping: 023_incorrect_1000000 [v1]
# ⏭ Skipping: 025_correct_1000000 [v1]
# ⏭ Skipping: 025_incorrect_1000000 [v1]
# ⏭ Skipping: 026_correct_1000000 [v1]
# ⏭ Skipping: 026_incorrect_1000000 [v1]
# ⏭ Skipping: 028_correct_1000000 [v1]
# ⏭ Skipping: 028_incorrect_1000000 [v1]
# ⏭ Skipping: 029_correct_1000000 [v1]
# ⏭ Skipping: 029_incorrect_1000000 [v1]
# ⏭ Skipping: 030_correct_1000000 [v1]
# ⏭ Skipping: 030_incorrect_1000000 [v1]
# ⏭ Skipping: 032_correct_1000000 [v1]
# ⏭ Skipping: 032_incorrect_1000000 [v1]
# ⏭ Skipping: 036_correct_1000000 [v1]
# ⏭ Skipping: 036_incorrect_1000000 [v1]
# ⏭ Skipping: 039_correct_1000000 [v1]
# ⏭ Skipping: 039_incorrect_1000000 [v1]
# ⏭ Skipping: 044_correct_1000000 [v1]
# ⏭ Skipping: 044_incorrect_1000000 [v1]
# ⏭ Skipping: 047_correct_1000000 [v1]
# ⏭ Skipping: 047_incorrect_1000000 [v1]
# ⏭ Skipping: 052_correct_1000000 [v1]
# ⏭ Skipping: 052_incorrect_1000000 [v1]
# ⏭ Skipping: 054_correct_1000000 [v1]
# ⏭ Skipping: 054_incorrect_1000000 [v1]
# ⏭ Skipping: 055_correct_1000000 [v1]
# ⏭ Skipping: 055_incorrect_1000000 [v1]
# ⏭ Skipping: 058_correct_1000000 [v1]
# ⏭ Skipping: 058_incorrect_1000000 [v1]
# ⏭ Skipping: 059_correct_1000000 [v1]
# ⏭ Skipping: 059_incorrect_1000000 [v1]
# ⏭ Skipping: 063_correct_1000000 [v1]
# ⏭ Skipping: 063_incorrect_1000000 [v1]
# ⏭ Skipping: 065_correct_1000000 [v1]
# ⏭ Skipping: 065_incorrect_1000000 [v1]
# ⏭ Skipping: 068_correct_1000000 [v1]
# ⏭ Skipping: 068_incorrect_1000000 [v1]
# ⏭ Skipping: 069_correct_1000000 [v1]
# ⏭ Skipping: 069_incorrect_1000000 [v1]
# ⏭ Skipping: 070_correct_1000000 [v1]
# ⏭ Skipping: 070_incorrect_1000000 [v1]
# ⏭ Skipping: 072_correct_1000000 [v1]
# ⏭ Skipping: 072_incorrect_1000000 [v1]
# ⏭ Skipping: 076_correct_1000000 [v1]
# ⏭ Skipping: 076_incorrect_1000000 [v1]
# ⏭ Skipping: 078_correct_1000000 [v1]
# ⏭ Skipping: 078_incorrect_1000000 [v1]
# ⏭ Skipping: 080_correct_1000000 [v1]
# ⏭ Skipping: 080_incorrect_1000000 [v1]
# ⏭ Skipping: 082_correct_1000000 [v1]
# ⏭ Skipping: 082_incorrect_1000000 [v1]
# ⏭ Skipping: 083_correct_1000000 [v1]
# ⏭ Skipping: 083_incorrect_1000000 [v1]
# ⏭ Skipping: 085_correct_1000000 [v1]
# ⏭ Skipping: 085_incorrect_1000000 [v1]
# ⏭ Skipping: 087_correct_1000000 [v1]
# ⏭ Skipping: 087_incorrect_1000000 [v1]
# ⏭ Skipping: 089_correct_1000000 [v1]
# ⏭ Skipping: 089_incorrect_1000000 [v1]
# ⏭ Skipping: 090_correct_1000000 [v1]
# ⏭ Skipping: 090_incorrect_1000000 [v1]
# ⏭ Skipping: 091_correct_1000000 [v1]
# ⏭ Skipping: 091_incorrect_1000000 [v1]
# ⏭ Skipping: 094_correct_1000000 [v1]
# ⏭ Skipping: 094_incorrect_1000000 [v1]
# ⏭ Skipping: 095_correct_1000000 [v1]
# ⏭ Skipping: 095_incorrect_1000000 [v1]
# ⏭ Skipping: 096_correct_1000000 [v1]
# ⏭ Skipping: 096_incorrect_1000000 [v1]
# ⏭ Skipping: 098_correct_1000000 [v1]
# ⏭ Skipping: 098_incorrect_1000000 [v1]
# ⏭ Skipping: 100_correct_1000000 [v1]
# ⏭ Skipping: 100_incorrect_1000000 [v1]
#
# ============================================================
# Running: v2
# ============================================================
# ⏭ Skipping: 001_correct_10 [v2]
# ⏭ Skipping: 001_incorrect_10 [v2]
# ⏭ Skipping: 003_correct_10 [v2]
# ⏭ Skipping: 003_incorrect_10 [v2]
# ⏭ Skipping: 004_correct_10 [v2]
# ⏭ Skipping: 004_incorrect_10 [v2]
# ⏭ Skipping: 005_correct_10 [v2]
# ⏭ Skipping: 005_incorrect_10 [v2]
# ⏭ Skipping: 006_correct_10 [v2]
# ⏭ Skipping: 006_incorrect_10 [v2]
# ⏭ Skipping: 007_correct_10 [v2]
# ⏭ Skipping: 007_incorrect_10 [v2]
# ⏭ Skipping: 012_correct_10 [v2]
# ⏭ Skipping: 012_incorrect_10 [v2]
# ⏭ Skipping: 014_correct_10 [v2]
# ⏭ Skipping: 014_incorrect_10 [v2]
# ⏭ Skipping: 015_correct_10 [v2]
# ⏭ Skipping: 015_incorrect_10 [v2]
# ⏭ Skipping: 017_correct_10 [v2]
# ⏭ Skipping: 017_incorrect_10 [v2]
# ⏭ Skipping: 018_correct_10 [v2]
# ⏭ Skipping: 018_incorrect_10 [v2]
# ⏭ Skipping: 020_correct_10 [v2]
# ⏭ Skipping: 020_incorrect_10 [v2]
# ⏭ Skipping: 021_correct_10 [v2]
# ⏭ Skipping: 021_incorrect_10 [v2]
# ⏭ Skipping: 023_correct_10 [v2]
# ⏭ Skipping: 023_incorrect_10 [v2]
# ⏭ Skipping: 025_correct_10 [v2]
# ⏭ Skipping: 025_incorrect_10 [v2]
# ⏭ Skipping: 026_correct_10 [v2]
# ⏭ Skipping: 026_incorrect_10 [v2]
# ⏭ Skipping: 028_correct_10 [v2]
# ⏭ Skipping: 028_incorrect_10 [v2]
# ⏭ Skipping: 029_correct_10 [v2]
# ⏭ Skipping: 029_incorrect_10 [v2]
# ⏭ Skipping: 030_correct_10 [v2]
# ⏭ Skipping: 030_incorrect_10 [v2]
# ⏭ Skipping: 032_correct_10 [v2]
# ⏭ Skipping: 032_incorrect_10 [v2]
# ⏭ Skipping: 036_correct_10 [v2]
# ⏭ Skipping: 036_incorrect_10 [v2]
# ⏭ Skipping: 039_correct_10 [v2]
# ⏭ Skipping: 039_incorrect_10 [v2]
# ⏭ Skipping: 044_correct_10 [v2]
# ⏭ Skipping: 044_incorrect_10 [v2]
# ⏭ Skipping: 047_correct_10 [v2]
# ⏭ Skipping: 047_incorrect_10 [v2]
# ⏭ Skipping: 052_correct_10 [v2]
# ⏭ Skipping: 052_incorrect_10 [v2]
# ⏭ Skipping: 054_correct_10 [v2]
# ⏭ Skipping: 054_incorrect_10 [v2]
# ⏭ Skipping: 055_correct_10 [v2]
# ⏭ Skipping: 055_incorrect_10 [v2]
# ⏭ Skipping: 058_correct_10 [v2]
# ⏭ Skipping: 058_incorrect_10 [v2]
# ⏭ Skipping: 059_correct_10 [v2]
# ⏭ Skipping: 059_incorrect_10 [v2]
# ⏭ Skipping: 063_correct_10 [v2]
# ⏭ Skipping: 063_incorrect_10 [v2]
# ⏭ Skipping: 065_correct_10 [v2]
# ⏭ Skipping: 065_incorrect_10 [v2]
# ⏭ Skipping: 068_correct_10 [v2]
# ⏭ Skipping: 068_incorrect_10 [v2]
# ⏭ Skipping: 069_correct_10 [v2]
# ⏭ Skipping: 069_incorrect_10 [v2]
# ⏭ Skipping: 070_correct_10 [v2]
# ⏭ Skipping: 070_incorrect_10 [v2]
# ⏭ Skipping: 072_correct_10 [v2]
# ⏭ Skipping: 072_incorrect_10 [v2]
# ⏭ Skipping: 076_correct_10 [v2]
# ⏭ Skipping: 076_incorrect_10 [v2]
# ⏭ Skipping: 078_correct_10 [v2]
# ⏭ Skipping: 078_incorrect_10 [v2]
# ⏭ Skipping: 080_correct_10 [v2]
# ⏭ Skipping: 080_incorrect_10 [v2]
# ⏭ Skipping: 082_correct_10 [v2]
# ⏭ Skipping: 082_incorrect_10 [v2]
# ⏭ Skipping: 083_correct_10 [v2]
# ⏭ Skipping: 083_incorrect_10 [v2]
# ⏭ Skipping: 085_correct_10 [v2]
# ⏭ Skipping: 085_incorrect_10 [v2]
# ⏭ Skipping: 087_correct_10 [v2]
# ⏭ Skipping: 087_incorrect_10 [v2]
# ⏭ Skipping: 089_correct_10 [v2]
# ⏭ Skipping: 089_incorrect_10 [v2]
# ⏭ Skipping: 090_correct_10 [v2]
# ⏭ Skipping: 090_incorrect_10 [v2]
# ⏭ Skipping: 091_correct_10 [v2]
# ⏭ Skipping: 091_incorrect_10 [v2]
# ⏭ Skipping: 094_correct_10 [v2]
# ⏭ Skipping: 094_incorrect_10 [v2]
# ⏭ Skipping: 095_correct_10 [v2]
# ⏭ Skipping: 095_incorrect_10 [v2]
# ⏭ Skipping: 096_correct_10 [v2]
# ⏭ Skipping: 096_incorrect_10 [v2]
# ⏭ Skipping: 098_correct_10 [v2]
# ⏭ Skipping: 098_incorrect_10 [v2]
# ⏭ Skipping: 100_correct_10 [v2]
# ⏭ Skipping: 100_incorrect_10 [v2]
# ⏭ Skipping: 001_correct_100 [v2]
# ⏭ Skipping: 001_incorrect_100 [v2]
# ⏭ Skipping: 003_correct_100 [v2]
# ⏭ Skipping: 003_incorrect_100 [v2]
# ⏭ Skipping: 004_correct_100 [v2]
# ⏭ Skipping: 004_incorrect_100 [v2]
# ⏭ Skipping: 005_correct_100 [v2]
# ⏭ Skipping: 005_incorrect_100 [v2]
# ⏭ Skipping: 006_correct_100 [v2]
# ⏭ Skipping: 006_incorrect_100 [v2]
# ⏭ Skipping: 007_correct_100 [v2]
# ⏭ Skipping: 007_incorrect_100 [v2]
# ⏭ Skipping: 012_correct_100 [v2]
# ⏭ Skipping: 012_incorrect_100 [v2]
# ⏭ Skipping: 014_correct_100 [v2]
# ⏭ Skipping: 014_incorrect_100 [v2]
# ⏭ Skipping: 015_correct_100 [v2]
# ⏭ Skipping: 015_incorrect_100 [v2]
# ⏭ Skipping: 017_correct_100 [v2]
# ⏭ Skipping: 017_incorrect_100 [v2]
# ⏭ Skipping: 018_correct_100 [v2]
# ⏭ Skipping: 018_incorrect_100 [v2]
# ⏭ Skipping: 020_correct_100 [v2]
# ⏭ Skipping: 020_incorrect_100 [v2]
# ⏭ Skipping: 021_correct_100 [v2]
# ⏭ Skipping: 021_incorrect_100 [v2]
# ⏭ Skipping: 023_correct_100 [v2]
# ⏭ Skipping: 023_incorrect_100 [v2]
# ⏭ Skipping: 025_correct_100 [v2]
# ⏭ Skipping: 025_incorrect_100 [v2]
# ⏭ Skipping: 026_correct_100 [v2]
# ⏭ Skipping: 026_incorrect_100 [v2]
# ⏭ Skipping: 028_correct_100 [v2]
# ⏭ Skipping: 028_incorrect_100 [v2]
# ⏭ Skipping: 029_correct_100 [v2]
# ⏭ Skipping: 029_incorrect_100 [v2]
# ⏭ Skipping: 030_correct_100 [v2]
# ⏭ Skipping: 030_incorrect_100 [v2]
# ⏭ Skipping: 032_correct_100 [v2]
# ⏭ Skipping: 032_incorrect_100 [v2]
# ⏭ Skipping: 036_correct_100 [v2]
# ⏭ Skipping: 036_incorrect_100 [v2]
# ⏭ Skipping: 039_correct_100 [v2]
# ⏭ Skipping: 039_incorrect_100 [v2]
# ⏭ Skipping: 044_correct_100 [v2]
# ⏭ Skipping: 044_incorrect_100 [v2]
# ⏭ Skipping: 047_correct_100 [v2]
# ⏭ Skipping: 047_incorrect_100 [v2]
# ⏭ Skipping: 052_correct_100 [v2]
# ⏭ Skipping: 052_incorrect_100 [v2]
# ⏭ Skipping: 054_correct_100 [v2]
# ⏭ Skipping: 054_incorrect_100 [v2]
# ⏭ Skipping: 055_correct_100 [v2]
# ⏭ Skipping: 055_incorrect_100 [v2]
# ⏭ Skipping: 058_correct_100 [v2]
# ⏭ Skipping: 058_incorrect_100 [v2]
# ⏭ Skipping: 059_correct_100 [v2]
# ⏭ Skipping: 059_incorrect_100 [v2]
# ⏭ Skipping: 063_correct_100 [v2]
# ⏭ Skipping: 063_incorrect_100 [v2]
# ⏭ Skipping: 065_correct_100 [v2]
# ⏭ Skipping: 065_incorrect_100 [v2]
# ⏭ Skipping: 068_correct_100 [v2]
# ⏭ Skipping: 068_incorrect_100 [v2]
# ⏭ Skipping: 069_correct_100 [v2]
# ⏭ Skipping: 069_incorrect_100 [v2]
# ⏭ Skipping: 070_correct_100 [v2]
# ⏭ Skipping: 070_incorrect_100 [v2]
# ⏭ Skipping: 072_correct_100 [v2]
# ⏭ Skipping: 072_incorrect_100 [v2]
# ⏭ Skipping: 076_correct_100 [v2]
# ⏭ Skipping: 076_incorrect_100 [v2]
# ⏭ Skipping: 078_correct_100 [v2]
# ⏭ Skipping: 078_incorrect_100 [v2]
# ⏭ Skipping: 080_correct_100 [v2]
# ⏭ Skipping: 080_incorrect_100 [v2]
# ⏭ Skipping: 082_correct_100 [v2]
# ⏭ Skipping: 082_incorrect_100 [v2]
# ⏭ Skipping: 083_correct_100 [v2]
# ⏭ Skipping: 083_incorrect_100 [v2]
# ⏭ Skipping: 085_correct_100 [v2]
# ⏭ Skipping: 085_incorrect_100 [v2]
# ⏭ Skipping: 087_correct_100 [v2]
# ⏭ Skipping: 087_incorrect_100 [v2]
# ⏭ Skipping: 089_correct_100 [v2]
# ⏭ Skipping: 089_incorrect_100 [v2]
# ⏭ Skipping: 090_correct_100 [v2]
# ⏭ Skipping: 090_incorrect_100 [v2]
# ⏭ Skipping: 091_correct_100 [v2]
# ⏭ Skipping: 091_incorrect_100 [v2]
# ⏭ Skipping: 094_correct_100 [v2]
# ⏭ Skipping: 094_incorrect_100 [v2]
# ⏭ Skipping: 095_correct_100 [v2]
# ⏭ Skipping: 095_incorrect_100 [v2]
# ⏭ Skipping: 096_correct_100 [v2]
# ⏭ Skipping: 096_incorrect_100 [v2]
# ⏭ Skipping: 098_correct_100 [v2]
# ⏭ Skipping: 098_incorrect_100 [v2]
# ⏭ Skipping: 100_correct_100 [v2]
# ⏭ Skipping: 100_incorrect_100 [v2]
# ⏭ Skipping: 001_correct_1000 [v2]
# ⏭ Skipping: 001_incorrect_1000 [v2]
# ⏭ Skipping: 003_correct_1000 [v2]
# ⏭ Skipping: 003_incorrect_1000 [v2]
# ⏭ Skipping: 004_correct_1000 [v2]
# ⏭ Skipping: 004_incorrect_1000 [v2]
# ⏭ Skipping: 005_correct_1000 [v2]
# ⏭ Skipping: 005_incorrect_1000 [v2]
# ⏭ Skipping: 006_correct_1000 [v2]
# ⏭ Skipping: 006_incorrect_1000 [v2]
# ⏭ Skipping: 007_correct_1000 [v2]
# ⏭ Skipping: 007_incorrect_1000 [v2]
# ⏭ Skipping: 012_correct_1000 [v2]
# ⏭ Skipping: 012_incorrect_1000 [v2]
# ⏭ Skipping: 014_correct_1000 [v2]
# ⏭ Skipping: 014_incorrect_1000 [v2]
# ⏭ Skipping: 015_correct_1000 [v2]
# ⏭ Skipping: 015_incorrect_1000 [v2]
# ⏭ Skipping: 017_correct_1000 [v2]
# ⏭ Skipping: 017_incorrect_1000 [v2]
# ⏭ Skipping: 018_correct_1000 [v2]
# ⏭ Skipping: 018_incorrect_1000 [v2]
# ⏭ Skipping: 020_correct_1000 [v2]
# ⏭ Skipping: 020_incorrect_1000 [v2]
# ⏭ Skipping: 021_correct_1000 [v2]
# ⏭ Skipping: 021_incorrect_1000 [v2]
# ⏭ Skipping: 023_correct_1000 [v2]
# ⏭ Skipping: 023_incorrect_1000 [v2]
# ⏭ Skipping: 025_correct_1000 [v2]
# ⏭ Skipping: 025_incorrect_1000 [v2]
# ⏭ Skipping: 026_correct_1000 [v2]
# ⏭ Skipping: 026_incorrect_1000 [v2]
# ⏭ Skipping: 028_correct_1000 [v2]
# ⏭ Skipping: 028_incorrect_1000 [v2]
# ⏭ Skipping: 029_correct_1000 [v2]
# ⏭ Skipping: 029_incorrect_1000 [v2]
# ⏭ Skipping: 030_correct_1000 [v2]
# ⏭ Skipping: 030_incorrect_1000 [v2]
# ⏭ Skipping: 032_correct_1000 [v2]
# ⏭ Skipping: 032_incorrect_1000 [v2]
# ⏭ Skipping: 036_correct_1000 [v2]
# ⏭ Skipping: 036_incorrect_1000 [v2]
# ⏭ Skipping: 039_correct_1000 [v2]
# ⏭ Skipping: 039_incorrect_1000 [v2]
# ⏭ Skipping: 044_correct_1000 [v2]
# ⏭ Skipping: 044_incorrect_1000 [v2]
# ⏭ Skipping: 047_correct_1000 [v2]
# ⏭ Skipping: 047_incorrect_1000 [v2]
# ⏭ Skipping: 052_correct_1000 [v2]
# ⏭ Skipping: 052_incorrect_1000 [v2]
# ⏭ Skipping: 054_correct_1000 [v2]
# ⏭ Skipping: 054_incorrect_1000 [v2]
# ⏭ Skipping: 055_correct_1000 [v2]
# ⏭ Skipping: 055_incorrect_1000 [v2]
# ⏭ Skipping: 058_correct_1000 [v2]
# ⏭ Skipping: 058_incorrect_1000 [v2]
# ⏭ Skipping: 059_correct_1000 [v2]
# ⏭ Skipping: 059_incorrect_1000 [v2]
# ⏭ Skipping: 063_correct_1000 [v2]
# ⏭ Skipping: 063_incorrect_1000 [v2]
# ⏭ Skipping: 065_correct_1000 [v2]
# ⏭ Skipping: 065_incorrect_1000 [v2]
# ⏭ Skipping: 068_correct_1000 [v2]
# ⏭ Skipping: 068_incorrect_1000 [v2]
# ⏭ Skipping: 069_correct_1000 [v2]
# ⏭ Skipping: 069_incorrect_1000 [v2]
# ⏭ Skipping: 070_correct_1000 [v2]
# ⏭ Skipping: 070_incorrect_1000 [v2]
# ⏭ Skipping: 072_correct_1000 [v2]
# ⏭ Skipping: 072_incorrect_1000 [v2]
# ⏭ Skipping: 076_correct_1000 [v2]
# ⏭ Skipping: 076_incorrect_1000 [v2]
# ⏭ Skipping: 078_correct_1000 [v2]
# ⏭ Skipping: 078_incorrect_1000 [v2]
# ⏭ Skipping: 080_correct_1000 [v2]
# ⏭ Skipping: 080_incorrect_1000 [v2]
# ⏭ Skipping: 082_correct_1000 [v2]
# ⏭ Skipping: 082_incorrect_1000 [v2]
# ⏭ Skipping: 083_correct_1000 [v2]
# ⏭ Skipping: 083_incorrect_1000 [v2]
# ⏭ Skipping: 085_correct_1000 [v2]
# ⏭ Skipping: 085_incorrect_1000 [v2]
# ⏭ Skipping: 087_correct_1000 [v2]
# ⏭ Skipping: 087_incorrect_1000 [v2]
# ⏭ Skipping: 089_correct_1000 [v2]
# ⏭ Skipping: 089_incorrect_1000 [v2]
# ⏭ Skipping: 090_correct_1000 [v2]
# ⏭ Skipping: 090_incorrect_1000 [v2]
# ⏭ Skipping: 091_correct_1000 [v2]
# ⏭ Skipping: 091_incorrect_1000 [v2]
# ⏭ Skipping: 094_correct_1000 [v2]
# ⏭ Skipping: 094_incorrect_1000 [v2]
# ⏭ Skipping: 095_correct_1000 [v2]
# ⏭ Skipping: 095_incorrect_1000 [v2]
# ⏭ Skipping: 096_correct_1000 [v2]
# ⏭ Skipping: 096_incorrect_1000 [v2]
# ⏭ Skipping: 098_correct_1000 [v2]
# ⏭ Skipping: 098_incorrect_1000 [v2]
# ⏭ Skipping: 100_correct_1000 [v2]
# ⏭ Skipping: 100_incorrect_1000 [v2]
# ⏭ Skipping: 001_correct_10000 [v2]
# ⏭ Skipping: 001_incorrect_10000 [v2]
# ⏭ Skipping: 003_correct_10000 [v2]
# ⏭ Skipping: 003_incorrect_10000 [v2]
# ⏭ Skipping: 004_correct_10000 [v2]
# ⏭ Skipping: 004_incorrect_10000 [v2]
# ⏭ Skipping: 005_correct_10000 [v2]
# ⏭ Skipping: 005_incorrect_10000 [v2]
# ⏭ Skipping: 006_correct_10000 [v2]
# ⏭ Skipping: 006_incorrect_10000 [v2]
# ⏭ Skipping: 007_correct_10000 [v2]
# ⏭ Skipping: 007_incorrect_10000 [v2]
# ⏭ Skipping: 012_correct_10000 [v2]
# ⏭ Skipping: 012_incorrect_10000 [v2]
# ⏭ Skipping: 014_correct_10000 [v2]
# ⏭ Skipping: 014_incorrect_10000 [v2]
# ⏭ Skipping: 015_correct_10000 [v2]
# ⏭ Skipping: 015_incorrect_10000 [v2]
# ⏭ Skipping: 017_correct_10000 [v2]
# ⏭ Skipping: 017_incorrect_10000 [v2]
# ⏭ Skipping: 018_correct_10000 [v2]
# ⏭ Skipping: 018_incorrect_10000 [v2]
# ⏭ Skipping: 020_correct_10000 [v2]
# ⏭ Skipping: 020_incorrect_10000 [v2]
# ⏭ Skipping: 021_correct_10000 [v2]
# ⏭ Skipping: 021_incorrect_10000 [v2]
# ⏭ Skipping: 023_correct_10000 [v2]
# ⏭ Skipping: 023_incorrect_10000 [v2]
# ⏭ Skipping: 025_correct_10000 [v2]
# ⏭ Skipping: 025_incorrect_10000 [v2]
# ⏭ Skipping: 026_correct_10000 [v2]
# ⏭ Skipping: 026_incorrect_10000 [v2]
# ⏭ Skipping: 028_correct_10000 [v2]
# ⏭ Skipping: 028_incorrect_10000 [v2]
# ⏭ Skipping: 029_correct_10000 [v2]
# ⏭ Skipping: 029_incorrect_10000 [v2]
# ⏭ Skipping: 030_correct_10000 [v2]
# ⏭ Skipping: 030_incorrect_10000 [v2]
# ⏭ Skipping: 032_correct_10000 [v2]
# ⏭ Skipping: 032_incorrect_10000 [v2]
# ⏭ Skipping: 036_correct_10000 [v2]
# ⏭ Skipping: 036_incorrect_10000 [v2]
# ⏭ Skipping: 039_correct_10000 [v2]
# ⏭ Skipping: 039_incorrect_10000 [v2]
# ⏭ Skipping: 044_correct_10000 [v2]
# ⏭ Skipping: 044_incorrect_10000 [v2]
# ⏭ Skipping: 047_correct_10000 [v2]
# ⏭ Skipping: 047_incorrect_10000 [v2]
# ⏭ Skipping: 052_correct_10000 [v2]
# ⏭ Skipping: 052_incorrect_10000 [v2]
# ⏭ Skipping: 054_correct_10000 [v2]
# ⏭ Skipping: 054_incorrect_10000 [v2]
# ⏭ Skipping: 055_correct_10000 [v2]
# ⏭ Skipping: 055_incorrect_10000 [v2]
# ⏭ Skipping: 058_correct_10000 [v2]
# ⏭ Skipping: 058_incorrect_10000 [v2]
# ⏭ Skipping: 059_correct_10000 [v2]
# ⏭ Skipping: 059_incorrect_10000 [v2]
# ⏭ Skipping: 063_correct_10000 [v2]
# ⏭ Skipping: 063_incorrect_10000 [v2]
# ⏭ Skipping: 065_correct_10000 [v2]
# ⏭ Skipping: 065_incorrect_10000 [v2]
# ⏭ Skipping: 068_correct_10000 [v2]
# ⏭ Skipping: 068_incorrect_10000 [v2]
# ⏭ Skipping: 069_correct_10000 [v2]
# ⏭ Skipping: 069_incorrect_10000 [v2]
# ⏭ Skipping: 070_correct_10000 [v2]
# ⏭ Skipping: 070_incorrect_10000 [v2]
# ⏭ Skipping: 072_correct_10000 [v2]
# ⏭ Skipping: 072_incorrect_10000 [v2]
# ⏭ Skipping: 076_correct_10000 [v2]
# ⏭ Skipping: 076_incorrect_10000 [v2]
# ⏭ Skipping: 078_correct_10000 [v2]
# ⏭ Skipping: 078_incorrect_10000 [v2]
# ⏭ Skipping: 080_correct_10000 [v2]
# ⏭ Skipping: 080_incorrect_10000 [v2]
# ⏭ Skipping: 082_correct_10000 [v2]
# ⏭ Skipping: 082_incorrect_10000 [v2]
# ⏭ Skipping: 083_correct_10000 [v2]
# ⏭ Skipping: 083_incorrect_10000 [v2]
# ⏭ Skipping: 085_correct_10000 [v2]
# ⏭ Skipping: 085_incorrect_10000 [v2]
# ⏭ Skipping: 087_correct_10000 [v2]
# ⏭ Skipping: 087_incorrect_10000 [v2]
# ⏭ Skipping: 089_correct_10000 [v2]
# ⏭ Skipping: 089_incorrect_10000 [v2]
# ⏭ Skipping: 090_correct_10000 [v2]
# ⏭ Skipping: 090_incorrect_10000 [v2]
# ⏭ Skipping: 091_correct_10000 [v2]
# ⏭ Skipping: 091_incorrect_10000 [v2]
# ⏭ Skipping: 094_correct_10000 [v2]
# ⏭ Skipping: 094_incorrect_10000 [v2]
# ⏭ Skipping: 095_correct_10000 [v2]
# ⏭ Skipping: 095_incorrect_10000 [v2]
# ⏭ Skipping: 096_correct_10000 [v2]
# ⏭ Skipping: 096_incorrect_10000 [v2]
# ⏭ Skipping: 098_correct_10000 [v2]
# ⏭ Skipping: 098_incorrect_10000 [v2]
# ⏭ Skipping: 100_correct_10000 [v2]
# ⏭ Skipping: 100_incorrect_10000 [v2]
# ⏭ Skipping: 001_correct_100000 [v2]
# ⏭ Skipping: 001_incorrect_100000 [v2]
# ⏭ Skipping: 003_correct_100000 [v2]
# ⏭ Skipping: 003_incorrect_100000 [v2]
# ⏭ Skipping: 004_correct_100000 [v2]
# ⏭ Skipping: 004_incorrect_100000 [v2]
# ⏭ Skipping: 005_correct_100000 [v2]
# ⏭ Skipping: 005_incorrect_100000 [v2]
# ⏭ Skipping: 006_correct_100000 [v2]
# ⏭ Skipping: 006_incorrect_100000 [v2]
# ⏭ Skipping: 007_correct_100000 [v2]
# ⏭ Skipping: 007_incorrect_100000 [v2]
# ⏭ Skipping: 012_correct_100000 [v2]
# ⏭ Skipping: 012_incorrect_100000 [v2]
# ⏭ Skipping: 014_correct_100000 [v2]
# ⏭ Skipping: 014_incorrect_100000 [v2]
# ⏭ Skipping: 015_correct_100000 [v2]
# ⏭ Skipping: 015_incorrect_100000 [v2]
# ⏭ Skipping: 017_correct_100000 [v2]
# ⏭ Skipping: 017_incorrect_100000 [v2]
# ⏭ Skipping: 018_correct_100000 [v2]
# ⏭ Skipping: 018_incorrect_100000 [v2]
# ⏭ Skipping: 020_correct_100000 [v2]
# ⏭ Skipping: 020_incorrect_100000 [v2]
# ⏭ Skipping: 021_correct_100000 [v2]
# ⏭ Skipping: 021_incorrect_100000 [v2]
# ⏭ Skipping: 023_correct_100000 [v2]
# ⏭ Skipping: 023_incorrect_100000 [v2]
# ⏭ Skipping: 025_correct_100000 [v2]
# ⏭ Skipping: 025_incorrect_100000 [v2]
# ⏭ Skipping: 026_correct_100000 [v2]
# ⏭ Skipping: 026_incorrect_100000 [v2]
# ⏭ Skipping: 028_correct_100000 [v2]
# ⏭ Skipping: 028_incorrect_100000 [v2]
# ⏭ Skipping: 029_correct_100000 [v2]
# ⏭ Skipping: 029_incorrect_100000 [v2]
# ⏭ Skipping: 030_correct_100000 [v2]
# ⏭ Skipping: 030_incorrect_100000 [v2]
# ⏭ Skipping: 032_correct_100000 [v2]
# ⏭ Skipping: 032_incorrect_100000 [v2]
# ⏭ Skipping: 036_correct_100000 [v2]
# ⏭ Skipping: 036_incorrect_100000 [v2]
# ⏭ Skipping: 039_correct_100000 [v2]
# ⏭ Skipping: 039_incorrect_100000 [v2]
# ⏭ Skipping: 044_correct_100000 [v2]
# ⏭ Skipping: 044_incorrect_100000 [v2]
# ⏭ Skipping: 047_correct_100000 [v2]
# ⏭ Skipping: 047_incorrect_100000 [v2]
# ⏭ Skipping: 052_correct_100000 [v2]
# ⏭ Skipping: 052_incorrect_100000 [v2]
# ⏭ Skipping: 054_correct_100000 [v2]
# ⏭ Skipping: 054_incorrect_100000 [v2]
# ⏭ Skipping: 055_correct_100000 [v2]
# ⏭ Skipping: 055_incorrect_100000 [v2]
# ⏭ Skipping: 058_correct_100000 [v2]
# ⏭ Skipping: 058_incorrect_100000 [v2]
# ⏭ Skipping: 059_correct_100000 [v2]
# ⏭ Skipping: 059_incorrect_100000 [v2]
# ⏭ Skipping: 063_correct_100000 [v2]
# ⏭ Skipping: 063_incorrect_100000 [v2]
# ⏭ Skipping: 065_correct_100000 [v2]
# ⏭ Skipping: 065_incorrect_100000 [v2]
# ⏭ Skipping: 068_correct_100000 [v2]
# ⏭ Skipping: 068_incorrect_100000 [v2]
# ⏭ Skipping: 069_correct_100000 [v2]
# ⏭ Skipping: 069_incorrect_100000 [v2]
# ⏭ Skipping: 070_correct_100000 [v2]
# ⏭ Skipping: 070_incorrect_100000 [v2]
# ⏭ Skipping: 072_correct_100000 [v2]
# ⏭ Skipping: 072_incorrect_100000 [v2]
# ⏭ Skipping: 076_correct_100000 [v2]
# ⏭ Skipping: 076_incorrect_100000 [v2]
# ⏭ Skipping: 078_correct_100000 [v2]
# ⏭ Skipping: 078_incorrect_100000 [v2]
# ⏭ Skipping: 080_correct_100000 [v2]
# ⏭ Skipping: 080_incorrect_100000 [v2]
# ⏭ Skipping: 082_correct_100000 [v2]
# ⏭ Skipping: 082_incorrect_100000 [v2]
# ⏭ Skipping: 083_correct_100000 [v2]
# ⏭ Skipping: 083_incorrect_100000 [v2]
# ⏭ Skipping: 085_correct_100000 [v2]
# ⏭ Skipping: 085_incorrect_100000 [v2]
# ⏭ Skipping: 087_correct_100000 [v2]
# ⏭ Skipping: 087_incorrect_100000 [v2]
# ⏭ Skipping: 089_correct_100000 [v2]
# ⏭ Skipping: 089_incorrect_100000 [v2]
# ⏭ Skipping: 090_correct_100000 [v2]
# ⏭ Skipping: 090_incorrect_100000 [v2]
# ⏭ Skipping: 091_correct_100000 [v2]
# ⏭ Skipping: 091_incorrect_100000 [v2]
# ⏭ Skipping: 094_correct_100000 [v2]
# ⏭ Skipping: 094_incorrect_100000 [v2]
# ⏭ Skipping: 095_correct_100000 [v2]
# ⏭ Skipping: 095_incorrect_100000 [v2]
# ⏭ Skipping: 096_correct_100000 [v2]
# ⏭ Skipping: 096_incorrect_100000 [v2]
# ⏭ Skipping: 098_correct_100000 [v2]
# ⏭ Skipping: 098_incorrect_100000 [v2]
# ⏭ Skipping: 100_correct_100000 [v2]
# ⏭ Skipping: 100_incorrect_100000 [v2]
# ⏭ Skipping: 001_correct_1000000 [v2]
# ⏭ Skipping: 001_incorrect_1000000 [v2]
# ⏭ Skipping: 003_correct_1000000 [v2]
# ⏭ Skipping: 003_incorrect_1000000 [v2]
# ⏭ Skipping: 004_correct_1000000 [v2]
# ⏭ Skipping: 004_incorrect_1000000 [v2]
# ⏭ Skipping: 005_correct_1000000 [v2]
# ⏭ Skipping: 005_incorrect_1000000 [v2]
# ⏭ Skipping: 006_correct_1000000 [v2]
# ⏭ Skipping: 006_incorrect_1000000 [v2]
# ⏭ Skipping: 007_correct_1000000 [v2]
# ⏭ Skipping: 007_incorrect_1000000 [v2]
# ⏭ Skipping: 012_correct_1000000 [v2]
# ⏭ Skipping: 012_incorrect_1000000 [v2]
# ⏭ Skipping: 014_correct_1000000 [v2]
# ⏭ Skipping: 014_incorrect_1000000 [v2]
# ⏭ Skipping: 015_correct_1000000 [v2]
# ⏭ Skipping: 015_incorrect_1000000 [v2]
# ⏭ Skipping: 017_correct_1000000 [v2]
# ⏭ Skipping: 017_incorrect_1000000 [v2]
# ⏭ Skipping: 018_correct_1000000 [v2]
# ⏭ Skipping: 018_incorrect_1000000 [v2]
# ⏭ Skipping: 020_correct_1000000 [v2]
# ⏭ Skipping: 020_incorrect_1000000 [v2]
# ⏭ Skipping: 021_correct_1000000 [v2]
# ⏭ Skipping: 021_incorrect_1000000 [v2]
# ⏭ Skipping: 023_correct_1000000 [v2]
# ⏭ Skipping: 023_incorrect_1000000 [v2]
# ⏭ Skipping: 025_correct_1000000 [v2]
# ⏭ Skipping: 025_incorrect_1000000 [v2]
# ⏭ Skipping: 026_correct_1000000 [v2]
# ⏭ Skipping: 026_incorrect_1000000 [v2]
# ⏭ Skipping: 028_correct_1000000 [v2]
# ⏭ Skipping: 028_incorrect_1000000 [v2]
# ⏭ Skipping: 029_correct_1000000 [v2]
# ⏭ Skipping: 029_incorrect_1000000 [v2]
# ⏭ Skipping: 030_correct_1000000 [v2]
# ⏭ Skipping: 030_incorrect_1000000 [v2]
# ⏭ Skipping: 032_correct_1000000 [v2]
# ⏭ Skipping: 032_incorrect_1000000 [v2]
# ⏭ Skipping: 036_correct_1000000 [v2]
# ⏭ Skipping: 036_incorrect_1000000 [v2]
# ⏭ Skipping: 039_correct_1000000 [v2]
# ⏭ Skipping: 039_incorrect_1000000 [v2]
# ⏭ Skipping: 044_correct_1000000 [v2]
# ⏭ Skipping: 044_incorrect_1000000 [v2]
# ⏭ Skipping: 047_correct_1000000 [v2]
# ⏭ Skipping: 047_incorrect_1000000 [v2]
# ⏭ Skipping: 052_correct_1000000 [v2]
# ⏭ Skipping: 052_incorrect_1000000 [v2]
# ⏭ Skipping: 054_correct_1000000 [v2]
# ⏭ Skipping: 054_incorrect_1000000 [v2]
# ⏭ Skipping: 055_correct_1000000 [v2]
# ⏭ Skipping: 055_incorrect_1000000 [v2]
# ⏭ Skipping: 058_correct_1000000 [v2]
# ⏭ Skipping: 058_incorrect_1000000 [v2]
# ⏭ Skipping: 059_correct_1000000 [v2]
# ⏭ Skipping: 059_incorrect_1000000 [v2]
# ⏭ Skipping: 063_correct_1000000 [v2]
# ⏭ Skipping: 063_incorrect_1000000 [v2]
# ⏭ Skipping: 065_correct_1000000 [v2]
# ⏭ Skipping: 065_incorrect_1000000 [v2]
# ⏭ Skipping: 068_correct_1000000 [v2]
# ⏭ Skipping: 068_incorrect_1000000 [v2]
# ⏭ Skipping: 069_correct_1000000 [v2]
# ⏭ Skipping: 069_incorrect_1000000 [v2]
# ⏭ Skipping: 070_correct_1000000 [v2]
# ⏭ Skipping: 070_incorrect_1000000 [v2]
# ⏭ Skipping: 072_correct_1000000 [v2]
# ⏭ Skipping: 072_incorrect_1000000 [v2]
# ⏭ Skipping: 076_correct_1000000 [v2]
# ⏭ Skipping: 076_incorrect_1000000 [v2]
# ⏭ Skipping: 078_correct_1000000 [v2]
# ⏭ Skipping: 078_incorrect_1000000 [v2]
# ⏭ Skipping: 080_correct_1000000 [v2]
# ⏭ Skipping: 080_incorrect_1000000 [v2]
# ⏭ Skipping: 082_correct_1000000 [v2]
# ⏭ Skipping: 082_incorrect_1000000 [v2]
# ⏭ Skipping: 083_correct_1000000 [v2]
# ⏭ Skipping: 083_incorrect_1000000 [v2]
# ⏭ Skipping: 085_correct_1000000 [v2]
# ⏭ Skipping: 085_incorrect_1000000 [v2]
# ⏭ Skipping: 087_correct_1000000 [v2]
# ⏭ Skipping: 087_incorrect_1000000 [v2]
# ⏭ Skipping: 089_correct_1000000 [v2]
# ⏭ Skipping: 089_incorrect_1000000 [v2]
# ⏭ Skipping: 090_correct_1000000 [v2]
# ⏭ Skipping: 090_incorrect_1000000 [v2]
# ⏭ Skipping: 091_correct_1000000 [v2]
# ⏭ Skipping: 091_incorrect_1000000 [v2]
# ⏭ Skipping: 094_correct_1000000 [v2]
# ⏭ Skipping: 094_incorrect_1000000 [v2]
# ⏭ Skipping: 095_correct_1000000 [v2]
# ⏭ Skipping: 095_incorrect_1000000 [v2]
# ⏭ Skipping: 096_correct_1000000 [v2]
# ⏭ Skipping: 096_incorrect_1000000 [v2]
# ⏭ Skipping: 098_correct_1000000 [v2]
# ⏭ Skipping: 098_incorrect_1000000 [v2]
# ⏭ Skipping: 100_correct_1000000 [v2]
# ⏭ Skipping: 100_incorrect_1000000 [v2]
#
# ============================================================
# Running: v3
# ============================================================
# ⏭ Skipping: 001_correct_10 [v3]
# ⏭ Skipping: 001_incorrect_10 [v3]
# ⏭ Skipping: 003_correct_10 [v3]
# ⏭ Skipping: 003_incorrect_10 [v3]
# ⏭ Skipping: 004_correct_10 [v3]
# ⏭ Skipping: 004_incorrect_10 [v3]
# ⏭ Skipping: 005_correct_10 [v3]
# ⏭ Skipping: 005_incorrect_10 [v3]
# ⏭ Skipping: 006_correct_10 [v3]
# ⏭ Skipping: 006_incorrect_10 [v3]
# ⏭ Skipping: 007_correct_10 [v3]
# ⏭ Skipping: 007_incorrect_10 [v3]
# ⏭ Skipping: 012_correct_10 [v3]
# ⏭ Skipping: 012_incorrect_10 [v3]
# ⏭ Skipping: 014_correct_10 [v3]
# ⏭ Skipping: 014_incorrect_10 [v3]
# ⏭ Skipping: 015_correct_10 [v3]
# ⏭ Skipping: 015_incorrect_10 [v3]
# ⏭ Skipping: 017_correct_10 [v3]
# ⏭ Skipping: 017_incorrect_10 [v3]
# ⏭ Skipping: 018_correct_10 [v3]
# ⏭ Skipping: 018_incorrect_10 [v3]
# ⏭ Skipping: 020_correct_10 [v3]
# ⏭ Skipping: 020_incorrect_10 [v3]
# ⏭ Skipping: 021_correct_10 [v3]
# ⏭ Skipping: 021_incorrect_10 [v3]
# ⏭ Skipping: 023_correct_10 [v3]
# ⏭ Skipping: 023_incorrect_10 [v3]
# ⏭ Skipping: 025_correct_10 [v3]
# ⏭ Skipping: 025_incorrect_10 [v3]
# ⏭ Skipping: 026_correct_10 [v3]
# ⏭ Skipping: 026_incorrect_10 [v3]
# ⏭ Skipping: 028_correct_10 [v3]
# ⏭ Skipping: 028_incorrect_10 [v3]
# ⏭ Skipping: 029_correct_10 [v3]
# ⏭ Skipping: 029_incorrect_10 [v3]
# ⏭ Skipping: 030_correct_10 [v3]
# ⏭ Skipping: 030_incorrect_10 [v3]
# ⏭ Skipping: 032_correct_10 [v3]
# ⏭ Skipping: 032_incorrect_10 [v3]
# ⏭ Skipping: 036_correct_10 [v3]
# ⏭ Skipping: 036_incorrect_10 [v3]
# ⏭ Skipping: 039_correct_10 [v3]
# ⏭ Skipping: 039_incorrect_10 [v3]
# ⏭ Skipping: 044_correct_10 [v3]
# ⏭ Skipping: 044_incorrect_10 [v3]
# ⏭ Skipping: 047_correct_10 [v3]
# ⏭ Skipping: 047_incorrect_10 [v3]
# ⏭ Skipping: 052_correct_10 [v3]
# ⏭ Skipping: 052_incorrect_10 [v3]
# ⏭ Skipping: 054_correct_10 [v3]
# ⏭ Skipping: 054_incorrect_10 [v3]
# ⏭ Skipping: 055_correct_10 [v3]
# ⏭ Skipping: 055_incorrect_10 [v3]
# ⏭ Skipping: 058_correct_10 [v3]
# ⏭ Skipping: 058_incorrect_10 [v3]
# ⏭ Skipping: 059_correct_10 [v3]
# ⏭ Skipping: 059_incorrect_10 [v3]
# ⏭ Skipping: 063_correct_10 [v3]
# ⏭ Skipping: 063_incorrect_10 [v3]
# ⏭ Skipping: 065_correct_10 [v3]
# ⏭ Skipping: 065_incorrect_10 [v3]
# ⏭ Skipping: 068_correct_10 [v3]
# ⏭ Skipping: 068_incorrect_10 [v3]
# ⏭ Skipping: 069_correct_10 [v3]
# ⏭ Skipping: 069_incorrect_10 [v3]
# ⏭ Skipping: 070_correct_10 [v3]
# ⏭ Skipping: 070_incorrect_10 [v3]
# ⏭ Skipping: 072_correct_10 [v3]
# ⏭ Skipping: 072_incorrect_10 [v3]
# ⏭ Skipping: 076_correct_10 [v3]
# ⏭ Skipping: 076_incorrect_10 [v3]
# ⏭ Skipping: 078_correct_10 [v3]
# ⏭ Skipping: 078_incorrect_10 [v3]
# ⏭ Skipping: 080_correct_10 [v3]
# ⏭ Skipping: 080_incorrect_10 [v3]
# ⏭ Skipping: 082_correct_10 [v3]
# ⏭ Skipping: 082_incorrect_10 [v3]
# ⏭ Skipping: 083_correct_10 [v3]
# ⏭ Skipping: 083_incorrect_10 [v3]
# ⏭ Skipping: 085_correct_10 [v3]
# ⏭ Skipping: 085_incorrect_10 [v3]
# ⏭ Skipping: 087_correct_10 [v3]
# ⏭ Skipping: 087_incorrect_10 [v3]
# ⏭ Skipping: 089_correct_10 [v3]
# ⏭ Skipping: 089_incorrect_10 [v3]
# ⏭ Skipping: 090_correct_10 [v3]
# ⏭ Skipping: 090_incorrect_10 [v3]
# ⏭ Skipping: 091_correct_10 [v3]
# ⏭ Skipping: 091_incorrect_10 [v3]
# ⏭ Skipping: 094_correct_10 [v3]
# ⏭ Skipping: 094_incorrect_10 [v3]
# ⏭ Skipping: 095_correct_10 [v3]
# ⏭ Skipping: 095_incorrect_10 [v3]
# ⏭ Skipping: 096_correct_10 [v3]
# ⏭ Skipping: 096_incorrect_10 [v3]
# ⏭ Skipping: 098_correct_10 [v3]
# ⏭ Skipping: 098_incorrect_10 [v3]
# ⏭ Skipping: 100_correct_10 [v3]
# ⏭ Skipping: 100_incorrect_10 [v3]
# ⏭ Skipping: 001_correct_100 [v3]
# ⏭ Skipping: 001_incorrect_100 [v3]
# ⏭ Skipping: 003_correct_100 [v3]
# ⏭ Skipping: 003_incorrect_100 [v3]
# ⏭ Skipping: 004_correct_100 [v3]
# ⏭ Skipping: 004_incorrect_100 [v3]
# ⏭ Skipping: 005_correct_100 [v3]
# ⏭ Skipping: 005_incorrect_100 [v3]
# ⏭ Skipping: 006_correct_100 [v3]
# ⏭ Skipping: 006_incorrect_100 [v3]
# ⏭ Skipping: 007_correct_100 [v3]
# ⏭ Skipping: 007_incorrect_100 [v3]
# ⏭ Skipping: 012_correct_100 [v3]
# ⏭ Skipping: 012_incorrect_100 [v3]
# ⏭ Skipping: 014_correct_100 [v3]
# ⏭ Skipping: 014_incorrect_100 [v3]
# ⏭ Skipping: 015_correct_100 [v3]
# ⏭ Skipping: 015_incorrect_100 [v3]
# ⏭ Skipping: 017_correct_100 [v3]
# ⏭ Skipping: 017_incorrect_100 [v3]
# ⏭ Skipping: 018_correct_100 [v3]
# ⏭ Skipping: 018_incorrect_100 [v3]
# ⏭ Skipping: 020_correct_100 [v3]
# ⏭ Skipping: 020_incorrect_100 [v3]
# ⏭ Skipping: 021_correct_100 [v3]
# ⏭ Skipping: 021_incorrect_100 [v3]
# ⏭ Skipping: 023_correct_100 [v3]
# ⏭ Skipping: 023_incorrect_100 [v3]
# ⏭ Skipping: 025_correct_100 [v3]
# ⏭ Skipping: 025_incorrect_100 [v3]
# ⏭ Skipping: 026_correct_100 [v3]
# ⏭ Skipping: 026_incorrect_100 [v3]
# ⏭ Skipping: 028_correct_100 [v3]
# ⏭ Skipping: 028_incorrect_100 [v3]
# ⏭ Skipping: 029_correct_100 [v3]
# ...
# ⏭ Skipping: 065_correct_100 [v4]
# ⏭ Skipping: 065_incorrect_100 [v4]
# ⏭ Skipping: 068_correct_100 [v4]
# ⏭ Skipping: 068_incorrect_100 [v4]
# ⏭ Skipping: 069_correct_100 [v4]
# ⏭ Skipping: 069_incorrect_100 [v4]
# ⏭ Skipping: 070_correct_100 [v4]
# ⏭ Skipping: 070_incorrect_100 [v4]
# ⏭ Skipping: 072_correct_100 [v4]
# ⏭ Skipping: 072_incorrect_100 [v4]
# ⏭ Skipping: 076_correct_100 [v4]
# ⏭ Skipping: 076_incorrect_100 [v4]
# ⏭ Skipping: 078_correct_100 [v4]
# ⏭ Skipping: 078_incorrect_100 [v4]
# ⏭ Skipping: 080_correct_100 [v4]
# ⏭ Skipping: 080_incorrect_100 [v4]
# ⏭ Skipping: 082_correct_100 [v4]
# ⏭ Skipping: 082_incorrect_100 [v4]
# ⏭ Skipping: 083_correct_100 [v4]
# ⏭ Skipping: 083_incorrect_100 [v4]
# ⏭ Skipping: 085_correct_100 [v4]
# ⏭ Skipping: 085_incorrect_100 [v4]
# ⏭ Skipping: 087_correct_100 [v4]
# ⏭ Skipping: 087_incorrect_100 [v4]
# ⏭ Skipping: 089_correct_100 [v4]
# ⏭ Skipping: 089_incorrect_100 [v4]
# ⏭ Skipping: 090_correct_100 [v4]
# ⏭ Skipping: 090_incorrect_100 [v4]
# ⏭ Skipping: 091_correct_100 [v4]
# ⏭ Skipping: 091_incorrect_100 [v4]
# ⏭ Skipping: 094_correct_100 [v4]
# ⏭ Skipping: 094_incorrect_100 [v4]
# ⏭ Skipping: 095_correct_100 [v4]
# ⏭ Skipping: 095_incorrect_100 [v4]
# ⏭ Skipping: 096_correct_100 [v4]
# ⏭ Skipping: 096_incorrect_100 [v4]
# ⏭ Skipping: 098_correct_100 [v4]
# ⏭ Skipping: 098_incorrect_100 [v4]
# ⏭ Skipping: 100_correct_100 [v4]
# ⏭ Skipping: 100_incorrect_100 [v4]
# ⏭ Skipping: 001_correct_1000 [v4]
# ⏭ Skipping: 001_incorrect_1000 [v4]
# ⏭ Skipping: 003_correct_1000 [v4]
# ⏭ Skipping: 003_incorrect_1000 [v4]
# ⏭ Skipping: 004_correct_1000 [v4]
# ⏭ Skipping: 004_incorrect_1000 [v4]
# ⏭ Skipping: 005_correct_1000 [v4]
# ⏭ Skipping: 005_incorrect_1000 [v4]
# ⏭ Skipping: 006_correct_1000 [v4]
# ⏭ Skipping: 006_incorrect_1000 [v4]
# ⏭ Skipping: 007_correct_1000 [v4]
# ⏭ Skipping: 007_incorrect_1000 [v4]
# ⏭ Skipping: 012_correct_1000 [v4]
# ⏭ Skipping: 012_incorrect_1000 [v4]
# ⏭ Skipping: 014_correct_1000 [v4]
# ⏭ Skipping: 014_incorrect_1000 [v4]
# ⏭ Skipping: 015_correct_1000 [v4]
# ⏭ Skipping: 015_incorrect_1000 [v4]
# ⏭ Skipping: 017_correct_1000 [v4]
# ⏭ Skipping: 017_incorrect_1000 [v4]
# ⏭ Skipping: 018_correct_1000 [v4]
# ⏭ Skipping: 018_incorrect_1000 [v4]
# ⏭ Skipping: 020_correct_1000 [v4]
# ⏭ Skipping: 020_incorrect_1000 [v4]
# ⏭ Skipping: 021_correct_1000 [v4]
# ⏭ Skipping: 021_incorrect_1000 [v4]
# ⏭ Skipping: 023_correct_1000 [v4]
# ⏭ Skipping: 023_incorrect_1000 [v4]
# ⏭ Skipping: 025_correct_1000 [v4]
# ⏭ Skipping: 025_incorrect_1000 [v4]
# ⏭ Skipping: 026_correct_1000 [v4]
# ⏭ Skipping: 026_incorrect_1000 [v4]
# ⏭ Skipping: 028_correct_1000 [v4]
# ⏭ Skipping: 028_incorrect_1000 [v4]
# ⏭ Skipping: 029_correct_1000 [v4]
# ⏭ Skipping: 029_incorrect_1000 [v4]
# ⏭ Skipping: 030_correct_1000 [v4]
# ⏭ Skipping: 030_incorrect_1000 [v4]
# ⏭ Skipping: 032_correct_1000 [v4]
# ⏭ Skipping: 032_incorrect_1000 [v4]
# ⏭ Skipping: 036_correct_1000 [v4]
# ⏭ Skipping: 036_incorrect_1000 [v4]
# ⏭ Skipping: 039_correct_1000 [v4]
# ⏭ Skipping: 039_incorrect_1000 [v4]
# ⏭ Skipping: 044_correct_1000 [v4]
# ⏭ Skipping: 044_incorrect_1000 [v4]
# ⏭ Skipping: 047_correct_1000 [v4]
# ⏭ Skipping: 047_incorrect_1000 [v4]
# ⏭ Skipping: 052_correct_1000 [v4]
# ⏭ Skipping: 052_incorrect_1000 [v4]
# ⏭ Skipping: 054_correct_1000 [v4]
# ⏭ Skipping: 054_incorrect_1000 [v4]
# ⏭ Skipping: 055_correct_1000 [v4]
# ⏭ Skipping: 055_incorrect_1000 [v4]
# ⏭ Skipping: 058_correct_1000 [v4]
# ⏭ Skipping: 058_incorrect_1000 [v4]
# ⏭ Skipping: 059_correct_1000 [v4]
# ⏭ Skipping: 059_incorrect_1000 [v4]
# ⏭ Skipping: 063_correct_1000 [v4]
# ⏭ Skipping: 063_incorrect_1000 [v4]
# ⏭ Skipping: 065_correct_1000 [v4]
# ⏭ Skipping: 065_incorrect_1000 [v4]
# ⏭ Skipping: 068_correct_1000 [v4]
# ⏭ Skipping: 068_incorrect_1000 [v4]
# ⏭ Skipping: 069_correct_1000 [v4]
# ⏭ Skipping: 069_incorrect_1000 [v4]
# ⏭ Skipping: 070_correct_1000 [v4]
# ⏭ Skipping: 070_incorrect_1000 [v4]
# ⏭ Skipping: 072_correct_1000 [v4]
# ⏭ Skipping: 072_incorrect_1000 [v4]
# ⏭ Skipping: 076_correct_1000 [v4]
# ⏭ Skipping: 076_incorrect_1000 [v4]
# ⏭ Skipping: 078_correct_1000 [v4]
# ⏭ Skipping: 078_incorrect_1000 [v4]
# ⏭ Skipping: 080_correct_1000 [v4]
# ⏭ Skipping: 080_incorrect_1000 [v4]
# ⏭ Skipping: 082_correct_1000 [v4]
# ⏭ Skipping: 082_incorrect_1000 [v4]
# ⏭ Skipping: 083_correct_1000 [v4]
# ⏭ Skipping: 083_incorrect_1000 [v4]
# ⏭ Skipping: 085_correct_1000 [v4]
# ⏭ Skipping: 085_incorrect_1000 [v4]
# ⏭ Skipping: 087_correct_1000 [v4]
# ⏭ Skipping: 087_incorrect_1000 [v4]
# ⏭ Skipping: 089_correct_1000 [v4]
# ⏭ Skipping: 089_incorrect_1000 [v4]
# ⏭ Skipping: 090_correct_1000 [v4]
# ⏭ Skipping: 090_incorrect_1000 [v4]
# ⏭ Skipping: 091_correct_1000 [v4]
# ⏭ Skipping: 091_incorrect_1000 [v4]
# ⏭ Skipping: 094_correct_1000 [v4]
# ⏭ Skipping: 094_incorrect_1000 [v4]
# ⏭ Skipping: 095_correct_1000 [v4]
# ⏭ Skipping: 095_incorrect_1000 [v4]
# ⏭ Skipping: 096_correct_1000 [v4]
# ⏭ Skipping: 096_incorrect_1000 [v4]
# ⏭ Skipping: 098_correct_1000 [v4]
# ⏭ Skipping: 098_incorrect_1000 [v4]
# ⏭ Skipping: 100_correct_1000 [v4]
# ⏭ Skipping: 100_incorrect_1000 [v4]
# ⏭ Skipping: 001_correct_10000 [v4]
# ⏭ Skipping: 001_incorrect_10000 [v4]
# ⏭ Skipping: 003_correct_10000 [v4]
# ⏭ Skipping: 003_incorrect_10000 [v4]
# ⏭ Skipping: 004_correct_10000 [v4]
# ⏭ Skipping: 004_incorrect_10000 [v4]
# ⏭ Skipping: 005_correct_10000 [v4]
# ⏭ Skipping: 005_incorrect_10000 [v4]
# ⏭ Skipping: 006_correct_10000 [v4]
# ⏭ Skipping: 006_incorrect_10000 [v4]
# ⏭ Skipping: 007_correct_10000 [v4]
# ⏭ Skipping: 007_incorrect_10000 [v4]
# ⏭ Skipping: 012_correct_10000 [v4]
# ⏭ Skipping: 012_incorrect_10000 [v4]
# ⏭ Skipping: 014_correct_10000 [v4]
# ⏭ Skipping: 014_incorrect_10000 [v4]
# ⏭ Skipping: 015_correct_10000 [v4]
# ⏭ Skipping: 015_incorrect_10000 [v4]
# ⏭ Skipping: 017_correct_10000 [v4]
# ⏭ Skipping: 017_incorrect_10000 [v4]
# ⏭ Skipping: 018_correct_10000 [v4]
# ⏭ Skipping: 018_incorrect_10000 [v4]
# ⏭ Skipping: 020_correct_10000 [v4]
# ⏭ Skipping: 020_incorrect_10000 [v4]
# ⏭ Skipping: 021_correct_10000 [v4]
# ⏭ Skipping: 021_incorrect_10000 [v4]
# ⏭ Skipping: 023_correct_10000 [v4]
# ⏭ Skipping: 023_incorrect_10000 [v4]
# ⏭ Skipping: 025_correct_10000 [v4]
# ⏭ Skipping: 025_incorrect_10000 [v4]
# ⏭ Skipping: 026_correct_10000 [v4]
# ⏭ Skipping: 026_incorrect_10000 [v4]
# ⏭ Skipping: 028_correct_10000 [v4]
# ⏭ Skipping: 028_incorrect_10000 [v4]
# ⏭ Skipping: 029_correct_10000 [v4]
# ⏭ Skipping: 029_incorrect_10000 [v4]
# ⏭ Skipping: 030_correct_10000 [v4]
# ⏭ Skipping: 030_incorrect_10000 [v4]
# ⏭ Skipping: 032_correct_10000 [v4]
# ⏭ Skipping: 032_incorrect_10000 [v4]
# ⏭ Skipping: 036_correct_10000 [v4]
# ⏭ Skipping: 036_incorrect_10000 [v4]
# ⏭ Skipping: 039_correct_10000 [v4]
# ⏭ Skipping: 039_incorrect_10000 [v4]
# ⏭ Skipping: 044_correct_10000 [v4]
# ⏭ Skipping: 044_incorrect_10000 [v4]
# ⏭ Skipping: 047_correct_10000 [v4]
# ⏭ Skipping: 047_incorrect_10000 [v4]
# ⏭ Skipping: 052_correct_10000 [v4]
# ⏭ Skipping: 052_incorrect_10000 [v4]
# ⏭ Skipping: 054_correct_10000 [v4]
# ⏭ Skipping: 054_incorrect_10000 [v4]
# ⏭ Skipping: 055_correct_10000 [v4]
# ⏭ Skipping: 055_incorrect_10000 [v4]
# ⏭ Skipping: 058_correct_10000 [v4]
# ⏭ Skipping: 058_incorrect_10000 [v4]
# ⏭ Skipping: 059_correct_10000 [v4]
# ⏭ Skipping: 059_incorrect_10000 [v4]
# ⏭ Skipping: 063_correct_10000 [v4]
# ⏭ Skipping: 063_incorrect_10000 [v4]
# ⏭ Skipping: 065_correct_10000 [v4]
# ⏭ Skipping: 065_incorrect_10000 [v4]
# ⏭ Skipping: 068_correct_10000 [v4]
# ⏭ Skipping: 068_incorrect_10000 [v4]
# ⏭ Skipping: 069_correct_10000 [v4]
# ⏭ Skipping: 069_incorrect_10000 [v4]
# ⏭ Skipping: 070_correct_10000 [v4]
# ⏭ Skipping: 070_incorrect_10000 [v4]
# ⏭ Skipping: 072_correct_10000 [v4]
# ⏭ Skipping: 072_incorrect_10000 [v4]
# ⏭ Skipping: 076_correct_10000 [v4]
# ⏭ Skipping: 076_incorrect_10000 [v4]
# ⏭ Skipping: 078_correct_10000 [v4]
# ⏭ Skipping: 078_incorrect_10000 [v4]
# ⏭ Skipping: 080_correct_10000 [v4]
# ⏭ Skipping: 080_incorrect_10000 [v4]
# ⏭ Skipping: 082_correct_10000 [v4]
# ⏭ Skipping: 082_incorrect_10000 [v4]
# ⏭ Skipping: 083_correct_10000 [v4]
# ⏭ Skipping: 083_incorrect_10000 [v4]
# ⏭ Skipping: 085_correct_10000 [v4]
# ⏭ Skipping: 085_incorrect_10000 [v4]
# ⏭ Skipping: 087_correct_10000 [v4]
# ⏭ Skipping: 087_incorrect_10000 [v4]
# ⏭ Skipping: 089_correct_10000 [v4]
# ⏭ Skipping: 089_incorrect_10000 [v4]
# ⏭ Skipping: 090_correct_10000 [v4]
# ⏭ Skipping: 090_incorrect_10000 [v4]
# ⏭ Skipping: 091_correct_10000 [v4]
# ⏭ Skipping: 091_incorrect_10000 [v4]
# ⏭ Skipping: 094_correct_10000 [v4]
# ⏭ Skipping: 094_incorrect_10000 [v4]
# ⏭ Skipping: 095_correct_10000 [v4]
# ⏭ Skipping: 095_incorrect_10000 [v4]
# ⏭ Skipping: 096_correct_10000 [v4]
# ⏭ Skipping: 096_incorrect_10000 [v4]
# ⏭ Skipping: 098_correct_10000 [v4]
# ⏭ Skipping: 098_incorrect_10000 [v4]
# ⏭ Skipping: 100_correct_10000 [v4]
# ⏭ Skipping: 100_incorrect_10000 [v4]
# ⏭ Skipping: 001_correct_100000 [v4]
# ⏭ Skipping: 001_incorrect_100000 [v4]
# ⏭ Skipping: 003_correct_100000 [v4]
# ⏭ Skipping: 003_incorrect_100000 [v4]
# ⏭ Skipping: 004_correct_100000 [v4]
# ⏭ Skipping: 004_incorrect_100000 [v4]
# ⏭ Skipping: 005_correct_100000 [v4]
# ⏭ Skipping: 005_incorrect_100000 [v4]
# ⏭ Skipping: 006_correct_100000 [v4]
# ⏭ Skipping: 006_incorrect_100000 [v4]
# ⏭ Skipping: 007_correct_100000 [v4]
# ⏭ Skipping: 007_incorrect_100000 [v4]
# ⏭ Skipping: 012_correct_100000 [v4]
# ⏭ Skipping: 012_incorrect_100000 [v4]
# ⏭ Skipping: 014_correct_100000 [v4]
# ⏭ Skipping: 014_incorrect_100000 [v4]
# ⏭ Skipping: 015_correct_100000 [v4]
# ⏭ Skipping: 015_incorrect_100000 [v4]
# ⏭ Skipping: 017_correct_100000 [v4]
# ⏭ Skipping: 017_incorrect_100000 [v4]
# ⏭ Skipping: 018_correct_100000 [v4]
# ⏭ Skipping: 018_incorrect_100000 [v4]
# ⏭ Skipping: 020_correct_100000 [v4]
# ⏭ Skipping: 020_incorrect_100000 [v4]
# ⏭ Skipping: 021_correct_100000 [v4]
# ⏭ Skipping: 021_incorrect_100000 [v4]
# ⏭ Skipping: 023_correct_100000 [v4]
# ⏭ Skipping: 023_incorrect_100000 [v4]
# ⏭ Skipping: 025_correct_100000 [v4]
# ⏭ Skipping: 025_incorrect_100000 [v4]
# ⏭ Skipping: 026_correct_100000 [v4]
# ⏭ Skipping: 026_incorrect_100000 [v4]
# ⏭ Skipping: 028_correct_100000 [v4]
# ⏭ Skipping: 028_incorrect_100000 [v4]
# ⏭ Skipping: 029_correct_100000 [v4]
# ⏭ Skipping: 029_incorrect_100000 [v4]
# ⏭ Skipping: 030_correct_100000 [v4]
# ⏭ Skipping: 030_incorrect_100000 [v4]
# ⏭ Skipping: 032_correct_100000 [v4]
# ⏭ Skipping: 032_incorrect_100000 [v4]
# ⏭ Skipping: 036_correct_100000 [v4]
# ⏭ Skipping: 036_incorrect_100000 [v4]
# ⏭ Skipping: 039_correct_100000 [v4]
# ⏭ Skipping: 039_incorrect_100000 [v4]
# ⏭ Skipping: 044_correct_100000 [v4]
# ⏭ Skipping: 044_incorrect_100000 [v4]
# ⏭ Skipping: 047_correct_100000 [v4]
# ⏭ Skipping: 047_incorrect_100000 [v4]
# ⏭ Skipping: 052_correct_100000 [v4]
# ⏭ Skipping: 052_incorrect_100000 [v4]
# ⏭ Skipping: 054_correct_100000 [v4]
# ⏭ Skipping: 054_incorrect_100000 [v4]
# ⏭ Skipping: 055_correct_100000 [v4]
# ⏭ Skipping: 055_incorrect_100000 [v4]
# ⏭ Skipping: 058_correct_100000 [v4]
# ⏭ Skipping: 058_incorrect_100000 [v4]
# ⏭ Skipping: 059_correct_100000 [v4]
# ⏭ Skipping: 059_incorrect_100000 [v4]
# ⏭ Skipping: 063_correct_100000 [v4]
# ⏭ Skipping: 063_incorrect_100000 [v4]
# ⏭ Skipping: 065_correct_100000 [v4]
# ⏭ Skipping: 065_incorrect_100000 [v4]
# ⏭ Skipping: 068_correct_100000 [v4]
# ⏭ Skipping: 068_incorrect_100000 [v4]
# ⏭ Skipping: 069_correct_100000 [v4]
# ⏭ Skipping: 069_incorrect_100000 [v4]
# ⏭ Skipping: 070_correct_100000 [v4]
# ⏭ Skipping: 070_incorrect_100000 [v4]
# ⏭ Skipping: 072_correct_100000 [v4]
# ⏭ Skipping: 072_incorrect_100000 [v4]
# ⏭ Skipping: 076_correct_100000 [v4]
# ⏭ Skipping: 076_incorrect_100000 [v4]
# ⏭ Skipping: 078_correct_100000 [v4]
# ⏭ Skipping: 078_incorrect_100000 [v4]
# ⏭ Skipping: 080_correct_100000 [v4]
# ⏭ Skipping: 080_incorrect_100000 [v4]
# ⏭ Skipping: 082_correct_100000 [v4]
# ⏭ Skipping: 082_incorrect_100000 [v4]
# ⏭ Skipping: 083_correct_100000 [v4]
# ⏭ Skipping: 083_incorrect_100000 [v4]
# ⏭ Skipping: 085_correct_100000 [v4]
# ⏭ Skipping: 085_incorrect_100000 [v4]
# ⏭ Skipping: 087_correct_100000 [v4]
# ⏭ Skipping: 087_incorrect_100000 [v4]
# ⏭ Skipping: 089_correct_100000 [v4]
# ⏭ Skipping: 089_incorrect_100000 [v4]
# ⏭ Skipping: 090_correct_100000 [v4]
# ⏭ Skipping: 090_incorrect_100000 [v4]
# ⏭ Skipping: 091_correct_100000 [v4]
# ⏭ Skipping: 091_incorrect_100000 [v4]
# ⏭ Skipping: 094_correct_100000 [v4]
# ⏭ Skipping: 094_incorrect_100000 [v4]
# ⏭ Skipping: 095_correct_100000 [v4]
# ⏭ Skipping: 095_incorrect_100000 [v4]
# ⏭ Skipping: 096_correct_100000 [v4]
# ⏭ Skipping: 096_incorrect_100000 [v4]
# ⏭ Skipping: 098_correct_100000 [v4]
# ⏭ Skipping: 098_incorrect_100000 [v4]
# ⏭ Skipping: 100_correct_100000 [v4]
# ⏭ Skipping: 100_incorrect_100000 [v4]
# ⏭ Skipping: 001_correct_1000000 [v4]
# ⏭ Skipping: 001_incorrect_1000000 [v4]
# ⏭ Skipping: 003_correct_1000000 [v4]
# ⏭ Skipping: 003_incorrect_1000000 [v4]
# ⏭ Skipping: 004_correct_1000000 [v4]
# ⏭ Skipping: 004_incorrect_1000000 [v4]
# ⏭ Skipping: 005_correct_1000000 [v4]
# ⏭ Skipping: 005_incorrect_1000000 [v4]
# ⏭ Skipping: 006_correct_1000000 [v4]
# ⏭ Skipping: 006_incorrect_1000000 [v4]
# ⏭ Skipping: 007_correct_1000000 [v4]
# ⏭ Skipping: 007_incorrect_1000000 [v4]
# ⏭ Skipping: 012_correct_1000000 [v4]
# ⏭ Skipping: 012_incorrect_1000000 [v4]
# ⏭ Skipping: 014_correct_1000000 [v4]
# ⏭ Skipping: 014_incorrect_1000000 [v4]
# ⏭ Skipping: 015_correct_1000000 [v4]
# ⏭ Skipping: 015_incorrect_1000000 [v4]
# ⏭ Skipping: 017_correct_1000000 [v4]
# ⏭ Skipping: 017_incorrect_1000000 [v4]
# ⏭ Skipping: 018_correct_1000000 [v4]
# ⏭ Skipping: 018_incorrect_1000000 [v4]
# ⏭ Skipping: 020_correct_1000000 [v4]
# ⏭ Skipping: 020_incorrect_1000000 [v4]
# ⏭ Skipping: 021_correct_1000000 [v4]
# ⏭ Skipping: 021_incorrect_1000000 [v4]
# ⏭ Skipping: 023_correct_1000000 [v4]
# ⏭ Skipping: 023_incorrect_1000000 [v4]
# ⏭ Skipping: 025_correct_1000000 [v4]
# ⏭ Skipping: 025_incorrect_1000000 [v4]
# ⏭ Skipping: 026_correct_1000000 [v4]
# ⏭ Skipping: 026_incorrect_1000000 [v4]
# ⏭ Skipping: 028_correct_1000000 [v4]
# ⏭ Skipping: 028_incorrect_1000000 [v4]
# ⏭ Skipping: 029_correct_1000000 [v4]
# ⏭ Skipping: 029_incorrect_1000000 [v4]
# ⏭ Skipping: 030_correct_1000000 [v4]
# ⏭ Skipping: 030_incorrect_1000000 [v4]
# ⏭ Skipping: 032_correct_1000000 [v4]
# ⏭ Skipping: 032_incorrect_1000000 [v4]
# ⏭ Skipping: 036_correct_1000000 [v4]
# ⏭ Skipping: 036_incorrect_1000000 [v4]
# ⏭ Skipping: 039_correct_1000000 [v4]
# ⏭ Skipping: 039_incorrect_1000000 [v4]
# ⏭ Skipping: 044_correct_1000000 [v4]
# ⏭ Skipping: 044_incorrect_1000000 [v4]
# ⏭ Skipping: 047_correct_1000000 [v4]
# ⏭ Skipping: 047_incorrect_1000000 [v4]
# ⏭ Skipping: 052_correct_1000000 [v4]
# ⏭ Skipping: 052_incorrect_1000000 [v4]
# ⏭ Skipping: 054_correct_1000000 [v4]
# ⏭ Skipping: 054_incorrect_1000000 [v4]
# ⏭ Skipping: 055_correct_1000000 [v4]
# ⏭ Skipping: 055_incorrect_1000000 [v4]
# ⏭ Skipping: 058_correct_1000000 [v4]
# ⏭ Skipping: 058_incorrect_1000000 [v4]
# ⏭ Skipping: 059_correct_1000000 [v4]
# ⏭ Skipping: 059_incorrect_1000000 [v4]
# ⏭ Skipping: 063_correct_1000000 [v4]
# ⏭ Skipping: 063_incorrect_1000000 [v4]
# ⏭ Skipping: 065_correct_1000000 [v4]
# ⏭ Skipping: 065_incorrect_1000000 [v4]
# ⏭ Skipping: 068_correct_1000000 [v4]
# ⏭ Skipping: 068_incorrect_1000000 [v4]
# ⏭ Skipping: 069_correct_1000000 [v4]
# ⏭ Skipping: 069_incorrect_1000000 [v4]
# ⏭ Skipping: 070_correct_1000000 [v4]
# ⏭ Skipping: 070_incorrect_1000000 [v4]
# ⏭ Skipping: 072_correct_1000000 [v4]
# ⏭ Skipping: 072_incorrect_1000000 [v4]
# ⏭ Skipping: 076_correct_1000000 [v4]
# ⏭ Skipping: 076_incorrect_1000000 [v4]
# ⏭ Skipping: 078_correct_1000000 [v4]
# ⏭ Skipping: 078_incorrect_1000000 [v4]
# ⏭ Skipping: 080_correct_1000000 [v4]
# ⏭ Skipping: 080_incorrect_1000000 [v4]
# ⏭ Skipping: 082_correct_1000000 [v4]
# ⏭ Skipping: 082_incorrect_1000000 [v4]
# ⏭ Skipping: 083_correct_1000000 [v4]
# ⏭ Skipping: 083_incorrect_1000000 [v4]
# ⏭ Skipping: 085_correct_1000000 [v4]
# ⏭ Skipping: 085_incorrect_1000000 [v4]
# ⏭ Skipping: 087_correct_1000000 [v4]
# ⏭ Skipping: 087_incorrect_1000000 [v4]
# ⏭ Skipping: 089_correct_1000000 [v4]
# ⏭ Skipping: 089_incorrect_1000000 [v4]
# ⏭ Skipping: 090_correct_1000000 [v4]
# ⏭ Skipping: 090_incorrect_1000000 [v4]
# ⏭ Skipping: 091_correct_1000000 [v4]
# ⏭ Skipping: 091_incorrect_1000000 [v4]
# ⏭ Skipping: 094_correct_1000000 [v4]
# ⏭ Skipping: 094_incorrect_1000000 [v4]
# ⏭ Skipping: 095_correct_1000000 [v4]
# ⏭ Skipping: 095_incorrect_1000000 [v4]
# ⏭ Skipping: 096_correct_1000000 [v4]
# ⏭ Skipping: 096_incorrect_1000000 [v4]
# ⏭ Skipping: 098_correct_1000000 [v4]
# ⏭ Skipping: 098_incorrect_1000000 [v4]
# ⏭ Skipping: 100_correct_1000000 [v4]
# ⏭ Skipping: 100_incorrect_1000000 [v4]
#
# ✅ All metrics versions complete.

# %%
from utils.quanti_benchmarking_4_analysis import run_accuracy_analysis

BASE_DIR = Path().resolve()
EXPERIMENT_NAME = "test-5-metrics-realistic-claim-only"

run_accuracy_analysis(BASE_DIR, EXPERIMENT_NAME)
# Out:
# ============================================================
# Prompt Version : v1
# Prompt Text    : Does the text in the post accurately describe the chart? Reply with only 'correct' or 'incorrect'.
# ============================================================
# === Overall Summary ===
#                        metric   value
# 0          overall_accuracy_%   64.17
# 1    accuracy_correct_posts_%   28.33
# 2  accuracy_incorrect_posts_%  100.00
# === Accuracy per Reaction Level ===
# /home/jovyan/utils/quanti_benchmarking_4_analysis.py:60: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   per_scale = df.groupby("scale_value").apply(lambda g: pd.Series({
#   scale_value  total_images  overall_accuracy_%  correct_posts_accuracy_%  \
# 0          10         100.0                68.0                      36.0
# 1         100         100.0                64.0                      28.0
# 2        1000         100.0                66.0                      32.0
# 3       10000         100.0                65.0                      30.0
# 4      100000         100.0                61.0                      22.0
# 5     1000000         100.0                61.0                      22.0
#
#    incorrect_posts_accuracy_%
# 0                       100.0
# 1                       100.0
# 2                       100.0
# 3                       100.0
# 4                       100.0
# 5                       100.0
# === Per Image Results ===
#                      image scale_value    variant ground_truth prediction  \
# 0           001_correct_10          10    correct      correct  incorrect
# 2           003_correct_10          10    correct      correct  incorrect
# 4           004_correct_10          10    correct      correct    correct
# 6           005_correct_10          10    correct      correct  incorrect
# 8           006_correct_10          10    correct      correct  incorrect
# ..                     ...         ...        ...          ...        ...
# 591  094_incorrect_1000000     1000000  incorrect    incorrect  incorrect
# 593  095_incorrect_1000000     1000000  incorrect    incorrect  incorrect
# 595  096_incorrect_1000000     1000000  incorrect    incorrect  incorrect
# 597  098_incorrect_1000000     1000000  incorrect    incorrect  incorrect
# 599  100_incorrect_1000000     1000000  incorrect    incorrect  incorrect
#
#      correct
# 0      False
# 2      False
# 4       True
# 6      False
# 8      False
# ..       ...
# 591     True
# 593     True
# 595     True
# 597     True
# 599     True
#
# [600 rows x 6 columns]
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-5-metrics-realistic-claim-only/v1/accuracy_scores_v1.csv
#
# ============================================================
# Prompt Version : v2
# Prompt Text    : Read the text in the post and look at the chart. Does the text correctly describe what the chart shows? Reply with only 'correct' or 'incorrect'.
# ============================================================
# === Overall Summary ===
#                        metric  value
# 0          overall_accuracy_%   74.5
# 1    accuracy_correct_posts_%   49.0
# 2  accuracy_incorrect_posts_%  100.0
# === Accuracy per Reaction Level ===
# /home/jovyan/utils/quanti_benchmarking_4_analysis.py:60: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   per_scale = df.groupby("scale_value").apply(lambda g: pd.Series({
#   scale_value  total_images  overall_accuracy_%  correct_posts_accuracy_%  \
# 0          10         100.0                77.0                      54.0
# 1         100         100.0                76.0                      52.0
# 2        1000         100.0                72.0                      44.0
# 3       10000         100.0                77.0                      54.0
# 4      100000         100.0                75.0                      50.0
# 5     1000000         100.0                70.0                      40.0
#
#    incorrect_posts_accuracy_%
# 0                       100.0
# 1                       100.0
# 2                       100.0
# 3                       100.0
# 4                       100.0
# 5                       100.0
# === Per Image Results ===
#                      image scale_value    variant ground_truth prediction  \
# 0           001_correct_10          10    correct      correct  incorrect
# 2           003_correct_10          10    correct      correct    correct
# 4           004_correct_10          10    correct      correct    correct
# 6           005_correct_10          10    correct      correct    correct
# 8           006_correct_10          10    correct      correct  incorrect
# ..                     ...         ...        ...          ...        ...
# 591  094_incorrect_1000000     1000000  incorrect    incorrect  incorrect
# 593  095_incorrect_1000000     1000000  incorrect    incorrect  incorrect
# 595  096_incorrect_1000000     1000000  incorrect    incorrect  incorrect
# 597  098_incorrect_1000000     1000000  incorrect    incorrect  incorrect
# 599  100_incorrect_1000000     1000000  incorrect    incorrect  incorrect
#
#      correct
# 0      False
# 2       True
# 4       True
# 6       True
# 8      False
# ..       ...
# 591     True
# 593     True
# 595     True
# 597     True
# 599     True
#
# [600 rows x 6 columns]
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-5-metrics-realistic-claim-only/v2/accuracy_scores_v2.csv
#
# ============================================================
# Prompt Version : v3
# Prompt Text    : The post text claims one music genre is more popular than another. Look at the percentage values in the chart to verify this claim. If the genre described as more popular in the text has a higher percentage in the chart, reply 'correct'. If not, reply 'incorrect'.
# ============================================================
# === Overall Summary ===
#                        metric  value
# 0          overall_accuracy_%   87.5
# 1    accuracy_correct_posts_%   75.0
# 2  accuracy_incorrect_posts_%  100.0
# === Accuracy per Reaction Level ===
# /home/jovyan/utils/quanti_benchmarking_4_analysis.py:60: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   per_scale = df.groupby("scale_value").apply(lambda g: pd.Series({
#   scale_value  total_images  overall_accuracy_%  correct_posts_accuracy_%  \
# 0          10         100.0                86.0                      72.0
# 1         100         100.0                88.0                      76.0
# 2        1000         100.0                90.0                      80.0
# 3       10000         100.0                89.0                      78.0
# 4      100000         100.0                87.0                      74.0
# 5     1000000         100.0                85.0                      70.0
#
#    incorrect_posts_accuracy_%
# 0                       100.0
# 1                       100.0
# 2                       100.0
# 3                       100.0
# 4                       100.0
# 5                       100.0
# === Per Image Results ===
#                      image scale_value    variant ground_truth prediction  \
# 0           001_correct_10          10    correct      correct  incorrect
# 2           003_correct_10          10    correct      correct    correct
# 4           004_correct_10          10    correct      correct    correct
# 6           005_correct_10          10    correct      correct    correct
# 8           006_correct_10          10    correct      correct  incorrect
# ..                     ...         ...        ...          ...        ...
# 591  094_incorrect_1000000     1000000  incorrect    incorrect  incorrect
# 593  095_incorrect_1000000     1000000  incorrect    incorrect  incorrect
# 595  096_incorrect_1000000     1000000  incorrect    incorrect  incorrect
# 597  098_incorrect_1000000     1000000  incorrect    incorrect  incorrect
# 599  100_incorrect_1000000     1000000  incorrect    incorrect  incorrect
#
#      correct
# 0      False
# 2       True
# 4       True
# 6       True
# 8      False
# ..       ...
# 591     True
# 593     True
# 595     True
# 597     True
# 599     True
#
# [600 rows x 6 columns]
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-5-metrics-realistic-claim-only/v3/accuracy_scores_v3.csv
#
# ============================================================
# Prompt Version : v4
# Prompt Text    : In the post, the text above the image makes a claim comparing the popularity of Pop and Latin. Identify the according values in the chart to verify this claim. If the claim matches the visualization reply 'correct'. If not, reply 'incorrect'.
# ============================================================
# === Overall Summary ===
#                        metric   value
# 0          overall_accuracy_%   98.83
# 1    accuracy_correct_posts_%   97.67
# 2  accuracy_incorrect_posts_%  100.00
# === Accuracy per Reaction Level ===
# /home/jovyan/utils/quanti_benchmarking_4_analysis.py:60: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   per_scale = df.groupby("scale_value").apply(lambda g: pd.Series({
#   scale_value  total_images  overall_accuracy_%  correct_posts_accuracy_%  \
# 0          10         100.0                98.0                      96.0
# 1         100         100.0                98.0                      96.0
# 2        1000         100.0                99.0                      98.0
# 3       10000         100.0                99.0                      98.0
# 4      100000         100.0               100.0                     100.0
# 5     1000000         100.0                99.0                      98.0
#
#    incorrect_posts_accuracy_%
# 0                       100.0
# 1                       100.0
# 2                       100.0
# 3                       100.0
# 4                       100.0
# 5                       100.0
# === Per Image Results ===
#                      image scale_value    variant ground_truth prediction  \
# 0           001_correct_10          10    correct      correct  incorrect
# 2           003_correct_10          10    correct      correct    correct
# 4           004_correct_10          10    correct      correct    correct
# 6           005_correct_10          10    correct      correct    correct
# 8           006_correct_10          10    correct      correct    correct
# ..                     ...         ...        ...          ...        ...
# 591  094_incorrect_1000000     1000000  incorrect    incorrect  incorrect
# 593  095_incorrect_1000000     1000000  incorrect    incorrect  incorrect
# 595  096_incorrect_1000000     1000000  incorrect    incorrect  incorrect
# 597  098_incorrect_1000000     1000000  incorrect    incorrect  incorrect
# 599  100_incorrect_1000000     1000000  incorrect    incorrect  incorrect
#
#      correct
# 0      False
# 2       True
# 4       True
# 6       True
# 8       True
# ..       ...
# 591     True
# 593     True
# 595     True
# 597     True
# 599     True
#
# [600 rows x 6 columns]
# ✅ Saved to: /home/jovyan/benchmarking/outputs/quantitative/test-5-metrics-realistic-claim-only/v4/accuracy_scores_v4.csv
